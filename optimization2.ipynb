# %%
import pygame
import random
import math
import queue
import pandas as pd
from datetime import datetime
import time

# ---------------- Global Configuration ----------------
# Speed control constants
PPM = 1100 / 170  # Pixels Per Meter (screen scaling)
pixel_speed = ((3 * PPM) / 60) * 10  # Converts 3 m/s to pixels per frame (adjusted for 60 FPS and visibility)

SIMULATION_SPEED = 10.0 # Adjust simulation speed here
update_log = []  # Global log for simulation messages

# Set to store reservations that will have a longer wait time (4-5 minutes)
delayed_reservations = set()
# Counter to limit the number of delayed reservations
delayed_count = 0
# Maximum number of delayed reservations per flight#############################################
MAX_DELAYED_RESERVATIONS = 0

def add_update_message(message, color):
    update_log.append((message, color, pygame.time.get_ticks()))
    # Debug print
    print(f"[LOG] {message}")

def load_data():
    """Loads luggage data from CSV and filters for SLHS-handled bags."""
    file_path = "~/Desktop/A/luggage_data_sle.csv"
    df = pd.read_csv(file_path)
    df['Handled_by_SLHS'] = df['Handled_by_SLHS'].astype(str).str.lower()
    filtered_df = df[df['Handled_by_SLHS'] == 'true']
    return filtered_df

def get_flights_data(data):
    """Organizes luggage data into a dictionary grouped by flight number."""
    flights = data['Flight_Number'].unique()
    flights_data = {}
    for flight in flights:
        flights_data[flight] = data[data['Flight_Number'] == flight]
    return flights_data

def expected_bags_for_reservation(reservation, fallback):
    """
    Returns the expected bag count extracted from the reservation id.
    For instance, if the id ends with "04", returns 4.
    Otherwise, uses the fallback value.
    """
    if reservation[-2:].isdigit():
        return int(reservation[-2:])
    return fallback

# ---------------- Definitions for Conveyor Belt and Key Points ----------------

conveyor_belts = [
    [(1200, 600), (100, 600)],
    [(100, 550), (800, 550)],
    [(200, 500), (800, 500)],
    [(200, 450), (700, 450)],
    [(300, 400), (700, 400)],
    [(300, 350), (600, 350)],
    [(100, 250), (900, 250)],
    [(100, 600), (100, 200)],
    [(200, 500), (200, 200)],
    [(300, 400), (300, 200)],
    [(600, 350), (600, 200)],
    [(700, 450), (700, 200)],
    [(800, 550), (800, 200)],
    [(900, 600), (900, 250)],
    [(580, 200), (600, 250)],
    [(620, 200), (600, 250)],
    [(320, 200), (300, 250)],
    [(280, 200), (300, 250)],
    [(680, 200), (700, 250)],
    [(720, 200), (700, 250)],
    [(180, 200), (200, 250)],
    [(220, 200), (200, 250)],
    [(780, 200), (800, 250)],
    [(820, 200), (800, 250)],
    [(80, 200), (100, 250)],
    [(120, 200), (100, 250)],
]

points = [
    (100, 250), (100, 550), (100, 600),
    (200, 250), (200, 450), (200, 500),
    (300, 250), (300, 350), (300, 400),
    (600, 250), (600, 350), (700, 250),
    (700, 400), (700, 450), (800, 250),
    (800, 500), (800, 550), (900, 250),
    (900, 600)
]

gates_entry_positions = [
    (600, 250),  # Gate 7
    (300, 250),  # Gate 6
    (700, 250),  # Gate 5
    (200, 250),  # Gate 4
    (800, 250),  # Gate 3
    (100, 250),  # Gate 2
]

pickup_gates_positions = [
    (600, 200),  # Gate 7 - 7B
    (580, 200),  # Gate 7 - 7A
    (620, 200),  # Gate 7 - 7C
    (300, 200),  # Gate 6 - 6B
    (320, 200),  # Gate 6 - 6A
    (280, 200),  # Gate 6 - 6C
    (700, 200),  # Gate 5 - 5B
    (680, 200),  # Gate 5 - 5A
    (720, 200),  # Gate 5 - 5C
    (200, 200),  # Gate 4 - 4B
    (180, 200),  # Gate 4 - 4A
    (220, 200),  # Gate 4 - 4C
    (800, 200),  # Gate 3 - 3B
    (780, 200),  # Gate 3 - 3A
    (820, 200),  # Gate 3 - 3C
    (100, 200),  # Gate 2 - 2B
    (80, 200),   # Gate 2 - 2A
    (120, 200),  # Gate 2 - 2C
]

# ---------------- Path and Reservation Color Generation ----------------

class Path:
    def __init__(self, name, points):
        self.name = name
        self.points = points

paths = {
    7: Path("F", [(900, 600), (100, 600), (100, 550), (100, 250)]),
    6: Path("E", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (800, 250)]),
    5: Path("D", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (200, 250)]),
    4: Path("C", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (700, 250)]),
    3: Path("B", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (300, 400), (300, 350), (300, 250)]),
    2: Path("A", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (300, 400), (300, 350), (600, 350), (600, 250)])
}

paths_2 = {
    cluster: Path(str(cluster), points)
    for cluster, points in {
        7: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        6: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        5: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        4: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        3: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        2: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)]
    }.items()
}

def generate_color_from_id(reservation_id):
    numbers = ''.join(filter(str.isdigit, reservation_id))
    hash_value = hash(numbers) if numbers else hash(reservation_id)
    r = (hash_value % 200) + 30
    g = ((hash_value // 200) % 200) + 30
    b = ((hash_value // 40000) % 200) + 30
    return (r, g, b)

reservation_colors = {}
claim_stats = {}

# ---------------- Bag Class ----------------

class Bag:
    def __init__(self, bag_id, reservation_id, flight_number, num_bags):
        self.ready = False
        self.path = []
        self.bag_id = bag_id
        self.reservation = reservation_id.lower()
        self.flight_number = flight_number
        self.num_bags_in_res = num_bags  # total number of bags in this reservation
        self.position = (1200, 600)
        self.assigned_to_gate = False
        self.gate = None
        #self.speed = 2 * SIMULATION_SPEED
        self.speed = pixel_speed * SIMULATION_SPEED  # ✅ correct formula from FINAL Connected.ipynb
        self.target = None
        self.start_time = None
        self.end_time = None
        self.travel_time = None
        self.claimed = False
        if self.reservation not in reservation_colors:
            reservation_colors[self.reservation] = generate_color_from_id(self.reservation)
        self.color = reservation_colors[self.reservation]
        self.last_reassign_attempt = 0

    def set_ready(self):
        self.ready = True
        self.start_time = pygame.time.get_ticks()

    def set_path(self, path):
        self.path = path.points[:] if isinstance(path, Path) else path[:]
        if self.path:
            self.target = self.path.pop(0)

    def set_gate(self, pickup_gate):
        self.gate = pickup_gate
        # Debug print
        print(f"[DEBUG] Bag {self.bag_id} with reservation {self.reservation} assigned to gate {pickup_gate.display_name}")

    def append_path(self, path):
        if isinstance(path, Path):
            self.path.extend(path.points)
        elif isinstance(path, list):
            self.path.extend(path)
        elif isinstance(path, tuple):
            self.path.append(path)
        if not self.target and self.path:
            self.target = self.path.pop(0)

    def has_reached_last_point(self):
        if not self.path:
            return True
        last_x, last_y = self.path[-1]
        return abs(self.position[0] - last_x) < 5 and abs(self.position[1] - last_y) < 5

    def has_reached_gate(self, threshold=8):
        if self.gate is None:
            return False
        gx, gy = self.gate.position
        bx, by = self.position
        return math.hypot(gx - bx, gy - by) < threshold

    def move(self):
        if self.target:
            x, y = self.position
            tx, ty = self.target
            dx = tx - x
            dy = ty - y
            distance = math.hypot(dx, dy)
            if distance <= self.speed or distance < 0.5:
                self.position = self.target
                if self.path:
                    self.target = self.path.pop(0)
                else:
                    self.target = None
                   # if not self.assigned_to_gate:
                    if not self.assigned_to_gate and self.gate is None:
                        # Try to assign to a gate
                        gate_assigned = False
                        
                        # Get the expected bags from the reservation ID
                        expected_bags = expected_bags_for_reservation(self.reservation, self.num_bags_in_res)
                        
                        # Be more lenient in the move method since we can't check remaining bags
                        # Assign to a gate regardless of expected bags count
                        for gate in gate_entries:
                            idx = gate.search(self)
                            if idx != -1:
                                self.set_path(paths[gate.name])
                                gate.gates[idx].set_reservation(self.reservation, expected_bags)
                                self.append_path(gate.gates[idx].position)
                                self.set_gate(gate.gates[idx])
                                self.assigned_to_gate = True
                                gate_assigned = True
                                break
                        if not gate_assigned:
                            self.set_path(paths_2[terminal_priority[0]])
            else:
                self.position = (x + (dx / distance) * self.speed, y + (dy / distance) * self.speed)

    def set_claimed(self):
        if not self.claimed:
            self.claimed = True
            self.end_time = pygame.time.get_ticks()
            self.travel_time = (self.end_time - self.start_time) / 1000.0
            if self.reservation not in claim_stats:
                claim_stats[self.reservation] = {"time": self.travel_time, "bags": 1, "flight": self.flight_number}
            else:
                claim_stats[self.reservation]["bags"] += 1

# ---------------- Gate and PickupGate Classes ----------------

gate_names = {7: "2", 6: "3", 5: "4", 4: "5", 3: "6", 2: "7"}
sub_gate_labels = ["A", "B", "C"]
terminal_priority = [7, 6, 5, 4, 3, 2]

class Gate:
    def __init__(self, name, gates, position):
        self.name = name
        self.display_name = gate_names.get(name, str(name))
        self.gates = gates
        self.position = position
        self.reservation_bags = {}
        self.claim_times = {}

    def max_loading(self):
        for pickup in self.gates:
            pickup.set_max()

    def search(self, bag):
        # First try to assign to a gate with the same reservation that is not full.
        for i, pickup in enumerate(self.gates):
            if pickup.reservation == bag.reservation and not pickup.full:
                return i
        # Otherwise, return the first unreserved gate.
        for i, pickup in enumerate(self.gates):
            if pickup.reservation is None:
                return i
        return -1

    ######################################
    # Check if this is a delayed reservation
           # wait_time = 300000 if reservation in delayed_reservations else 20000  # 5 minutes or 20 seconds
           # wait_time = 300000 if reservation in delayed_reservations else random.randint(10000, 70000)  # 10–70 sec 
           # if current_time - claim_time >= wait_time:
               # for pickup in self.gates:
                 #  if pickup.reservation == reservation:

    def update_claim_status(self, current_time , scanned_bags):
        for reservation, claim_time in list(self.claim_times.items()):
            for pickup in self.gates:
                if pickup.reservation == reservation:
                     # ✅ Check if claim_wait_time is set before using it
                    if not hasattr(pickup, "claim_wait_time"):
                       continue  # Skip if claim_wait_time wasn't set
                    wait_time = pickup.claim_wait_time  # ✅ Use fixed wait time
                    if current_time - claim_time >= wait_time:
                       for bag in pickup.bags:
                            bag.set_claimed()
                       sub_index = self.gates.index(pickup)
                       sub_label = sub_gate_labels[sub_index]
                       travel_time = pickup.bags[0].travel_time if pickup.bags else 0
                        
                        # Debug print for delayed reservations
                       if reservation in delayed_reservations:
                            msg = f"Delayed reservation {reservation} claimed from Gate {gate_names.get(self.name, self.name)}{sub_label} after 5 minutes"
                            print(f"[DEBUG] {msg}")
                       else:
                            msg = f"Reservation {reservation} claimed from Gate {gate_names.get(self.name, self.name)}{sub_label} in {format_time(travel_time)}"
                        
                       add_update_message(msg, reservation_colors.get(reservation, (0, 0, 0)))
                       pickup.clear_luggage(scanned_bags)
                        
                        # Remove from delayed reservations if it was there
                       if reservation in delayed_reservations:
                            delayed_reservations.remove(reservation)
                            
                       del self.claim_times[reservation]

    def check_complete_reservations(self, moving_bags):
        current_time = pygame.time.get_ticks()
        global delayed_count

        for pickup in self.gates:
            if pickup.reservation and pickup.load > 0 and pickup.reservation not in self.claim_times:
            
               if pickup.load >= pickup.expected_bags:
                  should_start_claim = True
               else:
                # Not all bags yet — check if any more bags are still moving
                    bags_still_moving = any(
                    bag for bag in moving_bags
                    if bag.reservation == pickup.reservation and not bag.claimed
                )
                    should_start_claim = not bags_still_moving  # debug Start claim only if no more bags moving meaning in the end start he timer any way 

               if should_start_claim:
                   self.claim_times[pickup.reservation] = current_time

                   if delayed_count < MAX_DELAYED_RESERVATIONS and random.random() < 0.2:# for the delayed bags 
                    delayed_reservations.add(pickup.reservation)
                    delayed_count += 1
                    wait_time = "5 minutes"
                    print(f"[DEBUG] Reservation {pickup.reservation} will be delayed for {wait_time}")
                   else:
                    wait_time = random.randint(10000, 70000)  # 10–70 seconds
                       
                    wait_seconds = wait_time // 1000  # Convert ms to seconds
                    print(f"[DEBUG] Reservation {pickup.reservation} will have normal delay of {wait_seconds} seconds")

                   pickup.claim_wait_time = wait_time  # ✅ Save wait time here
                   self.claim_times[pickup.reservation] = current_time
                   msg = (f"Starting {wait_seconds}s claim timer for reservation {pickup.reservation} "
                            f"at Gate {gate_names.get(self.name, self.name)}{pickup.name}")
                   add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))


                   # msg = (f"Starting {wait_time} claim timer for reservation {pickup.reservation} "
                    #   f"at Gate {gate_names.get(self.name, self.name)}{pickup.name}")
                   # add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))
'''def check_complete_reservations(self):############################################################
        current_time = pygame.time.get_ticks()
        global delayed_count
        
        # Check for each pickup gate
        for pickup in self.gates:
            # If the gate has a reservation, has at least one bag, and isn't already in claim timer
            if pickup.reservation and pickup.load > 0 and pickup.reservation not in self.claim_times:
                # Only start the claim timer if we've reached the expected number of bags
                # This ensures gates wait for the correct number of bags based on the reservation ID
                if pickup.load >= pickup.expected_bags:
                     should_start_claim = True
                else:   # Not all bags yet — check if bags are still moving
                    if no more moving bags with the same reservation:
                     start claim timer (because we know no more will come)
                    else:
                        wait (don't start timer yet)
                    
                    # Decide if this reservation should be delayed (only for the first few reservations)
                    if delayed_count < MAX_DELAYED_RESERVATIONS and random.random() < 0.2:  # 20% chance
                        delayed_reservations.add(pickup.reservation)
                        delayed_count += 1
                        wait_time = "5 minutes"
                        print(f"[DEBUG] Reservation {pickup.reservation} will be delayed for {wait_time}")
                    else:
                        wait_time = "20 seconds"
                    
                    msg = (f"Starting {wait_time} claim timer for reservation {pickup.reservation} "
                           f"at Gate {gate_names.get(self.name, self.name)}{pickup.name}")
                    add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))'''

class PickupGate:
    def __init__(self, name, position, parent_gate):
        self.name = name
        self.position = position
        self.parent_gate = parent_gate
        self.display_name = f"{gate_names[parent_gate]}{name}"
        self.reservation = None
        self.load = 0
        self.bags = []
        self.full = False
        self.status = "Available"
        self.pending_start_time = None
        self.expected_bags = 0

    def set_reservation(self, reservation, expected=None):
        if self.reservation is None:
            self.reservation = reservation.lower()
            self.status = "Reserved"
            if expected is None:
                expected = expected_bags_for_reservation(reservation, 1)
            self.expected_bags = expected
            # Debug print
            print(f"[DEBUG] Gate {self.display_name} reserved for reservation {reservation} (expecting {expected} bags)")
            return True
        return False

    def add_luggage(self, bag):
        current_time = pygame.time.get_ticks()
        # Only add this bag if it hasn't already been added.
        if bag.reservation == self.reservation and not self.full:
            if bag not in self.bags:
                self.bags.append(bag)
                self.load += 1
                # Update the pending_start_time whenever a new bag is added
                self.pending_start_time = current_time
                # Debug print
                print(f"[DEBUG] Bag {bag.bag_id} added to gate {self.display_name} ({self.load}/{self.expected_bags})")
            # When the total number of bags equals the expected count, mark the gate as full.
            if self.load >= self.expected_bags:
                self.full = True
                print(f"[DEBUG] Gate {self.display_name} is now full with {self.load} bags")

    def set_max(self):
        pass  # Not used in this version.

    def clear_luggage(self,scanned_bags):
        moving_bags = any(
        bag for bag in scanned_bags
        if bag.gate == self and not bag.claimed
    )
        # Debug print
       # if self.reservation:
          #  print(f"[DEBUG] Gate {self.display_name} cleared of reservation {self.reservation}")
        
        if not moving_bags:############
        # No more bags moving → Now it's safe to clear
          print(f"[DEBUG] Gate {self.display_name} cleared (no moving bags)")##################
          self.reservation = None
          self.load = 0
          self.bags = []
          self.full = False
          self.status = "Available"
          self.pending_start_time = None
          self.expected_bags = 0
        else:##########################################################
        # Still bags moving → Keep reservation!
            print(f"[DEBUG] Gate {self.display_name} NOT cleared — bags still moving toward it")
    

# ---------------- Initialize Gate Entries ----------------

gate_entries = [
    Gate(7, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[16], 7),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[15], 7),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[17], 7)
    ], gates_entry_positions[5]),
    Gate(6, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[13], 6),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[12], 6),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[14], 6)
    ], gates_entry_positions[4]),
    Gate(5, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[10], 5),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[9], 5),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[11], 5)
    ], gates_entry_positions[3]),
    Gate(4, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[7], 4),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[6], 4),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[8], 4)
    ], gates_entry_positions[2]),
    Gate(3, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[5], 3),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[3], 3),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[4], 3)
    ], gates_entry_positions[1]),
    Gate(2, [
        PickupGate(sub_gate_labels[0], pickup_gates_positions[1], 2),
        PickupGate(sub_gate_labels[1], pickup_gates_positions[0], 2),
        PickupGate(sub_gate_labels[2], pickup_gates_positions[2], 2)
    ], gates_entry_positions[0]),
]

for gate in gate_entries:
    gate.max_loading()

def format_time(seconds):
    minutes = int(seconds // 60)
    sec = int(seconds % 60)
    return f"{minutes:02d}:{sec:02d}"

# ---------------- Utility Functions for Drawing ----------------

def draw_log_box(screen, font):
    box_x, box_y, box_w, box_h = 920, 50, 450, 450
    bg_color = (250, 250, 250)
    BLACK = (0, 0, 0)
    GRAY = (80, 80, 80)
    pygame.draw.rect(screen, bg_color, (box_x, box_y, box_w, box_h))
    pygame.draw.rect(screen, GRAY, (box_x, box_y, box_w, box_h), 2)
    messages_to_show = update_log[-15:]
    text_y = box_y + 5
    for msg, color, _ in messages_to_show:
        text_surface = font.render(msg, True, BLACK)
        screen.blit(text_surface, (box_x + 20, text_y))
        pygame.draw.circle(screen, color, (box_x + 10, text_y + text_surface.get_height() // 2), 5)
        text_y += text_surface.get_height() + 5

def draw_gate_status_box(screen, medium_font, white_color):
    box_x, box_y, box_w, box_h = 920, 400, 450, 180
    bg_color = (250, 250, 250)
    BLACK = (0, 0, 0)
    GRAY = (80, 80, 80)
    pygame.draw.rect(screen, bg_color, (box_x, box_y, box_w, box_h))
    pygame.draw.rect(screen, GRAY, (box_x, box_y, box_w, box_h), 2)
    gate_status_y = box_y + 10
    gate_status_title = medium_font.render("Gate Status:", True, BLACK)
    screen.blit(gate_status_title, (box_x + 10, gate_status_y))
    gate_status_y += gate_status_title.get_height() + 5
    gates_per_line = 3
    gate_line_count = 0
    gate_col_count = 0
    gate_start_x = box_x + 10
    gate_current_x = gate_start_x
    gate_current_y = gate_status_y
    for gate in gate_entries:
        for pickup in gate.gates:
            if pickup.reservation is not None:
                remaining = pickup.expected_bags - pickup.load
                if remaining < 0: 
                    remaining = 0
                
                # Show if this is a delayed reservation
                if pickup.reservation in delayed_reservations:
                    status_str = f"{pickup.status} (DELAYED)"
                else:
                    status_str = f"{pickup.status} ({remaining})"
            else:
                status_str = pickup.status
            gate_line = f"{pickup.display_name}: {status_str}"
            gate_status_surface = medium_font.render(gate_line, True, BLACK)
            screen.blit(gate_status_surface, (gate_current_x + 10, gate_current_y))
            status_color = reservation_colors.get(pickup.reservation, white_color) if pickup.reservation else white_color
            pygame.draw.circle(screen, status_color, (gate_current_x, gate_current_y + gate_status_surface.get_height() // 2), 5)
            gate_current_x += 10 + gate_status_surface.get_width() + 40
            gate_col_count += 1
            if gate_col_count >= gates_per_line:
                gate_current_y += gate_status_surface.get_height() + 5
                gate_current_x = gate_start_x
                gate_col_count = 0
                gate_line_count += 1
            if gate_line_count >= 6:
                break
        if gate_line_count >= 6:
            break

def show_completion_screen(screen, width, height, title_font, subtitle_font, info_font, small_font, flight_num, flight_time, return_on_key=True):
    completion_screen_time = 5  # seconds
    start_ticks = pygame.time.get_ticks()
    clock = pygame.time.Clock()
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)
    BLUE = (65, 105, 225)
    GRAY = (200, 200, 200)
    while (pygame.time.get_ticks() - start_ticks) < completion_screen_time * 1000:
        screen.fill(WHITE)
        title_text = title_font.render("Flight Processing Complete", True, BLACK)
        screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 100))
        flight_text = subtitle_font.render(f"Flight: {flight_num}", True, BLUE)
        screen.blit(flight_text, (width // 2 - flight_text.get_width() // 2, 160))
        stats_text = info_font.render("All bags claimed successfully", True, BLACK)
        screen.blit(stats_text, (width // 2 - stats_text.get_width() // 2, 220))
        time_text = info_font.render(f"Total processing time: {format_time(flight_time)}", True, BLACK)
        screen.blit(time_text, (width // 2 - time_text.get_width() // 2, 260))
        continue_text = small_font.render("Press any key to continue to next flight...", True, GRAY)
        screen.blit(continue_text, (width // 2 - continue_text.get_width() // 2, height - 100))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                return True
            elif event.type == pygame.KEYDOWN and return_on_key:
                return False
        pygame.display.update()
        clock.tick(30)
    return False

def show_waiting_screen(screen, width, height, title_font, subtitle_font, info_font, small_font, next_flight, wait_total=30):
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)
    BLUE = (65, 105, 225)
    GRAY = (200, 200, 200)
    clock = pygame.time.Clock()
    wait_start = pygame.time.get_ticks()
    waiting = True
    while waiting:
        current_time = pygame.time.get_ticks()
        elapsed = (current_time - wait_start) / 1000.0
        remaining = wait_total - elapsed
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                return True
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_SPACE:
                    waiting = False
        if remaining <= 0:
            break
        screen.fill(WHITE)
        title_text = title_font.render("Smart Luggage Handling System", True, BLACK)
        screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 20))
        next_text = subtitle_font.render(f"Next Flight: {next_flight}", True, BLUE)
        screen.blit(next_text, (width // 2 - next_text.get_width() // 2, height // 2 - 60))
        wait_msg = subtitle_font.render("Waiting between flights:", True, BLACK)
        screen.blit(wait_msg, (width // 2 - wait_msg.get_width() // 2, height // 2 - 20))
        time_remaining = info_font.render(f"Time remaining: {format_time(remaining)}", True, BLACK)
        screen.blit(time_remaining, (width // 2 - time_remaining.get_width() // 2, height // 2 + 20))
        skip_msg = info_font.render("Press SPACE to skip waiting time", True, GRAY)
        screen.blit(skip_msg, (width // 2 - skip_msg.get_width() // 2, height // 2 + 60))
        pygame.display.update()
        clock.tick(10)
    return False

def reset_flight_state():
    global update_log, claim_stats, gate_entries, delayed_reservations, delayed_count
    update_log.clear()
    claim_stats.clear()
    delayed_reservations.clear()
    delayed_count = 0
    
    # Reset all gate entries to ensure they don't carry over reservations
    for gate in gate_entries:
        for pickup in gate.gates:
            pickup.clear_luggage()
        gate.claim_times.clear()
        gate.reservation_bags.clear()

# ---------------- Main Simulation ----------------
########### add function for help
def is_gate_in_use(pickup, scanned_bags):
    for b in scanned_bags:
        if b.gate == pickup and not b.claimed:
            return True
    return False
def main():
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)
    BLUE = (65, 105, 225)
    GRAY = (200, 200, 200)
    try:
        filtered_df = load_data()
        print("Loaded the bags - handled by SLHS")
    except Exception as e:
        print(f"Error loading data: {e}")
        filtered_df = pd.DataFrame()
    flights_data = get_flights_data(filtered_df)
    flight_list = list(flights_data.items())
    print(f"Found {len(flight_list)} flights")
    pygame.init()
    width, height = 1400, 720
    screen = pygame.display.set_mode((width, height))
    pygame.display.set_caption("Smart Luggage Handling System")
    title_font = pygame.font.SysFont('Arial', 28, bold=True)
    subtitle_font = pygame.font.SysFont('Arial', 20)
    info_font = pygame.font.SysFont('Arial', 16)
    medium_font = pygame.font.SysFont('Arial', 14)
    small_font = pygame.font.SysFont('Arial', 12)
    clock = pygame.time.Clock()
    
    # Process flights one by one.
    for flight_idx, (flight_num, flight_data) in enumerate(flight_list):
        print(f"Processing flight {flight_num}")
        # Group rows by Reservation_ID; each row is one bag.
        reservations = flight_data.groupby('Reservation_ID')
        all_bags = []
        for reservation_id, res_data in reservations:
            num_bags = len(res_data)  # Total bags for this reservation.
            for _, row in res_data.iterrows():
                bag = Bag(
                    row['Bag_ID'],
                    row['Reservation_ID'],
                    row['Flight_Number'],
                    num_bags
                )
                all_bags.append(bag)
        random.shuffle(all_bags)
        conveyor_belt = all_bags
        scanned_bags = []
        i = 0
        #spawn_interval = int(500 / SIMULATION_SPEED) ###################################################
        #spawn_interval = int((3*(1100/170)) / SIMULATION_SPEED)*10 ###################################################
        spawn_interval = 300 # 0.3 seconds = 3 secondes times 10 
        last_spawn_time = pygame.time.get_ticks()
        flight_start_time = pygame.time.get_ticks()
        flight_complete = False
        
        while not flight_complete:
            screen.fill(WHITE)
            # Draw header and flight info.
            title_text = title_font.render("Smart Luggage Handling System", True, BLACK)
            screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 20))
            flight_text = subtitle_font.render(f"Flight: {flight_num}", True, BLUE)
            screen.blit(flight_text, (width // 2 - flight_text.get_width() // 2, 60))
            elapsed_seconds = (pygame.time.get_ticks() - flight_start_time) / 1000.0
            time_text = info_font.render(f"Elapsed Time: {format_time(elapsed_seconds)}", True, BLACK)
            screen.blit(time_text, (20, 20))
            
            # Draw conveyor belts and key points.
            for belt in conveyor_belts:
                pygame.draw.line(screen, BLACK, belt[0], belt[1], 3)
            for point in points:
                pygame.draw.circle(screen, BLACK, point, 5)
            
            # Draw gate entries and pickup gates.
            for gate in gate_entries:
                pygame.draw.rect(screen, BLACK, (gate.position[0] - 5, gate.position[1] - 5, 10, 10))
                for pickup in gate.gates:
                    if pickup.reservation is None:
                        pygame.draw.rect(screen, BLACK, (pickup.position[0] - 5, pickup.position[1] - 5, 10, 10))
                    else:
                        gate_color = reservation_colors.get(pickup.reservation, BLACK)
                        pygame.draw.circle(screen, gate_color, pickup.position, 5)
                    point_label = small_font.render(pickup.display_name, True, BLACK)
                    screen.blit(point_label, (pickup.position[0] - 12, pickup.position[1] - 20))
            
            help_text = small_font.render("Press ESC to exit | SPACE to skip wait time", True, GRAY)
            screen.blit(help_text, (width - 300, height - 20))
            
            draw_log_box(screen, medium_font)
            draw_gate_status_box(screen, medium_font, WHITE)
            
            # Event handling.
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    return
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_ESCAPE:
                        pygame.quit()
                        return
            
            current_time = pygame.time.get_ticks()
            for gate in gate_entries:
                gate.update_claim_status(current_time , scanned_bags)
                gate.check_complete_reservations(conveyor_belt)
            
            # Spawn new bags.
            if i < len(conveyor_belt) and current_time - last_spawn_time >= spawn_interval:
                bag = conveyor_belt[i]
                scanned_bags.append(bag)
                bag.set_ready()
                bag.spawn_time = current_time
                reservation_id = bag.reservation
                assigned_gate = False
                # First try to assign to a gate that already has this reservation.
                for gate in gate_entries:
                    for pickup in gate.gates:
                        if pickup.reservation == reservation_id and not is_gate_in_use(pickup, scanned_bags):
                            bag.set_path(paths[gate.name])
                            bag.append_path(pickup.position)
                            bag.set_gate(pickup)
                            bag.assigned_to_gate = True
                            assigned_gate = True
                            if reservation_id not in gate.reservation_bags:
                                gate.reservation_bags[reservation_id] = []
                            gate.reservation_bags[reservation_id].append(bag)
                            break
                    if assigned_gate:
                        break

                # ✅ PREVENT GATE REASSIGNMENT FOR ALREADY-ASSIGNED BAGS
                if bag.assigned_to_gate:
                   i += 1
                   last_spawn_time = current_time
                   continue
                # Otherwise, assign to a free gate.
                if not assigned_gate:
                 # Count how many bags with this reservation are left to be processed
                    remaining_bags_with_id = 1
                    for remaining_bag in conveyor_belt[i+1:]:
                        if remaining_bag.reservation == reservation_id:
                           remaining_bags_with_id += 1

                    expected_bags = expected_bags_for_reservation(bag.reservation, bag.num_bags_in_res)

                    if remaining_bags_with_id >= expected_bags - 1 or expected_bags == 1 or i < 20:
                        for gate in gate_entries:
                            idx = gate.search(bag)
                            if idx != -1:
                               pickup = gate.gates[idx]

                               # ✅ NEW: Check if the gate is still in use
                               if is_gate_in_use(pickup, scanned_bags):
                                  continue  # Skip this gate

                               # ✅ Reserve and assign as usual
                               pickup.set_reservation(bag.reservation, expected_bags)
                               pickup.claim_wait_time = random.randint(10000, 70000)
                               bag.set_path(paths[gate.name])
                               bag.append_path(pickup.position)
                               bag.set_gate(pickup)
                               bag.assigned_to_gate = True
                               if reservation_id not in gate.reservation_bags:
                                  gate.reservation_bags[reservation_id] = []
                               gate.reservation_bags[reservation_id].append(bag)
                               break
                else:
        # Not enough bags left – fallback
                      bag.set_path(paths_2[terminal_priority[0]])
                      print(f"[DEBUG] Not enough bags left for reservation {reservation_id}, not reserving a gate")

                if not bag.assigned_to_gate:
                    bag.set_path(paths_2[terminal_priority[0]])
             #if not assigned_gate:
                    # Count how many bags with this reservation are left to be processed
                   # remaining_bags_with_id = 1  # Start with 1 for the current bag
                   # for remaining_bag in conveyor_belt[i+1:]:  # Skip the current bag
                     #   if remaining_bag.reservation == reservation_id:
                     #       remaining_bags_with_id += 1
                    
                    # Get the expected bags from the reservation ID
                  #  expected_bags = expected_bags_for_reservation(bag.reservation, bag.num_bags_in_res)'''
                    
                    # Reserve a gate if:
                    # 1. There are enough bags left to fulfill the expected count, or
                    # 2. This is a single bag reservation, or
                    # 3. We're at the start of the simulation (i < 20) - this ensures gates get reserved at the beginning
                    # Restoring the i < 20 condition to ensure better gate distribution
                  # if remaining_bags_with_id >= expected_bags - 1 or expected_bags == 1 or i < 20:
                       # for gate in gate_entries:
                         #   idx = gate.search(bag)
                         #   if idx != -1:
                         #       gate.gates[idx].set_reservation(bag.reservation, expected_bags)
                          #      gate.gates[idx].claim_wait_time = random.randint(10000, 70000)  # NEW: Add this line
                          #      bag.set_path(paths[gate.name])
                          #      bag.append_path(gate.gates[idx].position)
                           #     bag.set_gate(gate.gates[idx])
                           #     bag.assigned_to_gate = True
                            #    if reservation_id not in gate.reservation_bags:
                             #       gate.reservation_bags[reservation_id] = []
                             #   gate.reservation_bags[reservation_id].append(bag)
                             #   break
                    # If not enough bags left, don't reserve a gate
                  #  else:
                   #     bag.set_path(paths_2[terminal_priority[0]])
                   #     print(f"[DEBUG] Not enough bags left for reservation {reservation_id}, not reserving a gate")
                  #  if not bag.assigned_to_gate:
                      #  bag.set_path(paths_2[terminal_priority[0]])
          
                i += 1
                last_spawn_time = current_time
            
            # Move and draw bags.
            still_moving = False
            for bag in scanned_bags:
                if not bag.claimed:
                    if bag.assigned_to_gate and bag.has_reached_gate():
                        for gate in gate_entries:
                            if gate.name == bag.gate.parent_gate:
                                gate.gates[gate.gates.index(bag.gate)].add_luggage(bag)
                                break
                        pygame.draw.circle(screen, bag.color, bag.position, 8)
                    else:
                        bag.move()
                        pygame.draw.circle(screen, bag.color, bag.position, 8)
                        still_moving = True
                else:
                    pygame.draw.rect(screen, BLACK, (bag.position[0] - 5, bag.position[1] - 5, 10, 10))
            
            pygame.display.update()
            clock.tick(60)
            
            # Check for gates with reservations that won't receive enough bags
            if i >= len(conveyor_belt) - 5:  # When we're near the end of the conveyor belt
                # Count remaining bags by reservation
                remaining_bags_by_reservation = {}
                for remaining_bag in conveyor_belt[i:]:
                    if remaining_bag.reservation not in remaining_bags_by_reservation:
                        remaining_bags_by_reservation[remaining_bag.reservation] = 0
                    remaining_bags_by_reservation[remaining_bag.reservation] += 1
                
                # Check each gate for unfulfillable reservations
                for gate in gate_entries:
                    for pickup in gate.gates:
                        if pickup.reservation and pickup.reservation not in gate.claim_times:
                            # If this gate has a reservation but not enough bags left to fulfill it
                            remaining = remaining_bags_by_reservation.get(pickup.reservation, 0)
                            needed = pickup.expected_bags - pickup.load
                            if needed == 0 and pickup.reservation not in gate.claim_times:
                               if not hasattr(pickup, "claim_wait_time"):
                                  pickup.claim_wait_time = random.randint(10000, 70000)  # Ensure it’s set
                               gate.claim_times[pickup.reservation] = current_time
                               wait_sec = pickup.claim_wait_time // 1000
                               msg = f"Starting claim timer ({wait_sec}s) for reservation {pickup.reservation} at Gate {gate_names.get(gate.name, gate.name)}{pickup.name}"
                               add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))
                        """    if needed == 0 and pickup.reservation not in gate.claim_times:
                                gate.claim_times[pickup.reservation] = current_time
                                msg = f"Starting 20s claim timer for reservation {pickup.reservation} at Gate {gate_names.get(gate.name, gate.name)}{pickup.name}"
                                add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))"""
                                ####################################################################################################
                            #if needed > 0 and remaining < needed:
                              #  print(f"[DEBUG] Gate {pickup.display_name} has reservation {pickup.reservation} but only {remaining} bags left (needs {needed} more)")
                                
                                # If there are some bags in the gate, start the claim timer
                               # if pickup.load > 0:
                                 #   print(f"[DEBUG] Starting claim timer for partially filled gate {pickup.display_name}")
                                  #  gate.claim_times[pickup.reservation] = current_time
                                  #  msg = f"Starting 20s claim timer for reservation {pickup.reservation} (partial: {pickup.load}/{pickup.expected_bags}) at Gate {gate_names.get(gate.name, gate.name)}{pickup.name}"
                                  #  add_update_message(msg, reservation_colors.get(pickup.reservation, (0, 0, 0)))
                        
                                # We're no longer releasing empty gates to maintain better distribution
                                # This ensures gates stay reserved even if they might not get all expected bags
            
            # Check if flight is complete.
            # Only complete if:
            # 1. All bags have been processed
            # 2. No bags are still moving
            # 3. No active reservations in any gate's claim_times (especially delayed ones)
            
            active_reservations = False
            for gate in gate_entries:
                if gate.claim_times:  # If any gate has active claim timers
                    active_reservations = True
                    break
            
            if i >= len(conveyor_belt) and not flight_complete and not still_moving and not active_reservations:
                flight_complete = True
                print("[DEBUG] Flight complete - all bags processed and all reservations claimed")
            elif i >= len(conveyor_belt) and not still_moving and active_reservations:
                # All bags processed but still waiting for reservations to be claimed
                waiting_for = []
                for gate in gate_entries:
                    for res_id in gate.claim_times:
                        delay_status = "delayed" if res_id in delayed_reservations else "normal"
                        waiting_for.append(f"{res_id} ({delay_status})")
                
                if waiting_for:
                    print(f"[DEBUG] Waiting for reservations to be claimed: {', '.join(waiting_for)}")
        
        flight_time = (pygame.time.get_ticks() - flight_start_time) / 1000.0
        show_completion_screen(screen, width, height, title_font, subtitle_font, info_font, small_font, flight_num, flight_time, return_on_key=False)
        if flight_idx < len(flight_list) - 1:
            next_flight = flight_list[flight_idx + 1][0]
            show_waiting_screen(screen, width, height, title_font, subtitle_font, info_font, small_font, next_flight, wait_total=0)
            reset_flight_state()
    pygame.quit()

if __name__ == "__main__":
    main()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Loaded the bags - handled by SLHS
# Found 3 flights
# Processing flight EK6483
# [DEBUG] Gate 2A reserved for reservation res-0002907 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000118 with reservation res-0002907 assigned to gate 2A
# [DEBUG] Gate 2B reserved for reservation res-0000103 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000015 with reservation res-0000103 assigned to gate 2B
# [DEBUG] Gate 2C reserved for reservation res-0004804 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000199 with reservation res-0004804 assigned to gate 2C
# [DEBUG] Bag 176-EK6483-000118 added to gate 2A (1/7)
# [DEBUG] Gate 3A reserved for reservation res-0006307 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000277 with reservation res-0006307 assigned to gate 3A
# [DEBUG] Bag 176-EK6483-000015 added to gate 2B (1/3)
# [DEBUG] Gate 3B reserved for reservation res-0007407 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000335 with reservation res-0007407 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000199 added to gate 2C (1/4)
# [DEBUG] Gate 3C reserved for reservation res-0000407 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000017 with reservation res-0000407 assigned to gate 3C
# [DEBUG] Gate 4A reserved for reservation res-0006006 (expecting 6 bags)
# [DEBUG] Bag 176-EK6483-000259 with reservation res-0006006 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000277 added to gate 3A (1/7)
# [DEBUG] Gate 4B reserved for reservation res-0008302 (expecting 2 bags)
# [DEBUG] Bag 176-EK6483-000376 with reservation res-0008302 assigned to gate 4B
# [DEBUG] Bag 176-EK6483-000335 added to gate 3B (1/7)
# [DEBUG] Gate 4C reserved for reservation res-0000607 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000025 with reservation res-0000607 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000017 added to gate 3C (1/7)
# [DEBUG] Gate 5A reserved for reservation res-0007605 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000342 with reservation res-0007605 assigned to gate 5A
# [DEBUG] Gate 5B reserved for reservation res-0002107 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000095 with reservation res-0002107 assigned to gate 5B
# [DEBUG] Gate 5C reserved for reservation res-0001204 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000050 with reservation res-0001204 assigned to gate 5C
# [DEBUG] Bag 176-EK6483-000259 added to gate 4A (1/6)
# [DEBUG] Gate 6A reserved for reservation res-0004305 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000182 with reservation res-0004305 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000376 added to gate 4B (1/2)
# [DEBUG] Gate 6B reserved for reservation res-0003305 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000137 with reservation res-0003305 assigned to gate 6B
# [DEBUG] Bag 176-EK6483-000025 added to gate 4C (1/7)
# [DEBUG] Gate 6C reserved for reservation res-0000705 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000030 with reservation res-0000705 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000342 added to gate 5A (1/5)
# [DEBUG] Gate 7A reserved for reservation res-0002907 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000132 with reservation res-0002907 assigned to gate 7A
# [DEBUG] Bag 176-EK6483-000095 added to gate 5B (1/7)
# [DEBUG] Gate 7B reserved for reservation res-0006307 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000278 with reservation res-0006307 assigned to gate 7B
# [DEBUG] Bag 176-EK6483-000050 added to gate 5C (1/4)
# [DEBUG] Gate 7C reserved for reservation res-0005702 (expecting 2 bags)
# [DEBUG] Bag 176-EK6483-000244 with reservation res-0005702 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000182 added to gate 6A (1/5)
# [DEBUG] Bag 176-EK6483-000137 added to gate 6B (1/5)
# [DEBUG] Bag 176-EK6483-000030 added to gate 6C (1/5)
# [DEBUG] Bag 176-EK6483-000132 added to gate 7A (1/7)
# [DEBUG] Bag 176-EK6483-000278 added to gate 7B (1/7)
# [DEBUG] Bag 176-EK6483-000244 added to gate 7C (1/2)
# [DEBUG] Bag 176-EK6483-000243 with reservation res-0005702 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-
assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000274 with reservation res-0006307 assigned to gate 3A
# [DEBUG] Bag 176-EK6483-000140 added to gate 6B (5/5)
# [DEBUG] Gate 6B is now full with 5 bags
# [DEBUG] Reservation res-0003305 will have normal delay of 68 seconds
# [LOG] Starting 68s claim timer for reservation res-0003305 at Gate 6B
# [DEBUG] Bag 176-EK6483-000096 added to gate 5B (6/7)
# [DEBUG] Bag 176-EK6483-000012 added to gate 3C (6/7)
# [DEBUG] Bag 176-EK6483-000274 added to gate 3A (5/7)
# [DEBUG] Bag 176-EK6483-000013 with reservation res-0000407 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000031 with reservation res-0000705 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000331 with reservation res-0007407 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000375 with reservation res-0008302 assigned to gate 4B
# [DEBUG] Bag 176-EK6483-000013 added to gate 3C (7/7)
# [DEBUG] Gate 3C is now full with 7 bags
# [DEBUG] Reservation res-0000407 will have normal delay of 16 seconds
# [LOG] Starting 16s claim timer for reservation res-0000407 at Gate 3C
# [DEBUG] Bag 176-EK6483-000331 added to gate 3B (5/7)
# [DEBUG] Bag 176-EK6483-000031 added to gate 6C (4/5)
# [DEBUG] Bag 176-EK6483-000375 added to gate 4B (2/2)
# [DEBUG] Gate 4B is now full with 2 bags
# [DEBUG] Reservation res-0008302 will have normal delay of 55 seconds
# [LOG] Starting 55s claim timer for reservation res-0008302 at Gate 4B
# [DEBUG] Bag 176-EK6483-000275 with reservation res-0006307 assigned to gate 3A
# [DEBUG] Bag 176-EK6483-000275 added to gate 3A (6/7)
# [DEBUG] Bag 176-EK6483-000002 with reservation res-0000103 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000002 added to gate 2B (3/3)
# [DEBUG] Gate 2B is now full with 3 bags
# [DEBUG] Reservation res-0000103 will have normal delay of 31 seconds
# [LOG] Starting 31s claim timer for reservation res-0000103 at Gate 2B
# [DEBUG] Bag 176-EK6483-000197 with reservation res-0004804 assigned to gate 2C
# [DEBUG] Bag 176-EK6483-000197 added to gate 2C (2/4)
# [DEBUG] Bag 176-EK6483-000336 with reservation res-0007407 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000196 with reservation res-0004804 assigned to gate 2C
# [DEBUG] Bag 176-EK6483-000336 added to gate 3B (6/7)
# [DEBUG] Bag 176-EK6483-000339 with reservation res-0007605 assigned to gate 5A
# [DEBUG] Bag 176-EK6483-000196 added to gate 2C (3/4)
# [DEBUG] Bag 176-EK6483-000028 with reservation res-0000705 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000339 added to gate 5A (4/5)
# [DEBUG] Bag 176-EK6483-000051 with reservation res-0001204 assigned to gate 5C
# [DEBUG] Bag 176-EK6483-000198 with reservation res-0004804 assigned to gate 2C
# [DEBUG] Bag 176-EK6483-000028 added to gate 6C (5/5)
# [DEBUG] Gate 6C is now full with 5 bags
# [DEBUG] Bag 176-EK6483-000198 added to gate 2C (4/4)
# [DEBUG] Gate 2C is now full with 4 bags
# [DEBUG] Reservation res-0004804 will have normal delay of 62 seconds
# [LOG] Starting 62s claim timer for reservation res-0004804 at Gate 2C
# [DEBUG] Reservation res-0000705 will have normal delay of 13 seconds
# [LOG] Starting 13s claim timer for reservation res-0000705 at Gate 6C
# [DEBUG] Bag 176-EK6483-000051 added to gate 5C (4/4)
# [DEBUG] Gate 5C is now full with 4 bags
# [DEBUG] Reservation res-0001204 will have normal delay of 69 seconds
# [LOG] Starting 69s claim timer for reservation res-0001204 at Gate 5C
# [DEBUG] Bag 176-EK6483-000231 with reservation res-0005506 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000160 with reservation res-0004305 assigned to gate 6A
# [LOG] Reservation res-0000407 claimed from Gate 3C in 01:38
# [DEBUG] Gate 3C cleared (no moving bags)
# [DEBUG] Gate 3C reserved for reservation res-0007002 (expecting 2 bags)
# [DEBUG] Bag 176-EK6483-000310 with reservation res-0007002 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000231 added to gate 7C (6/6)
# [DEBUG] Gate 7C is now full with 6 bags
# [DEBUG] Reservation res-0005506 will have normal delay of 25 seconds
# [LOG] Starting 25s claim timer for reservation res-0005506 at Gate 7C
# [DEBUG] Bag 176-EK6483-000309 with reservation res-0007002 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000320 with reservation res-0007407 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000160 added to gate 6A (5/5)
# [DEBUG] Gate 6A is now full with 5 bags
# [DEBUG] Reservation res-0004305 will have normal delay of 24 seconds
# [LOG] Starting 24s claim timer for reservation res-0004305 at Gate 6A
# [DEBUG] Bag 176-EK6483-000059 with reservation res-0000607 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000309 added to gate 3C (1/2)
# [DEBUG] Bag 176-EK6483-000320 added to gate 3B (7/7)
# [DEBUG] Gate 3B is now full with 7 bags
# [DEBUG] Reservation res-0007407 will have normal delay of 45 seconds
# [LOG] Starting 45s claim timer for reservation res-0007407 at Gate 3B
# [DEBUG] Bag 176-EK6483-000310 added to gate 3C (2/2)
# [DEBUG] Gate 3C is now full with 2 bags
# [DEBUG] Reservation res-0007002 will have normal delay of 67 seconds
# [LOG] Starting 67s claim timer for reservation res-0007002 at Gate 3C
# [DEBUG] Bag 176-EK6483-000119 with reservation res-0002907 assigned to gate 2A
# [DEBUG] Bag 176-EK6483-000059 added to gate 4C (7/7)
# [DEBUG] Gate 4C is now full with 7 bags
# [LOG] Starting claim timer (43s) for reservation res-0000607 at Gate 4C
# [DEBUG] Bag 176-EK6483-000119 added to gate 2A (6/7)
# [DEBUG] Bag 176-EK6483-000097 with reservation res-0002107 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000341 with reservation res-0007605 assigned to gate 5A
# [DEBUG] Bag 176-EK6483-000097 added to gate 5B (7/7)
# [DEBUG] Gate 5B is now full with 7 bags
# [LOG] Starting claim timer (69s) for reservation res-0002107 at Gate 5B
# [DEBUG] Bag 176-EK6483-000341 added to gate 5A (5/5)
# [DEBUG] Gate 5A is now full with 5 bags
# [LOG] Starting claim timer (65s) for reservation res-0007605 at Gate 5A
# [LOG] Reservation res-0000705 claimed from Gate 6C in 01:44
# [DEBUG] Gate 6C cleared (no moving bags)
# [DEBUG] Gate 6C reserved for reservation res-0000505 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000021 with reservation res-0000505 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000020 with reservation res-0000505 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000018 with reservation res-0000505 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000021 added to gate 6C (1/5)
# [DEBUG] Bag 176-EK6483-000056 with reservation res-0000505 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000020 added to gate 6C (2/5)
# [DEBUG] Bag 176-EK6483-000019 with reservation res-0000505 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000018 added to gate 6C (3/5)
# [DEBUG] Bag 176-EK6483-000056 added to gate 6C (4/5)
# [DEBUG] Bag 176-EK6483-000019 added to gate 6C (5/5)
# [DEBUG] Gate 6C is now full with 5 bags
# [LOG] Starting claim timer (13s) for reservation res-0000505 at Gate 6C
# [LOG] Reservation res-0000103 claimed from Gate 2B in 02:01
# [DEBUG] Gate 2B cleared (no moving bags)
# [DEBUG] Gate 2B reserved for reservation res-0007303 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000328 with reservation res-0007303 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000329 with reservation res-0007303 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000328 added to gate 2B (1/3)
# [DEBUG] Bag 176-EK6483-000329 added to gate 2B (2/3)
# [DEBUG] Bag 176-EK6483-000317 with reservation res-0007303 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000317 added to gate 2B (3/3)
# [DEBUG] Gate 2B is now full with 3 bags
# [LOG] Starting claim timer (31s) for reservation res-0007303 at Gate 2B
# [LOG] Reservation res-0006006 claimed from Gate 4A in 02:03
# [DEBUG] Gate 4A cleared (no moving bags)
# [DEBUG] Gate 4A reserved for reservation res-0005005 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000207 with reservation res-0005005 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000206 with reservation res-0005005 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000212 with reservation res-0005005 assigned to gate 4A
# [LOG] Reservation res-0005506 claimed from Gate 7C in 01:36
# [DEBUG] Gate 7C cleared (no moving bags)
# [DEBUG] Gate 7C reserved for reservation res-0007107 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000314 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000313 with reservation res-0007107 assigned to gate 7C
# [LOG] Reservation res-0004305 claimed from Gate 6A in 02:02
# [DEBUG] Gate 6A cleared (no moving bags)
# [DEBUG] Gate 6A reserved for reservation res-0001307 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000054 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000311 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000061 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000315 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000058 with reservation res-0001307 assigned to gate 6A
# [LOG] Reservation res-0000505 claimed from Gate 6C in 01:53
# [DEBUG] Gate 6C cleared (no moving bags)
# [DEBUG] Gate 6C reserved for reservation res-0003004 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000125 with reservation res-0003004 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000319 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000207 added to gate 4A (1/5)
# [DEBUG] Bag 176-EK6483-000205 with reservation res-0005005 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000206 added to gate 4A (2/5)
# [DEBUG] Bag 176-EK6483-000212 added to gate 4A (3/5)
# [DEBUG] Bag 176-EK6483-000318 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000124 with reservation res-0003004 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000057 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000083 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000312 with reservation res-0007107 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000204 with reservation res-0005005 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000314 added to gate 7C (1/7)
# [DEBUG] Bag 176-EK6483-000054 added to gate 6A (1/7)
# [DEBUG] Bag 176-EK6483-000123 with reservation res-0003004 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000313 added to gate 7C (2/7)
# [DEBUG] Bag 176-EK6483-000060 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000053 with reservation res-0001307 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000126 with reservation res-0003004 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000205 added to gate 4A (4/5)
# [DEBUG] Bag 176-EK6483-000311 added to gate 7C (3/7)
# [DEBUG] Bag 176-EK6483-000061 added to gate 6A (2/7)
# [DEBUG] Bag 176-EK6483-000058 added to gate 6A (3/7)
# [DEBUG] Bag 176-EK6483-000125 added to gate 6C (1/4)
# [DEBUG] Bag 176-EK6483-000315 added to gate 7C (4/7)
# [DEBUG] Bag 176-EK6483-000319 added to gate 7C (5/7)
# [DEBUG] Bag 176-EK6483-000204 added to gate 4A (5/5)
# [DEBUG] Gate 4A is now full with 5 bags
# [LOG] Starting claim timer (59s) for reservation res-0005005 at Gate 4A
# [DEBUG] Bag 176-EK6483-000124 added to gate 6C (2/4)
# [DEBUG] Bag 176-EK6483-000318 added to gate 7C (6/7)
# [DEBUG] Bag 176-EK6483-000057 added to gate 6A (4/7)
# [DEBUG] Bag 176-EK6483-000083 added to gate 6A (5/7)
# [DEBUG] Bag 176-EK6483-000312 added to gate 7C (7/7)
# [DEBUG] Gate 7C is now full with 7 bags
# [LOG] Starting claim timer (25s) for reservation res-0007107 at Gate 7C
# [DEBUG] Bag 176-EK6483-000123 added to gate 6C (3/4)
# [DEBUG] Bag 176-EK6483-000060 added to gate 6A (6/7)
# [DEBUG] Bag 176-EK6483-000053 added to gate 6A (7/7)
# [DEBUG] Gate 6A is now full with 7 bags
# [LOG] Starting claim timer (24s) for reservation res-0001307 at Gate 6A
# [DEBUG] Bag 176-EK6483-000126 added to gate 6C (4/4)
# [DEBUG] Gate 6C is now full with 4 bags
# [LOG] Starting claim timer (13s) for reservation res-0003004 at Gate 6C
# [LOG] Reservation res-0008302 claimed from Gate 4B in 02:18
# [DEBUG] Gate 4B cleared (no moving bags)
# [DEBUG] Gate 4B reserved for reservation res-0009603 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000438 with reservation res-0009603 assigned to gate 4B
# [DEBUG] Bag 176-EK6483-000437 with reservation res-0009603 assigned to gate 4B
# [DEBUG] Bag 176-EK6483-000378 with reservation res-0009603 assigned to gate 4B
# [DEBUG] Bag 176-EK6483-000438 added to gate 4B (1/3)
# [DEBUG] Bag 176-EK6483-000437 added to gate 4B (2/3)
# [DEBUG] Bag 176-EK6483-000378 added to gate 4B (3/3)
# [DEBUG] Gate 4B is now full with 3 bags
# [LOG] Starting claim timer (55s) for reservation res-0009603 at Gate 4B
# [LOG] Reservation res-0003004 claimed from Gate 6C in 02:05
# [DEBUG] Gate 6C cleared (no moving bags)
# [DEBUG] Gate 6C reserved for reservation res-0005606 (expecting 6 bags)
# [DEBUG] Bag 176-EK6483-000239 with reservation res-0005606 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000241 with reservation res-0005606 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000236 with reservation res-0005606 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000240 with reservation res-0005606 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000237 with reservation res-0005606 assigned to gate 6C
# [LOG] Reservation res-0000607 claimed from Gate 4C in 02:23
# [DEBUG] Gate 4C cleared (no moving bags)
# [DEBUG] Gate 4C reserved for reservation res-0005306 (expecting 6 bags)
# [DEBUG] Bag 176-EK6483-000222 with reservation res-0005306 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000239 added to gate 6C (1/6)
# [DEBUG] Bag 176-EK6483-000242 with reservation res-0005606 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000221 with reservation res-0005306 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000241 added to gate 6C (2/6)
# [DEBUG] Bag 176-EK6483-000223 with reservation res-0005306 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000236 added to gate 6C (3/6)
# [DEBUG] Bag 176-EK6483-000240 added to gate 6C (4/6)
# [DEBUG] Bag 176-EK6483-000224 with reservation res-0005306 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000237 added to gate 6C (5/6)
# [DEBUG] Bag 176-EK6483-000227 with reservation res-0005306 assigned to gate 4C
# [LOG] Reservation res-0007407 claimed from Gate 3B in 02:25
# [DEBUG] Gate 3B cleared (no moving bags)
# [DEBUG] Gate 3B reserved for reservation res-0006207 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000271 with reservation res-0006207 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000269 with reservation res-0006207 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000226 with reservation res-0005306 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-
(expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000192 with reservation res-0004603 assigned to gate 5C
# [DEBUG] Bag 176-EK6483-000193 with reservation res-0004603 assigned to gate 5C
# [DEBUG] Bag 176-EK6483-000192 added to gate 5C (1/3)
# [DEBUG] Bag 176-EK6483-000187 with reservation res-0004603 assigned to gate 5C
# [DEBUG] Bag 176-EK6483-000193 added to gate 5C (2/3)
# [DEBUG] Bag 176-EK6483-000187 added to gate 5C (3/3)
# [DEBUG] Gate 5C is now full with 3 bags
# [LOG] Starting claim timer (69s) for reservation res-0004603 at Gate 5C
# [LOG] Reservation res-0007002 claimed from Gate 3C in 01:54
# [DEBUG] Gate 3C cleared (no moving bags)
# [DEBUG] Gate 3C reserved for reservation res-0005805 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000247 with reservation res-0005805 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000245 with reservation res-0005805 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000251 with reservation res-0005805 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000247 added to gate 3C (1/5)
# [DEBUG] Bag 176-EK6483-000245 added to gate 3C (2/5)
# [DEBUG] Bag 176-EK6483-000250 with reservation res-0005805 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000251 added to gate 3C (3/5)
# [DEBUG] Bag 176-EK6483-000248 with reservation res-0005805 assigned to gate 3C
# [DEBUG] Bag 176-EK6483-000250 added to gate 3C (4/5)
# [LOG] Reservation res-0007605 claimed from Gate 5A in 02:49
# [DEBUG] Gate 5A cleared (no moving bags)
# [DEBUG] Gate 5A reserved for reservation res-0004703 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000200 with reservation res-0004703 assigned to gate 5A
# [DEBUG] Bag 176-EK6483-000248 added to gate 3C (5/5)
# [DEBUG] Gate 3C is now full with 5 bags
# [LOG] Starting claim timer (67s) for reservation res-0005805 at Gate 3C
# [DEBUG] Bag 176-EK6483-000194 with reservation res-0004703 assigned to gate 5A
# [DEBUG] Bag 176-EK6483-000200 added to gate 5A (1/3)
# [DEBUG] Bag 176-EK6483-000195 with reservation res-0004703 assigned to gate 5A
# [LOG] Reservation res-0002107 claimed from Gate 5B in 02:52
# [DEBUG] Gate 5B cleared (no moving bags)
# [DEBUG] Gate 5B reserved for reservation res-0009707 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000398 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000387 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000194 added to gate 5A (2/3)
# [DEBUG] Bag 176-EK6483-000404 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000195 added to gate 5A (3/3)
# [DEBUG] Gate 5A is now full with 3 bags
# [LOG] Starting claim timer (65s) for reservation res-0004703 at Gate 5A
# [DEBUG] Bag 176-EK6483-000421 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000399 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000398 added to gate 5B (1/7)
# [DEBUG] Bag 176-EK6483-000387 added to gate 5B (2/7)
# [DEBUG] Bag 176-EK6483-000404 added to gate 5B (3/7)
# [DEBUG] Bag 176-EK6483-000392 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000395 with reservation res-0009707 assigned to gate 5B
# [DEBUG] Bag 176-EK6483-000421 added to gate 5B (4/7)
# [DEBUG] Bag 176-EK6483-000399 added to gate 5B (5/7)
# [LOG] Reservation res-0008207 claimed from Gate 6C in 02:27
# [DEBUG] Gate 6C cleared (no moving bags)
# [DEBUG] Gate 6C reserved for reservation res-0007703 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000344 with reservation res-0007703 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000392 added to gate 5B (6/7)
# [DEBUG] Bag 176-EK6483-000395 added to gate 5B (7/7)
# [DEBUG] Gate 5B is now full with 7 bags
# [LOG] Starting claim timer (69s) for reservation res-0009707 at Gate 5B
# [DEBUG] Bag 176-EK6483-000343 with reservation res-0007703 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000334 with reservation res-0007703 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000344 added to gate 6C (1/3)
# [DEBUG] Bag 176-EK6483-000343 added to gate 6C (2/3)
# [DEBUG] Bag 176-EK6483-000334 added to gate 6C (3/3)
# [DEBUG] Gate 6C is now full with 3 bags
# [LOG] Starting claim timer (13s) for reservation res-0007703 at Gate 6C
# [LOG] Reservation res-0000905 claimed from Gate 6A in 02:33
# [DEBUG] Gate 6A cleared (no moving bags)
# [DEBUG] Gate 6A reserved for reservation res-0001104 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000045 with reservation res-0001104 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000047 with reservation res-0001104 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000046 with reservation res-0001104 assigned to gate 6A
# [DEBUG] Bag 176-EK6483-000048 with reservation res-0001104 assigned to gate 6A
# [LOG] Reservation res-0009106 claimed from Gate 7C in 02:22
# [DEBUG] Gate 7C cleared (no moving bags)
# [DEBUG] Gate 7C reserved for reservation res-0008806 (expecting 6 bags)
# [DEBUG] Bag 176-EK6483-000400 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000403 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000402 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000045 added to gate 6A (1/4)
# [DEBUG] Bag 176-EK6483-000047 added to gate 6A (2/4)
# [DEBUG] Bag 176-EK6483-000046 added to gate 6A (3/4)
# [DEBUG] Bag 176-EK6483-000048 added to gate 6A (4/4)
# [DEBUG] Gate 6A is now full with 4 bags
# [LOG] Starting claim timer (24s) for reservation res-0001104 at Gate 6A
# [DEBUG] Bag 176-EK6483-000401 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000396 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000397 with reservation res-0008806 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000400 added to gate 7C (1/6)
# [LOG] Reservation res-0008403 claimed from Gate 2B in 01:54
# [DEBUG] Gate 2B cleared (no moving bags)
# [DEBUG] Gate 2B reserved for reservation res-0003506 (expecting 6 bags)
# [DEBUG] Bag 176-EK6483-000155 with reservation res-0003506 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000403 added to gate 7C (2/6)
# [DEBUG] Bag 176-EK6483-000402 added to gate 7C (3/6)
# [DEBUG] Bag 176-EK6483-000154 with reservation res-0003506 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000155 added to gate 2B (1/6)
# [DEBUG] Bag 176-EK6483-000154 added to gate 2B (2/6)
# [DEBUG] Bag 176-EK6483-000149 with reservation res-0003506 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000401 added to gate 7C (4/6)
# [DEBUG] Bag 176-EK6483-000396 added to gate 7C (5/6)
# [DEBUG] Bag 176-EK6483-000152 with reservation res-0003506 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000148 with reservation res-0003506 assigned to gate 2B
# [LOG] Reservation res-0005005 claimed from Gate 4A in 02:44
# [DEBUG] Gate 4A cleared (no moving bags)
# [DEBUG] Gate 4A reserved for reservation res-0003103 (expecting 3 bags)
# [DEBUG] Bag 176-EK6483-000141 with reservation res-0003103 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000397 added to gate 7C (6/6)
# [DEBUG] Gate 7C is now full with 6 bags
# [LOG] Starting claim timer (25s) for reservation res-0008806 at Gate 7C
# [DEBUG] Bag 176-EK6483-000149 added to gate 2B (3/6)
# [DEBUG] Bag 176-EK6483-000153 with reservation res-0003506 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000152 added to gate 2B (4/6)
# [DEBUG] Bag 176-EK6483-000148 added to gate 2B (5/6)
# [DEBUG] Bag 176-EK6483-000127 with reservation res-0003103 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000153 added to gate 2B (6/6)
# [DEBUG] Gate 2B is now full with 6 bags
# [LOG] Starting claim timer (31s) for reservation res-0003506 at Gate 2B
# [DEBUG] Bag 176-EK6483-000141 added to gate 4A (1/3)
# [DEBUG] Bag 176-EK6483-000128 with reservation res-0003103 assigned to gate 4A
# [DEBUG] Bag 176-EK6483-000127 added to gate 4A (2/3)
# [LOG] Reservation res-0005306 claimed from Gate 4C in 02:53
# [DEBUG] Gate 4C cleared (no moving bags)
# [DEBUG] Gate 4C reserved for reservation res-0008007 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000354 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000355 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000357 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000128 added to gate 4A (3/3)
# [DEBUG] Gate 4A is now full with 3 bags
# [LOG] Starting claim timer (59s) for reservation res-0003103 at Gate 4A
# [DEBUG] Bag 176-EK6483-000352 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000360 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000354 added to gate 4C (1/7)
# [DEBUG] Bag 176-EK6483-000355 added to gate 4C (2/7)
# [DEBUG] Bag 176-EK6483-000357 added to gate 4C (3/7)
# [DEBUG] Bag 176-EK6483-000352 added to gate 4C (4/7)
# [DEBUG] Bag 176-EK6483-000360 added to gate 4C (5/7)
# [DEBUG] Bag 176-EK6483-000359 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000356 with reservation res-0008007 assigned to gate 4C
# [DEBUG] Bag 176-EK6483-000359 added to gate 4C (6/7)
# [DEBUG] Bag 176-EK6483-000356 added to gate 4C (7/7)
# [DEBUG] Gate 4C is now full with 7 bags
# [LOG] Starting claim timer (43s) for reservation res-0008007 at Gate 4C
# [LOG] Reservation res-0006207 claimed from Gate 3B in 03:02
# [DEBUG] Gate 3B cleared (no moving bags)
# [DEBUG] Gate 3B reserved for reservation res-0006907 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000302 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000301 with reservation res-0006907 assigned to gate 3B
# [LOG] Reservation res-0007703 claimed from Gate 6C in 03:05
# [DEBUG] Gate 6C cleared (no moving bags)
# [DEBUG] Gate 6C reserved for reservation res-0006607 (expecting 7 bags)
# [DEBUG] Bag 176-EK6483-000292 with reservation res-0006607 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000302 added to gate 3B (1/7)
# [DEBUG] Bag 176-EK6483-000301 added to gate 3B (2/7)
# [DEBUG] Bag 176-EK6483-000304 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000308 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000307 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000288 with reservation res-0006607 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000296 with reservation res-0006607 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000306 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000305 with reservation res-0006907 assigned to gate 3B
# [DEBUG] Bag 176-EK6483-000291 with reservation res-0006607 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-
assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000228 with reservation res-0005403 assigned to gate 6C
# [DEBUG] Bag 176-EK6483-000010 added to gate 6A (3/5)
# [DEBUG] Bag 176-EK6483-000007 added to gate 6A (4/5)
# [LOG] Reservation res-0008806 claimed from Gate 7C in 03:22
# [DEBUG] Gate 7C cleared (no moving bags)
# [DEBUG] Gate 7C reserved for reservation res-0002205 (expecting 5 bags)
# [DEBUG] Bag 176-EK6483-000098 with reservation res-0002205 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000101 with reservation res-0002205 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000032 added to gate 6A (5/5)
# [DEBUG] Gate 6A is now full with 5 bags
# [LOG] Starting claim timer (24s) for reservation res-0000305 at Gate 6A
# [DEBUG] Bag 176-EK6483-000100 with reservation res-0002205 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000229 added to gate 6C (1/3)
# [DEBUG] Bag 176-EK6483-000238 added to gate 6C (2/3)
# [DEBUG] Bag 176-EK6483-000228 added to gate 6C (3/3)
# [DEBUG] Gate 6C is now full with 3 bags
# [LOG] Starting claim timer (13s) for reservation res-0005403 at Gate 6C
# [DEBUG] Bag 176-EK6483-000091 with reservation res-0002205 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000099 with reservation res-0002205 assigned to gate 7C
# [DEBUG] Bag 176-EK6483-000098 added to gate 7C (1/5)
# [DEBUG] Bag 176-EK6483-000101 added to gate 7C (2/5)
# [DEBUG] Bag 176-EK6483-000100 added to gate 7C (3/5)
# [DEBUG] Bag 176-EK6483-000091 added to gate 7C (4/5)
# [DEBUG] Bag 176-EK6483-000099 added to gate 7C (5/5)
# [DEBUG] Gate 7C is now full with 5 bags
# [LOG] Starting claim timer (25s) for reservation res-0002205 at Gate 7C
# [LOG] Reservation res-0003506 claimed from Gate 2B in 03:05
# [DEBUG] Gate 2B cleared (no moving bags)
# [DEBUG] Gate 2B reserved for reservation res-0009304 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000428 with reservation res-0009304 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000431 with reservation res-0009304 assigned to gate 2B
# [DEBUG] Bag 176-EK6483-000428 added to gate 2B (1/4)
# [LOG] Reservation res-0008602 claimed from Gate 6B in 03:00
# [DEBUG] Gate 6B cleared (no moving bags)
# [DEBUG] Bag 176-EK6483-000431 added to gate 2B (2/4)
# [DEBUG] Gate 6B reserved for reservation res-0003904 (expecting 4 bags)
# [DEBUG] Bag 176-EK6483-000169 with reservation res-0003904 assigned to gate 6B
# ...
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [DEBUG] Waiting for reservations to be claimed: res-0002402 (normal)
# [LOG] Reservation res-0002402 claimed from Gate 5A in 05:44
# [DEBUG] Gate 5A cleared (no moving bags)
# [DEBUG] Flight complete - all bags processed and all reservations claimed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 997
#     994     pygame.quit()
#     996 if __name__ == "__main__":
# --> 997     main()
#
# Cell In[2], line 993, in main()
#     991         next_flight = flight_list[flight_idx + 1][0]
#     992         show_waiting_screen(screen, width, height, title_font, subtitle_font, info_font, small_font, next_flight, wait_total=0)
# --> 993         reset_flight_state()
#     994 pygame.quit()
#
# Cell In[2], line 682, in reset_flight_state()
#     680 for gate in gate_entries:
#     681     for pickup in gate.gates:
# --> 682         pickup.clear_luggage()
#     683     gate.claim_times.clear()
#     684     gate.reservation_bags.clear()
#
# TypeError: PickupGate.clear_luggage() missing 1 required positional argument: 'scanned_bags'
