# %%
import pygame
import random
import math
import time
import queue
import os
import boto3
import pandas as pd
from io import StringIO
from datetime import datetime, timedelta, date
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
'''# Create a session using your configured AWS credentials
s3 = boto3.client('s3')

# Upload a file to S3
bucket_name = "trackage.1"
file_name = "luggage_dataset5.csv" # Path to your local file
s3_object_name = "database.csv" # Name in S3

s3.upload_file(file_name, bucket_name, s3_object_name)

print(f"Uploaded {file_name} to S3 bucket {bucket_name} as {s3_object_name}")


# Download the file from S3
obj = s3.get_object(Bucket=bucket_name, Key=s3_object_name)
'''
# Read it as a Pandas DataFrame
df = pd.read_csv('/Users/layal/Desktop/B-350P-large.csv')
df = df[df['Cluster_Size'] != 1]
#df = df[df['Claim_Option'] == 'SLHS Electronic Gates']

SPEED = 100;

print(df.head()) # Show first 5 rows
'''
# Save the updated DataFrame to a temporary local file
temp_file = '/tmp/luggage_dataset5.csv' # Local path to save the modified file
df.to_csv(temp_file, index=False)

# Upload the updated file back to the same location on S3 (this will overwrite the file)
s3.upload_file(temp_file, bucket_name, s3_object_name)

print(f"File {s3_object_name} updated successfully in S3.")'''
# Out:
#               Bag_ID           Claim_Option  Handled_by_SLHS Reservation_ID  \
# 0  176-EK5713-000001  SLHS Electronic Gates             True      RES-00001
# 1  176-EK5713-000002  SLHS Electronic Gates             True      RES-00001
# 2  176-EK5713-000003  SLHS Electronic Gates             True      RES-00001
# 3  176-EK5713-000004  SLHS Electronic Gates             True      RES-00001
# 4  176-EK5713-000005  SLHS Electronic Gates             True      RES-00002
#
#    Phone_Number Last_Name  Password Flight_Number Flight_Arrival_Time  \
# 0   13095573652   Elliott  9r:/<t`K        EK5713               23:14
# 1   12745646875   Elliott  9r:/<t`K        EK5713               23:14
# 2   12745646875   Elliott  9r:/<t`K        EK5713               23:14
# 3   13095573652   Elliott  9r:/<t`K        EK5713               23:14
# 4   16903074018     Brown  A#22hH7s        EK5713               23:14
#
#    Cluster_Size Delivery_Address  Estimated_Arrival_Time  Actual_Arrival_Time  \
# 0             4              NaN                     NaN                  NaN
# 1             4              NaN                     NaN                  NaN
# 2             4              NaN                     NaN                  NaN
# 3             4              NaN                     NaN                  NaN
# 4             6              NaN                     NaN                  NaN
#
#    Pickup_Gate Luggage_Status Pickup_Time
# 0          NaN     In-transit       23:18
# 1          NaN     In-transit       23:18
# 2          NaN     In-transit       23:18
# 3          NaN     In-transit       23:18
# 4          NaN     In-transit       23:37
# '\n# Save the updated DataFrame to a temporary local file\ntemp_file = \'/tmp/luggage_dataset5.csv\' # Local path to save the modified file\ndf.to_csv(temp_file, index=False)\n\n# Upload the updated file back to the same location on S3 (this will overwrite the file)\ns3.upload_file(temp_file, bucket_name, s3_object_name)\n\nprint(f"File {s3_object_name} updated successfully in S3.")'

# %%
conveyor_belts = [
    [(1200, 600), (100, 600)],
    [(100, 550), (800, 550)],
    [(200, 500), (800, 500)],
    [(200, 450), (700, 450)],
    [(300, 400), (700, 400)],
    [(300, 350), (600, 350)],
    [(100, 250), (900, 250)],
    [(100, 600), (100, 200)],
    [(200, 500), (200, 200)],
    [(300, 400), (300, 200)],
    [(600, 350), (600, 200)],
    [(700, 450), (700, 200)],
    [(800, 550), (800, 200)],
    [(900, 600), (900, 250)],
    [(580, 200), (600, 250)],
    [(620, 200), (600, 250)],
    [(320, 200), (300, 250)],
    [(280, 200), (300, 250)],
    [(680, 200), (700, 250)],
    [(720, 200), (700, 250)],
    [(180, 200), (200, 250)],
    [(220, 200), (200, 250)],
    [(780, 200), (800, 250)],
    [(820, 200), (800, 250)],
    [(80, 200), (100, 250)],
    [(120, 200), (100, 250)],
]

points = [
    (100, 250), (100, 550), (100, 600),
    (200, 250), (200, 450), (200, 500),
    (300, 250), (300, 350), (300, 400),
    (600, 250), (600, 350), (700, 250),
    (700, 400), (700, 450), (800, 250),
    (800, 500), (800, 550), (900, 250),
    (900, 600)
]

gates_entry_positions = [
    (600, 250), # Gate 2
    (300, 250), # Gate 3
    (700, 250), # Gate 4
    (200, 250), # Gate 5
    (800, 250), # Gate 6
    (100, 250), # Gate 7
]

pickup_gates_positions = [
    (600, 200), # Gates 2
    (580, 200),
    (620, 200),
    (300, 200), # Gates 3
    (320, 200),
    (280, 200),
    (700, 200), # Gates 4
    (680, 200),
    (720, 200),
    (200, 200), # Gates 5
    (180, 200),
    (220, 200),
    (800, 200), # Gates 6
    (780, 200), 
    (820, 200),
    (100, 200), # Gates 7
    (80, 200),
    (120, 200),
]

# %%
class Path:
    
    def __init__(self, name, points):
        self.name = name  
        self.points = points
    
paths = {
    cluster: Path(f"{cluster}", points) for cluster, points in {
        7: [(900, 600), (100, 600), (100, 550), (100, 250)],
        6: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (800, 250)], 
        5: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (200, 250)], 
        4: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (700, 250)],
        3: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (300, 400), (300, 350), (300, 250)],
        2: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (300, 400), (300, 350), (600, 350), (600, 250)]
    }.items()
}

paths_2 = {
  cluster: Path(f"{cluster}", points) for cluster, points in {
        7: [(900, 250), (900, 600)],
        6: [(900, 250), (900, 600)], 
        5: [(900, 250), (900, 600)], 
        4: [(900, 250), (900, 600)],
        3: [(900, 250), (900, 600)],
        2: [(900, 250), (900, 600)]
    }.items()
}

def generate_random_color():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

cluster_sizes = [2, 3, 4, 5, 6, 7, 8, 9, 10] 

cluster_colors = {size: generate_random_color() for size in cluster_sizes}


flights = ['EK4276', 'AA9359', 'BA3438']

# Assign a unique color to each flight
flight_colors = {flight: generate_random_color() for flight in flights}

PPM = 1100/170 

pixel_speed = ((3*PPM)/60)*SPEED

estimated_times = {
    7: 74.70,
    6: 110.76,
    5: 141.67,
    4: 167.42,
    3: 188.03,
    2: 203.48
}

gate_mapping = {
    1: 'A',
    2: 'B',
    3: 'C'
}

# %%
class Bag:  
        
    def __init__(self, bag_id, reservation_id, cluster_size, flight_number, flight_time):
        self.ready = False
        self.path = []
        self.bag_id = bag_id
        self.reservation = reservation_id
        self.cluster_size = cluster_size
        self.position = (1200, 600)
        self.assigned_to_gate = False
        self.gate = None
        self.gate_name = None
        self.speed = pixel_speed
        self.target = None 
        self.color = cluster_colors[cluster_size]
        self.at_gate = False
        self.flight_number = flight_number
        self.flight_time = flight_time
        self.time = None
        self.estimated_time = None
        self.actual_time = None
        self.first_time = True
        self.real_time = None

    def set_at_gate(self):
        self.at_gate = True

    def set_ready(self):
        self.ready = True   

    def set_path(self):
        if(self.cluster_size < 8):
            self.path = paths[self.cluster_size].points[:]  
            if self.path:
                self.target = self.path.pop(0) 
        else:
            abs_path = self.cluster_size%7 + 1
            self.path = paths[abs_path].points[:]  
            if self.path:
                self.target = self.path.pop(0) 


    def set_gate(self, pickup_gate):
        self.gate = pickup_gate

    def set_gate_name(self, pickup_gate):
        self.gate_name = str(self.cluster_size) + gate_mapping[pickup_gate.name]

    def append_path(self, path):
        if isinstance(path, Path):  
            self.path.extend(path.points)  
        elif isinstance(path, list):  
            self.path.extend(path)  
        elif isinstance(path, tuple):
            self.path.append(path)
        
        if not self.target and self.path:
            self.target = self.path.pop(0) # Get it moving

    def move(self):
        if self.target:
            x, y = self.position
            tx, ty = self.target
    
            dx = tx - x
            dy = ty - y
            distance = (dx**2 + dy**2) ** 0.5
    
            if distance <= self.speed:
                self.position = self.target  
                if self.path:
                    self.target = self.path.pop(0)  
                else:
                    self.target = None  
            else:
                self.position = (x + (dx / distance) * self.speed, 
                                 y + (dy / distance) * self.speed)

# %%
class Gate:
    
    def __init__(self, name, gates, position):
        self.name = name 
        self.gates = gates
        self.position = position
        self.res_queue = queue.Queue() 

    def add_res(self, reservation):
        if not reservation in list(self.res_queue.queue):
            self.res_queue.put(reservation)

    def search(self, bag):
        for i in range(3):
            if(self.gates[i].reservation == bag.reservation):
                return i
        for i in range(3):
            if(self.gates[i].reservation == None):
                return i
        return -1

# %%
class PickupGate:
    
    def __init__(self, name, position):
        self.name = name 
        self.position = position
        self.reservation = None
        self.load = 0
        self.max_load = 10
        self.bags = []
        self.full = False 
        self.dispense_time = None
    
    def set_reservation(self, reservation):
        if self.reservation is None:  
            self.reservation = reservation
            return True
        else:
            return False

    def add_luggage(self, bag):
        if bag.reservation == self.reservation:
            self.bags.append(bag)
            self.load += 1
            
    def is_full(self):
        if(self.load>0):
            if self.load == self.bags[0].cluster_size:
                return True
        return False

    def clear_luggage(self):
        removed_bags = self.bags if self.bags else []  
        self.reservation = None
        self.load = 0
        self.bags = [] 
        return removed_bags

# %%
class Reservation:
    
    def __init__(self, id, cluster_size, flight_time, flight_number):
        self.id = id
        self.cluster_size = cluster_size
        self.flight_time = flight_time
        self.flight_number = flight_number
        self.time = None

    def __str__(self):
        return f"Reservation ID: {self.id}, Cluster Size: {self.cluster_size}, Time: {self.time}, Flight time: {self.flight_time}, Flight number: {self.flight_number}"

# %%
def convert_flight_time(flight_time_str):
    flight_time_obj = datetime.strptime(flight_time_str + ":00", '%H:%M:%S')
    return flight_time_obj

# %%
gate_entries = []
k = 0
for i in range(6):
    gates = []
    for j in range(3):
        gates.append(PickupGate(j+1, pickup_gates_positions[k]))
        k += 1
    gate_entries.append(Gate(i+2, gates, gates_entry_positions[i]))

reservations = []

conveyor_belt = []

# Group bags by Flight Number
grouped_conveyor_belt = []

for flight_number, group in df.groupby("Flight_Number"):
    flight_bags = []
    
    flight_time = group.iloc[0]["Flight_Arrival_Time"]
    flight_start_time = convert_flight_time(flight_time) # Convert to milliseconds
    
    for reservation_id, res_group in group.groupby("Reservation_ID"):
        cluster_size = int(res_group.iloc[0]['Cluster_Size'])  # Get cluster size

        for _, row in res_group.iterrows():
            real_bag_id = row["Bag_ID"]  # Adjust this column name if different
            flight_bags.append(Bag(real_bag_id, reservation_id, cluster_size, flight_number, flight_time))

    # Shuffle bags within this flight
    random.shuffle(flight_bags)

    bag_time = flight_start_time  # Initialize the timestamp for the first bag

    for bag in flight_bags:
        # Assign timestamp after shuffling
        bag.time = datetime.combine(date.today(), bag_time.time())
        bag.estimated_time = (bag_time + timedelta(seconds=estimated_times[bag.cluster_size])).time()
        bag_time += timedelta(seconds=3)/SPEED 

    # Optionally: store flight index to simulate 12-min delay later
    for bag in flight_bags:
        bag.flight_index = len(grouped_conveyor_belt)

    grouped_conveyor_belt.append(flight_bags)

for flight_group in grouped_conveyor_belt:
    conveyor_belt.extend(flight_group)

conveyor_belt = sorted(conveyor_belt, key=lambda bag: bag.time)

reservations_info = {}

for bag in conveyor_belt:
    if bag.reservation not in reservations_info:
        reservations_info[bag.reservation] = (bag.cluster_size, bag.flight_time, bag.flight_number)

reservations_f = {
    res_id: Reservation(res_id, cluster_size, flight_time, flight_number)
    for res_id, (cluster_size, flight_time, flight_number) in reservations_info.items()
}

reservations_c = []

# %%
pygame.init()

width, height = 1600, 800
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("SLHS Visualization")

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)

# %%
scanned_bags = []
i = 0

clock = pygame.time.Clock()
running = True
last_spawn_time = 0  
spawn_interval = 2000 
title_font = pygame.font.SysFont('Arial', 28, bold=True)
font = pygame.font.Font(None, 20)
bag_start_times = []  
start_time = pygame.time.get_ticks()  

while running:
    
    screen.fill(WHITE) 
    
    elapsed_ms = (pygame.time.get_ticks() - start_time)*SPEED
    elapsed_seconds = elapsed_ms // 1000
    minutes = elapsed_seconds // 60
    seconds = elapsed_seconds % 60
    
    time_text = font.render(f"Time: {minutes:02}:{seconds:02}", True, BLACK)
    screen.blit(time_text, (10, 10))

    title_text = title_font.render("SLHS Algorithm", True, BLACK)
    screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 20))
    '''
    flight_text = font.render(f"Flight: {read_bag.flight_number}", True, BLACK)
    screen.blit(flight_text, (1000, 10))   ''' 

    for belt in conveyor_belts:
        pygame.draw.line(screen, BLACK, belt[0], belt[1], 3)

    for point in points:
        pygame.draw.circle(screen, BLACK, point, 5)

    for gate in gates_entry_positions:
        pygame.draw.rect(screen, BLACK, (gate[0] - 5, gate[1] - 5, 10, 10))

    for pickup in pickup_gates_positions:
        pygame.draw.rect(screen, BLACK, (pickup[0] - 5, pickup[1] - 5, 10, 10))

    for gate_group in gate_entries: 
        for gate in gate_group.gates: 
            load_text = font.render(f"{gate.load}", True, BLACK)    
            screen.blit(load_text, (gate.position[0]-5, 177))
        
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False


    current_ticks = pygame.time.get_ticks()
    
    current_time = convert_flight_time(conveyor_belt[0].flight_time) + timedelta(milliseconds=current_ticks*20)
    #print(current_time)
    current_time = current_time.time()
            
    more_items = len(conveyor_belt)-1

    if i < len(conveyor_belt): 
        read_bag = conveyor_belt[i] 
        if current_time >= read_bag.time.time():
        
            read_bag.real_time = datetime.now()
            scanned_bags.append(read_bag)
            '''
            mask = (df['Reservation_ID'].astype(str) == str(read_bag.reservation)) & (df['Last_Name'].astype(str) == str("Warren"))

            if not df[mask].empty:
            
                df.loc[mask, 'Luggage_Status'] = 'In the SLHS'
    
                # Save and upload to S3
                temp_file = '/tmp/luggage_dataset5.csv'
                df.to_csv(temp_file, index=False)
                s3.upload_file(temp_file, bucket_name, s3_object_name)
                print("Success")
            
            '''
            read_bag.set_ready()
            
            cluster_size = read_bag.cluster_size
            
            if cluster_size>7:
                cluster_size = cluster_size%7+1
            
            read_bag.set_path()
        
            gate = gate_entries[cluster_size-2].search(read_bag)
    
            bag_start_times.append(read_bag.time.time())
            
            if gate == -1:
                gate_entries[cluster_size-2].add_res(read_bag.reservation)
            else:
                gate_entries[cluster_size-2].gates[gate].set_reservation(read_bag.reservation)
                read_bag.append_path(gate_entries[cluster_size-2].gates[gate].position)
                read_bag.set_gate(gate_entries[cluster_size-2].gates[gate])
                read_bag.set_gate_name(gate_entries[cluster_size-2].gates[gate])
                read_bag.assigned_to_gate = True
            
            i+=1
    
    still_moving = False 
    
    j=0
    for bag in scanned_bags:
        
        if bag.cluster_size<8:            
            if bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].position and bag.at_gate:
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                if bag.first_time:
                    elapsed = datetime.now() - bag.real_time # both must be datetime objects
                    bag.actual_time = (elapsed*SPEED + bag.time).time()
                    bag.first_time = False
            elif bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].position:
                gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].add_luggage(bag)
                bag.set_at_gate()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif not bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].position:
                bag.append_path(paths_2[bag.cluster_size])
                bag.append_path(paths[bag.cluster_size])
                if bag.path: 
                    bag.move()
                    pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif current_time >= bag_start_times[j]:
                bag.move()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                still_moving = True 

        else:
            if bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].position and bag.at_gate:
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].position:
                gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].add_luggage(bag)
                bag.set_at_gate()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif not bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].position:
                bag.append_path(paths_2[bag.cluster_size%7-1])
                bag.append_path(paths[bag.cluster_size%7-1])
                if bag.path: 
                    bag.move()
                    pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif current_time >= bag_start_times[j]:
                bag.move()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                still_moving = True 

        
        for gate_group in gate_entries:
            for gate in gate_group.gates:
                if gate.is_full():
                    res_id = gate.reservation
                    if res_id in reservations_f:  
                        reservations_f[res_id].time = current_time
                        reservations_c.append(reservations_f.pop(res_id))
                        '''
                        mask = (df['Reservation_ID'].astype(str) == str(res_id)) & (df['Last_Name'].astype(str) == str("Warren"))
                        if not df[mask].empty:
                            df.loc[mask, 'Luggage_Status'] = 'Ready for Pickup'
                            temp_file = '/tmp/luggage_dataset5.csv'
                            df.to_csv(temp_file, index=False)
                            s3.upload_file(temp_file, bucket_name, s3_object_name)
                            print(f"Updated status for {res_id} to ready and uploaded to S3.")'''
                            

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.is_full() and gate.dispense_time is None:
                    wait_seconds = random.randint(0, 70)/SPEED
                    gate.dispense_time = datetime.combine(datetime.today(), current_time) + timedelta(seconds=wait_seconds)
                            

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.dispense_time and current_time >= gate.dispense_time.time():
                    removed_bags = gate.clear_luggage()  
                    scanned_bags = [bag for bag in scanned_bags if bag not in removed_bags]  
                    print(f"Gate {gate_group.name} was emptied, and {len(removed_bags)} bags disappeared at {current_time}!")
                    gate.dispense_time = None  


        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.reservation == None: 
                    if not gate_group.res_queue.empty():
                        res = gate_group.res_queue.get() 
                        gate.set_reservation(res)

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if not bag.assigned_to_gate and bag.reservation == gate.reservation:
                    bag.append_path(gate.position)
                    bag.set_gate(gate)
                    bag.set_gate_name(gate)
                    bag.assigned_to_gate = True

        j+=1

    pygame.display.update()
    clock.tick(60) 

    
    if i >= len(conveyor_belt) and not still_moving:
        running = False  
        pygame.quit()
# Out:
# 2025-05-14 16:11:07.455 python[98917:5896932] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-05-14 16:11:07.455 python[98917:5896932] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Gate 6 was emptied, and 6 bags disappeared at 23:18:36.580000!
# Gate 7 was emptied, and 7 bags disappeared at 23:18:46.820000!
# Gate 7 was emptied, and 7 bags disappeared at 23:18:56.960000!
# Gate 7 was emptied, and 7 bags disappeared at 23:19:01.180000!
# Gate 2 was emptied, and 2 bags disappeared at 23:19:03.340000!
# Gate 2 was emptied, and 2 bags disappeared at 23:19:05.640000!
# Gate 4 was emptied, and 4 bags disappeared at 23:19:11.360000!
# Gate 3 was emptied, and 3 bags disappeared at 23:19:13.940000!
# Gate 6 was emptied, and 6 bags disappeared at 23:19:19.860000!
# Gate 6 was emptied, and 6 bags disappeared at 23:19:37.840000!
# Gate 5 was emptied, and 5 bags disappeared at 23:19:38.500000!
# Gate 2 was emptied, and 2 bags disappeared at 23:19:45.040000!
# Gate 2 was emptied, and 2 bags disappeared at 23:19:52.660000!
# Gate 5 was emptied, and 5 bags disappeared at 23:19:55.240000!
# Gate 5 was emptied, and 5 bags disappeared at 23:19:59.580000!
# Gate 3 was emptied, and 3 bags disappeared at 23:20:00.220000!
# Gate 5 was emptied, and 5 bags disappeared at 23:20:10.020000!
# Gate 3 was emptied, and 3 bags disappeared at 23:20:24.520000!
# Gate 4 was emptied, and 4 bags disappeared at 23:20:33.280000!
# Gate 4 was emptied, and 4 bags disappeared at 23:20:34.940000!
# Gate 6 was emptied, and 6 bags disappeared at 23:20:36.560000!
# Gate 7 was emptied, and 7 bags disappeared at 23:20:47.420000!
# Gate 7 was emptied, and 7 bags disappeared at 23:20:55.640000!
# Gate 6 was emptied, and 6 bags disappeared at 23:20:56.640000!
# Gate 7 was emptied, and 7 bags disappeared at 23:20:59.620000!
# Gate 6 was emptied, and 6 bags disappeared at 23:21:30.680000!
# Gate 4 was emptied, and 4 bags disappeared at 23:21:37!
# Gate 6 was emptied, and 6 bags disappeared at 23:22:21.040000!
# Gate 7 was emptied, and 7 bags disappeared at 23:22:37.640000!
# Gate 6 was emptied, and 6 bags disappeared at 23:22:42.620000!
# Gate 4 was emptied, and 4 bags disappeared at 23:22:44.240000!
# Gate 7 was emptied, and 7 bags disappeared at 23:22:48.820000!
# Gate 5 was emptied, and 5 bags disappeared at 23:22:55.080000!
# Gate 5 was emptied, and 5 bags disappeared at 23:22:55.400000!
# Gate 3 was emptied, and 3 bags disappeared at 23:22:57.380000!
# Gate 7 was emptied, and 7 bags disappeared at 23:22:57.720000!
# Gate 6 was emptied, and 6 bags disappeared at 23:23:00.320000!
# Gate 5 was emptied, and 5 bags disappeared at 23:23:11.320000!
# Gate 4 was emptied, and 4 bags disappeared at 23:23:34.600000!
# Gate 4 was emptied, and 4 bags disappeared at 23:23:36.240000!
# Gate 6 was emptied, and 6 bags disappeared at 23:24:25.180000!
# Gate 7 was emptied, and 7 bags disappeared at 23:24:30.460000!
# Gate 7 was emptied, and 7 bags disappeared at 23:24:42.620000!
# Gate 6 was emptied, and 6 bags disappeared at 23:24:44.580000!
# Gate 6 was emptied, and 6 bags disappeared at 23:24:44.580000!
# Gate 7 was emptied, and 7 bags disappeared at 23:24:50.340000!
# Gate 5 was emptied, and 5 bags disappeared at 23:25:58.780000!
# Gate 5 was emptied, and 5 bags disappeared at 23:25:59.120000!
# Gate 5 was emptied, and 5 bags disappeared at 23:26:01.120000!
# Gate 7 was emptied, and 7 bags disappeared at 23:26:17.100000!
# Gate 6 was emptied, and 6 bags disappeared at 23:26:25.620000!
# Gate 6 was emptied, and 6 bags disappeared at 23:26:38.060000!
# Gate 6 was emptied, and 6 bags disappeared at 23:26:47.220000!
# Gate 7 was emptied, and 7 bags disappeared at 23:26:47.900000!
# Gate 7 was emptied, and 7 bags disappeared at 23:26:52.460000!
# Gate 7 was emptied, and 7 bags disappeared at 23:28:15.340000!
# Gate 6 was emptied, and 6 bags disappeared at 23:28:27.460000!
# Gate 7 was emptied, and 7 bags disappeared at 23:28:27.460000!
# Gate 6 was emptied, and 6 bags disappeared at 23:28:37.240000!
# Gate 6 was emptied, and 6 bags disappeared at 23:28:42.760000!
# Gate 7 was emptied, and 7 bags disappeared at 23:28:44.400000!
# Gate 5 was emptied, and 5 bags disappeared at 23:28:59.460000!
# Gate 5 was emptied, and 5 bags disappeared at 23:29:06.320000!
# Gate 5 was emptied, and 5 bags disappeared at 23:29:10.020000!
# Gate 6 was emptied, and 6 bags disappeared at 23:29:27.620000!
# Gate 7 was emptied, and 7 bags disappeared at 23:29:46.380000!
# Gate 6 was emptied, and 6 bags disappeared at 23:30:09.100000!
# Gate 7 was emptied, and 7 bags disappeared at 23:30:18.500000!
# Gate 6 was emptied, and 6 bags disappeared at 23:30:19.140000!
# Gate 7 was emptied, and 7 bags disappeared at 23:30:45.220000!
# Gate 6 was emptied, and 6 bags disappeared at 23:31:22.040000!
# Gate 7 was emptied, and 7 bags disappeared at 23:31:47.480000!
# Gate 6 was emptied, and 6 bags disappeared at 23:31:48.480000!
# Gate 7 was emptied, and 7 bags disappeared at 23:31:52.340000!
# Gate 2 was emptied, and 2 bags disappeared at 23:31:54.260000!
# Gate 3 was emptied, and 3 bags disappeared at 23:31:54.600000!
# Gate 4 was emptied, and 4 bags disappeared at 23:31:56.900000!
# Gate 5 was emptied, and 5 bags disappeared at 23:31:57.240000!
# Gate 5 was emptied, and 5 bags disappeared at 23:32:11.680000!
# Gate 6 was emptied, and 6 bags disappeared at 23:32:15.600000!
# Gate 5 was emptied, and 5 bags disappeared at 23:32:16.260000!
# Gate 4 was emptied, and 4 bags disappeared at 23:32:29.380000!
# Gate 2 was emptied, and 2 bags disappeared at 23:32:48.460000!
# Gate 3 was emptied, and 3 bags disappeared at 23:32:48.460000!
# Gate 7 was emptied, and 7 bags disappeared at 23:32:49.440000!
# Gate 4 was emptied, and 4 bags disappeared at 23:33:14.240000!
# Gate 6 was emptied, and 6 bags disappeared at 23:33:16.160000!
# Gate 6 was emptied, and 6 bags disappeared at 23:33:16.500000!
# Gate 5 was emptied, and 5 bags disappeared at 23:33:23.960000!
# Gate 3 was emptied, and 3 bags disappeared at 23:33:26.960000!
# Gate 2 was emptied, and 2 bags disappeared at 23:33:30.280000!
# Gate 2 was emptied, and 2 bags disappeared at 23:33:35.800000!
# Gate 7 was emptied, and 7 bags disappeared at 23:33:48.740000!
# Gate 5 was emptied, and 5 bags disappeared at 23:33:49.400000!
# Gate 7 was emptied, and 7 bags disappeared at 23:33:52.980000!
# Gate 4 was emptied, and 4 bags disappeared at 23:34:04.660000!
# Gate 6 was emptied, and 6 bags disappeared at 23:34:11.620000!
# Gate 7 was emptied, and 7 bags disappeared at 23:34:24.400000!
# Gate 4 was emptied, and 4 bags disappeared at 23:34:55.200000!
# Gate 7 was emptied, and 7 bags disappeared at 23:35:05.680000!
# Gate 6 was emptied, and 6 bags disappeared at 23:35:09.260000!
# Gate 5 was emptied, and 5 bags disappeared at 23:35:11.520000!
# Gate 6 was emptied, and 6 bags disappeared at 23:35:17.740000!
# Gate 3 was emptied, and 3 bags disappeared at 23:35:25.540000!
# Gate 3 was emptied, and 3 bags disappeared at 23:35:42.120000!
# Gate 7 was emptied, and 7 bags disappeared at 23:35:58.760000!
# Gate 4 was emptied, and 4 bags disappeared at 23:36:07.280000!
# Gate 6 was emptied, and 6 bags disappeared at 23:36:11.600000!
# Gate 7 was emptied, and 7 bags disappeared at 23:36:13.880000!
# Gate 5 was emptied, and 5 bags disappeared at 23:36:14.200000!
# Gate 3 was emptied, and 3 bags disappeared at 23:36:17.840000!
# Gate 2 was emptied, and 2 bags disappeared at 23:36:28.380000!
# Gate 5 was emptied, and 5 bags disappeared at 23:36:28.380000!
# Gate 4 was emptied, and 4 bags disappeared at 23:36:42.500000!
# Gate 7 was emptied, and 7 bags disappeared at 23:36:47.400000!
# Gate 3 was emptied, and 3 bags disappeared at 23:36:51!
# Gate 6 was emptied, and 6 bags disappeared at 23:36:51.960000!
# Gate 2 was emptied, and 2 bags disappeared at 23:37:00.420000!
# Gate 6 was emptied, and 6 bags disappeared at 23:37:14.340000!
# Gate 4 was emptied, and 4 bags disappeared at 23:37:37.600000!
# Gate 7 was emptied, and 7 bags disappeared at 23:38:01.040000!
# Gate 5 was emptied, and 5 bags disappeared at 23:38:10.560000!
# Gate 6 was emptied, and 6 bags disappeared at 23:38:11.860000!
# Gate 7 was emptied, and 7 bags disappeared at 23:38:11.860000!
# Gate 7 was emptied, and 7 bags disappeared at 23:38:27.520000!
# Gate 6 was emptied, and 6 bags disappeared at 23:38:31.660000!
# Gate 4 was emptied, and 4 bags disappeared at 23:38:49.020000!
# Gate 5 was emptied, and 5 bags disappeared at 23:38:50.700000!
# Gate 4 was emptied, and 4 bags disappeared at 23:38:52.300000!
# Gate 3 was emptied, and 3 bags disappeared at 23:39:05.280000!
# Gate 5 was emptied, and 5 bags disappeared at 23:39:20.160000!
# Gate 6 was emptied, and 6 bags disappeared at 23:39:21.140000!
# Gate 7 was emptied, and 7 bags disappeared at 23:39:39.580000!
# Gate 6 was emptied, and 6 bags disappeared at 23:39:51.660000!
# Gate 6 was emptied, and 6 bags disappeared at 23:40:10.020000!
# Gate 7 was emptied, and 7 bags disappeared at 23:40:13.640000!
# Gate 7 was emptied, and 7 bags disappeared at 23:40:29.620000!
# Gate 5 was emptied, and 5 bags disappeared at 23:40:50.340000!
# Gate 5 was emptied, and 5 bags disappeared at 23:40:55.920000!
# Gate 6 was emptied, and 6 bags disappeared at 23:41:22.100000!
# Gate 7 was emptied, and 7 bags disappeared at 23:41:39.160000!
# Gate 6 was emptied, and 6 bags disappeared at 23:41:48.020000!
# Gate 6 was emptied, and 6 bags disappeared at 23:41:48.020000!
# Gate 7 was emptied, and 7 bags disappeared at 23:42:03.500000!
# Gate 5 was emptied, and 5 bags disappeared at 23:42:22.980000!
# Gate 7 was emptied, and 7 bags disappeared at 23:42:32.280000!
# Gate 7 was emptied, and 7 bags disappeared at 23:42:55.900000!
# Gate 5 was emptied, and 5 bags disappeared at 23:42:57.860000!
# Gate 6 was emptied, and 6 bags disappeared at 23:43:03.120000!
# Gate 6 was emptied, and 6 bags disappeared at 23:43:41.280000!
# Gate 5 was emptied, and 5 bags disappeared at 23:43:42.960000!
# Gate 6 was emptied, and 6 bags disappeared at 23:43:51.580000!
# Gate 7 was emptied, and 7 bags disappeared at 23:44:10!
# Gate 7 was emptied, and 7 bags disappeared at 23:44:26.360000!
# Gate 6 was emptied, and 6 bags disappeared at 23:44:40.660000!
# Gate 2 was emptied, and 2 bags disappeared at 23:44:58.180000!
# Gate 7 was emptied, and 7 bags disappeared at 23:45:03.360000!
# Gate 5 was emptied, and 5 bags disappeared at 23:45:15.700000!
# Gate 5 was emptied, and 5 bags disappeared at 23:45:17.380000!
# Gate 6 was emptied, and 6 bags disappeared at 23:45:29.020000!
# Gate 3 was emptied, and 3 bags disappeared at 23:45:46.180000!
# Gate 4 was emptied, and 4 bags disappeared at 23:45:58.040000!
# Gate 5 was emptied, and 5 bags disappeared at 23:45:58.040000!
# Gate 6 was emptied, and 6 bags disappeared at 23:45:59.060000!
# Gate 2 was emptied, and 2 bags disappeared at 23:46:08.580000!
# Gate 7 was emptied, and 7 bags disappeared at 23:46:08.580000!
# Gate 3 was emptied, and 3 bags disappeared at 23:46:10.900000!
# Gate 6 was emptied, and 6 bags disappeared at 23:46:10.900000!
# Gate 4 was emptied, and 4 bags disappeared at 23:46:13.200000!
# Gate 4 was emptied, and 4 bags disappeared at 23:46:13.200000!
# Gate 2 was emptied, and 2 bags disappeared at 23:46:13.860000!
# Gate 7 was emptied, and 7 bags disappeared at 23:46:22!
# Gate 3 was emptied, and 3 bags disappeared at 23:46:36.520000!
# Gate 7 was emptied, and 7 bags disappeared at 23:47:04.960000!
# Gate 6 was emptied, and 6 bags disappeared at 23:47:34.480000!
# Gate 5 was emptied, and 5 bags disappeared at 23:47:34.820000!
# Gate 4 was emptied, and 4 bags disappeared at 23:47:41.920000!
# Gate 6 was emptied, and 6 bags disappeared at 23:48:03.900000!
# Gate 6 was emptied, and 6 bags disappeared at 23:48:08.480000!
# Gate 7 was emptied, and 7 bags disappeared at 23:48:09.120000!
# Gate 5 was emptied, and 5 bags disappeared at 23:48:19.400000!
# Gate 5 was emptied, and 5 bags disappeared at 23:48:23.280000!
# Gate 7 was emptied, and 7 bags disappeared at 23:48:25.200000!
# Gate 3 was emptied, and 3 bags disappeared at 23:48:36.200000!
# Gate 2 was emptied, and 2 bags disappeared at 23:48:38.800000!
# Gate 4 was emptied, and 4 bags disappeared at 23:48:45.860000!
# Gate 4 was emptied, and 4 bags disappeared at 23:48:49.060000!
# Gate 7 was emptied, and 7 bags disappeared at 23:48:59.320000!
# Gate 6 was emptied, and 6 bags disappeared at 23:49:11.620000!
# Gate 6 was emptied, and 6 bags disappeared at 23:49:39.980000!
# Gate 2 was emptied, and 2 bags disappeared at 23:49:42.560000!
# Gate 3 was emptied, and 3 bags disappeared at 23:49:50!
# Gate 3 was emptied, and 3 bags disappeared at 23:49:52.080000!
# Gate 3 was emptied, and 3 bags disappeared at 23:49:56.240000!
# Gate 7 was emptied, and 7 bags disappeared at 23:50:08.380000!
# Gate 6 was emptied, and 6 bags disappeared at 23:50:09.480000!
# Gate 4 was emptied, and 4 bags disappeared at 23:50:18.800000!
# Gate 7 was emptied, and 7 bags disappeared at 23:50:30!
# Gate 7 was emptied, and 7 bags disappeared at 23:50:33.540000!
# Gate 5 was emptied, and 5 bags disappeared at 23:50:37.780000!
# Gate 5 was emptied, and 5 bags disappeared at 23:50:50.360000!
# Gate 6 was emptied, and 6 bags disappeared at 23:51:11.700000!
# Gate 5 was emptied, and 5 bags disappeared at 23:51:14.420000!
# Gate 4 was emptied, and 4 bags disappeared at 23:51:24.100000!
# Gate 6 was emptied, and 6 bags disappeared at 23:51:28.840000!
# Gate 6 was emptied, and 6 bags disappeared at 23:52:14.440000!
# Gate 7 was emptied, and 7 bags disappeared at 23:52:16.160000!
# Gate 7 was emptied, and 7 bags disappeared at 23:52:20.260000!
# Gate 7 was emptied, and 7 bags disappeared at 23:52:31.320000!
# Gate 6 was emptied, and 6 bags disappeared at 23:52:45.620000!
# Gate 6 was emptied, and 6 bags disappeared at 23:53:03.660000!
# Gate 5 was emptied, and 5 bags disappeared at 23:53:46.500000!
# Gate 5 was emptied, and 5 bags disappeared at 23:53:57.400000!
# Gate 6 was emptied, and 6 bags disappeared at 23:54:06.780000!
# Gate 5 was emptied, and 5 bags disappeared at 23:54:09.040000!
# Gate 7 was emptied, and 7 bags disappeared at 23:54:18.380000!
# Gate 7 was emptied, and 7 bags disappeared at 23:54:21.260000!
# Gate 7 was emptied, and 7 bags disappeared at 23:54:23.840000!
# Gate 6 was emptied, and 6 bags disappeared at 23:54:42.020000!
# Gate 6 was emptied, and 6 bags disappeared at 23:55:07.020000!
# Gate 6 was emptied, and 6 bags disappeared at 23:56:08.340000!
# Gate 5 was emptied, and 5 bags disappeared at 23:56:14.880000!
# Gate 7 was emptied, and 7 bags disappeared at 23:56:17.180000!
# Gate 7 was emptied, and 7 bags disappeared at 23:56:21.060000!
# Gate 7 was emptied, and 7 bags disappeared at 23:56:24.280000!
# Gate 6 was emptied, and 6 bags disappeared at 23:56:30.320000!
# Gate 5 was emptied, and 5 bags disappeared at 23:56:32.540000!
# Gate 6 was emptied, and 6 bags disappeared at 23:56:32.540000!
# Gate 5 was emptied, and 5 bags disappeared at 23:57:10.580000!
# Gate 6 was emptied, and 6 bags disappeared at 23:58:08.860000!
# Gate 6 was emptied, and 6 bags disappeared at 23:58:13.600000!
# Gate 7 was emptied, and 7 bags disappeared at 23:58:19.760000!
# Gate 7 was emptied, and 7 bags disappeared at 23:58:20.400000!
# Gate 7 was emptied, and 7 bags disappeared at 23:58:22!
# Gate 6 was emptied, and 6 bags disappeared at 23:58:29.560000!
# Gate 5 was emptied, and 5 bags disappeared at 23:58:58.820000!
# Gate 5 was emptied, and 5 bags disappeared at 23:59:09.520000!

# %%
for res in reservations_c:
    flight_time_obj = datetime.strptime(res.flight_time, "%H:%M" if len(res.flight_time) == 5 else "%H:%M:%S").time()

    served_dt = datetime.combine(datetime.today(), res.time)
    flight_dt = datetime.combine(datetime.today(), flight_time_obj)
    res.time = served_dt - flight_dt

    print(res)
# Out:
# Reservation ID: RES-00061, Cluster Size: 6, Time: 0:04:29.460000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00041, Cluster Size: 7, Time: 0:04:43.880000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00051, Cluster Size: 7, Time: 0:04:53.040000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00252, Cluster Size: 7, Time: 0:04:54.340000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00313, Cluster Size: 2, Time: 0:05:00.880000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00026, Cluster Size: 2, Time: 0:05:04.340000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00016, Cluster Size: 4, Time: 0:05:09.640000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00029, Cluster Size: 3, Time: 0:05:12.980000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00308, Cluster Size: 6, Time: 0:05:18.580000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00240, Cluster Size: 6, Time: 0:05:32.240000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00017, Cluster Size: 5, Time: 0:05:35.180000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00004, Cluster Size: 2, Time: 0:05:42.440000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00350, Cluster Size: 2, Time: 0:05:47.600000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00035, Cluster Size: 5, Time: 0:05:49.580000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00048, Cluster Size: 5, Time: 0:05:54.260000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00070, Cluster Size: 3, Time: 0:05:59.900000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00292, Cluster Size: 5, Time: 0:06:03.180000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00314, Cluster Size: 3, Time: 0:06:19.560000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00212, Cluster Size: 4, Time: 0:06:28.060000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00046, Cluster Size: 4, Time: 0:06:33.280000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00234, Cluster Size: 6, Time: 0:06:34.620000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00257, Cluster Size: 7, Time: 0:06:45.400000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00254, Cluster Size: 7, Time: 0:06:53, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00039, Cluster Size: 6, Time: 0:06:54.320000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00068, Cluster Size: 7, Time: 0:06:54.660000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00040, Cluster Size: 6, Time: 0:07:23.600000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00001, Cluster Size: 4, Time: 0:07:30.680000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00042, Cluster Size: 6, Time: 0:08:17.080000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00069, Cluster Size: 7, Time: 0:08:30.940000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00065, Cluster Size: 4, Time: 0:08:40.940000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00032, Cluster Size: 6, Time: 0:08:41.600000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00066, Cluster Size: 7, Time: 0:08:43.260000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00358, Cluster Size: 5, Time: 0:08:50.440000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00052, Cluster Size: 5, Time: 0:08:50.440000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00056, Cluster Size: 6, Time: 0:08:54.420000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00226, Cluster Size: 7, Time: 0:08:56.080000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00266, Cluster Size: 3, Time: 0:08:56.720000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00010, Cluster Size: 5, Time: 0:09:11, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00271, Cluster Size: 4, Time: 0:09:30.960000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00063, Cluster Size: 4, Time: 0:09:31.920000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00216, Cluster Size: 6, Time: 0:10:19.580000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00357, Cluster Size: 7, Time: 0:10:29.140000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00315, Cluster Size: 6, Time: 0:10:38.680000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00036, Cluster Size: 7, Time: 0:10:39.020000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00293, Cluster Size: 6, Time: 0:10:40.660000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00291, Cluster Size: 7, Time: 0:10:43.260000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00009, Cluster Size: 5, Time: 0:11:52.780000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00019, Cluster Size: 5, Time: 0:11:55.120000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00043, Cluster Size: 5, Time: 0:11:57.480000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00319, Cluster Size: 7, Time: 0:12:14.160000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00031, Cluster Size: 6, Time: 0:12:25.620000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00349, Cluster Size: 6, Time: 0:12:36.400000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00038, Cluster Size: 7, Time: 0:12:43, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00006, Cluster Size: 6, Time: 0:12:44.640000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00276, Cluster Size: 7, Time: 0:12:51.120000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00295, Cluster Size: 7, Time: 0:14:14.040000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00224, Cluster Size: 7, Time: 0:14:23.500000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00062, Cluster Size: 6, Time: 0:14:27.120000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00034, Cluster Size: 6, Time: 0:14:34.620000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00012, Cluster Size: 7, Time: 0:14:41.780000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00325, Cluster Size: 6, Time: 0:14:42.440000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00028, Cluster Size: 5, Time: 0:14:59.140000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00286, Cluster Size: 5, Time: 0:15:01.740000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00211, Cluster Size: 5, Time: 0:15:03.400000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00057, Cluster Size: 6, Time: 0:15:26.940000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00023, Cluster Size: 7, Time: 0:15:43.820000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00258, Cluster Size: 6, Time: 0:16:04.600000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00053, Cluster Size: 6, Time: 0:16:13.300000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00340, Cluster Size: 7, Time: 0:16:15.580000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00037, Cluster Size: 7, Time: 0:16:41.340000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00002, Cluster Size: 6, Time: 0:17:16.500000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00014, Cluster Size: 7, Time: 0:17:43.840000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00250, Cluster Size: 7, Time: 0:17:46.500000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00321, Cluster Size: 6, Time: 0:17:48.480000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00346, Cluster Size: 2, Time: 0:04:50.340000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00117, Cluster Size: 3, Time: 0:04:52.340000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00079, Cluster Size: 4, Time: 0:04:52.340000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00059, Cluster Size: 5, Time: 0:17:53.640000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00024, Cluster Size: 5, Time: 0:18:08.420000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00280, Cluster Size: 6, Time: 0:18:10.040000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00033, Cluster Size: 5, Time: 0:18:11.680000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00241, Cluster Size: 4, Time: 0:05:25.500000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00219, Cluster Size: 3, Time: 0:05:43.220000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00054, Cluster Size: 7, Time: 0:18:45.180000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00108, Cluster Size: 2, Time: 0:05:47.160000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00323, Cluster Size: 4, Time: 0:06:08.340000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00021, Cluster Size: 6, Time: 0:19:13.580000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00247, Cluster Size: 6, Time: 0:19:16.160000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00045, Cluster Size: 5, Time: 0:19:16.820000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00088, Cluster Size: 3, Time: 0:06:26.620000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00136, Cluster Size: 2, Time: 0:06:27.280000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00290, Cluster Size: 2, Time: 0:06:31.240000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00214, Cluster Size: 5, Time: 0:19:44.200000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00302, Cluster Size: 7, Time: 0:19:45.180000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00013, Cluster Size: 7, Time: 0:19:46.820000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00092, Cluster Size: 4, Time: 0:07:02.700000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00044, Cluster Size: 6, Time: 0:20:05.320000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00242, Cluster Size: 7, Time: 0:20:21.140000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00134, Cluster Size: 4, Time: 0:07:50, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00243, Cluster Size: 7, Time: 0:20:58.500000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00122, Cluster Size: 6, Time: 0:08:07.320000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00008, Cluster Size: 5, Time: 0:21:08.620000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00228, Cluster Size: 6, Time: 0:08:14.120000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00128, Cluster Size: 3, Time: 0:08:23.600000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00299, Cluster Size: 3, Time: 0:08:40.160000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00055, Cluster Size: 7, Time: 0:21:53.240000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00334, Cluster Size: 4, Time: 0:09:04.980000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00126, Cluster Size: 6, Time: 0:09:07.600000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00025, Cluster Size: 7, Time: 0:22:10.960000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00015, Cluster Size: 5, Time: 0:22:13.540000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00075, Cluster Size: 3, Time: 0:09:13.540000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00232, Cluster Size: 2, Time: 0:09:26.060000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00018, Cluster Size: 5, Time: 0:22:26.420000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00073, Cluster Size: 4, Time: 0:09:40.820000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00296, Cluster Size: 7, Time: 0:22:44.780000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00272, Cluster Size: 3, Time: 0:09:49.020000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00324, Cluster Size: 6, Time: 0:09:51, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00096, Cluster Size: 2, Time: 0:09:59.440000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00090, Cluster Size: 6, Time: 0:10:11.360000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00077, Cluster Size: 4, Time: 0:10:31.040000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00274, Cluster Size: 7, Time: 0:23:55.500000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00220, Cluster Size: 5, Time: 0:24:06.300000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00330, Cluster Size: 6, Time: 0:11:07.280000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00213, Cluster Size: 7, Time: 0:24:11.540000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00333, Cluster Size: 7, Time: 0:24:22.380000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00093, Cluster Size: 6, Time: 0:11:26.220000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00332, Cluster Size: 4, Time: 0:11:46.120000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00082, Cluster Size: 4, Time: 0:11:47.100000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00022, Cluster Size: 5, Time: 0:24:49.360000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00100, Cluster Size: 3, Time: 0:12:04.640000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00099, Cluster Size: 6, Time: 0:12:14.240000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00260, Cluster Size: 5, Time: 0:25:18.180000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00341, Cluster Size: 7, Time: 0:25:35.980000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00071, Cluster Size: 6, Time: 0:12:50.680000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00123, Cluster Size: 6, Time: 0:13:05.100000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00067, Cluster Size: 7, Time: 0:26:10.340000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00320, Cluster Size: 7, Time: 0:26:24.380000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00030, Cluster Size: 5, Time: 0:26:43.620000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00050, Cluster Size: 5, Time: 0:26:54.300000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00133, Cluster Size: 6, Time: 0:14:18.160000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00304, Cluster Size: 7, Time: 0:27:35.900000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00110, Cluster Size: 6, Time: 0:14:45.740000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00120, Cluster Size: 6, Time: 0:14:46.080000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00027, Cluster Size: 7, Time: 0:28:01.860000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00049, Cluster Size: 5, Time: 0:28:18.460000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00317, Cluster Size: 7, Time: 0:28:25.540000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00235, Cluster Size: 7, Time: 0:15:51.700000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00318, Cluster Size: 5, Time: 0:15:52.980000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00256, Cluster Size: 6, Time: 0:16:01.520000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00060, Cluster Size: 5, Time: 0:29:37.860000, Flight time: 23:14, Flight number: EK5713
# Reservation ID: RES-00097, Cluster Size: 6, Time: 0:16:39.560000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00127, Cluster Size: 6, Time: 0:16:46.900000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00132, Cluster Size: 7, Time: 0:17:03.680000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00245, Cluster Size: 7, Time: 0:17:24.680000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00094, Cluster Size: 6, Time: 0:17:39.960000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00167, Cluster Size: 2, Time: 0:04:51.680000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00116, Cluster Size: 7, Time: 0:17:57.820000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00209, Cluster Size: 5, Time: 0:18:13.320000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00124, Cluster Size: 5, Time: 0:18:15.700000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00327, Cluster Size: 6, Time: 0:18:22.640000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00186, Cluster Size: 3, Time: 0:05:40.520000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00225, Cluster Size: 4, Time: 0:05:52.940000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00337, Cluster Size: 6, Time: 0:18:55.280000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00072, Cluster Size: 5, Time: 0:18:56.640000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00083, Cluster Size: 6, Time: 0:19:04.240000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00125, Cluster Size: 7, Time: 0:19:04.560000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00182, Cluster Size: 2, Time: 0:06:08.240000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00287, Cluster Size: 4, Time: 0:06:09.240000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00353, Cluster Size: 2, Time: 0:06:09.900000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00328, Cluster Size: 3, Time: 0:06:09.900000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00200, Cluster Size: 4, Time: 0:06:11.560000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00114, Cluster Size: 7, Time: 0:19:19.060000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00251, Cluster Size: 3, Time: 0:06:34.540000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00288, Cluster Size: 7, Time: 0:20:03, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00098, Cluster Size: 5, Time: 0:20:29.620000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00113, Cluster Size: 6, Time: 0:20:30.260000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00198, Cluster Size: 4, Time: 0:07:38.060000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00248, Cluster Size: 6, Time: 0:20:57.460000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00074, Cluster Size: 6, Time: 0:21:06.520000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00336, Cluster Size: 7, Time: 0:21:07.180000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00311, Cluster Size: 5, Time: 0:21:15.840000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00331, Cluster Size: 7, Time: 0:21:21.320000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00344, Cluster Size: 5, Time: 0:21:22.940000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00239, Cluster Size: 3, Time: 0:08:33.540000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00193, Cluster Size: 2, Time: 0:08:33.880000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00163, Cluster Size: 4, Time: 0:08:38.800000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00164, Cluster Size: 4, Time: 0:08:45.860000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00253, Cluster Size: 7, Time: 0:21:53.200000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00135, Cluster Size: 6, Time: 0:22:10.640000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00329, Cluster Size: 6, Time: 0:22:34.820000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00172, Cluster Size: 2, Time: 0:09:38.680000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00138, Cluster Size: 3, Time: 0:09:44.880000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00297, Cluster Size: 3, Time: 0:09:45.640000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00345, Cluster Size: 3, Time: 0:09:50.360000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00101, Cluster Size: 7, Time: 0:23:06.600000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00261, Cluster Size: 6, Time: 0:10:07.320000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00156, Cluster Size: 4, Time: 0:10:16.020000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00137, Cluster Size: 7, Time: 0:23:25.120000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00121, Cluster Size: 7, Time: 0:23:29.420000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00338, Cluster Size: 5, Time: 0:23:32.480000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00277, Cluster Size: 5, Time: 0:23:43.820000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00230, Cluster Size: 6, Time: 0:11:10.340000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00085, Cluster Size: 5, Time: 0:24:13.380000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00236, Cluster Size: 4, Time: 0:11:22.100000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00150, Cluster Size: 6, Time: 0:11:28.500000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00278, Cluster Size: 7, Time: 0:25:12, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00180, Cluster Size: 6, Time: 0:12:12.700000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00112, Cluster Size: 7, Time: 0:25:18.520000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00109, Cluster Size: 7, Time: 0:25:30, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00199, Cluster Size: 6, Time: 0:12:44.960000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00227, Cluster Size: 6, Time: 0:13:03.020000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00087, Cluster Size: 5, Time: 0:26:43.300000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00303, Cluster Size: 5, Time: 0:26:51.300000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00149, Cluster Size: 6, Time: 0:14:00.340000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00259, Cluster Size: 5, Time: 0:27:04.200000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00130, Cluster Size: 7, Time: 0:27:14.820000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00106, Cluster Size: 7, Time: 0:27:16.760000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00301, Cluster Size: 7, Time: 0:27:16.760000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00309, Cluster Size: 6, Time: 0:14:36.220000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00184, Cluster Size: 6, Time: 0:15:02.800000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00151, Cluster Size: 6, Time: 0:16:02.200000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00294, Cluster Size: 5, Time: 0:29:11.580000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00352, Cluster Size: 7, Time: 0:29:13.900000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00102, Cluster Size: 7, Time: 0:29:15.520000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00115, Cluster Size: 7, Time: 0:29:17.180000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00143, Cluster Size: 6, Time: 0:16:28.760000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00196, Cluster Size: 6, Time: 0:16:30.320000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00107, Cluster Size: 5, Time: 0:29:31.920000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00131, Cluster Size: 5, Time: 0:30:03.460000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00171, Cluster Size: 6, Time: 0:18:02.380000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00229, Cluster Size: 6, Time: 0:18:07.260000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00078, Cluster Size: 7, Time: 0:31:17.460000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00359, Cluster Size: 7, Time: 0:31:19.100000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00255, Cluster Size: 7, Time: 0:31:19.100000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00177, Cluster Size: 6, Time: 0:18:23.640000, Flight time: 23:40, Flight number: SV3163
# Reservation ID: RES-00080, Cluster Size: 5, Time: 0:31:57.180000, Flight time: 23:27, Flight number: AA7873
# Reservation ID: RES-00119, Cluster Size: 5, Time: 0:32:06.600000, Flight time: 23:27, Flight number: AA7873

# %%
bag_time_map = {}
for bag in conveyor_belt:
    # Make sure these are Python strings "HH:MM:SS"
    est = bag.estimated_time
    act = getattr(bag, "actual_time", None)
    # If est/act are datetime.time or timedelta, convert them now:
    if hasattr(est, "strftime"):
        est = est.strftime("%H:%M:%S")
    if hasattr(act, "strftime"):
        act = act.strftime("%H:%M:%S")
    bag_time_map[bag.bag_id] = (est, act)

'''
s3 = boto3.client("s3")
bucket = "trackage.1"
key = "database.csv"

obj = s3.get_object(Bucket=bucket, Key=key)
df = pd.read_csv(obj["Body"], on_bad_lines="skip")
'''
gate_name_map = {str(bag.bag_id): bag.gate_name for bag in conveyor_belt}
df["Bag_ID"] = df["Bag_ID"].astype(str)
df["Pickup_Gate"] = df["Bag_ID"].map(gate_name_map)


df["Estimated_Arrival_Time"] = df["Bag_ID"].map(lambda bid: bag_time_map.get(bid, ("", ""))[0])
df["Actual_Arrival_Time"]    = df["Bag_ID"].map(lambda bid: bag_time_map.get(bid, ("", ""))[1])
df["Flight_Arrival_Time"] = (
    pd.to_datetime(df["Flight_Arrival_Time"], format="%H:%M", errors="coerce")
      .subtract(pd.Timedelta(minutes=15))
      .dt.strftime("%H:%M")
)


out_tmp     = "/tmp/luggage_dataset.csv"
out_desktop = os.path.join(os.path.expanduser("~"), "Desktop", "luggage_dataset5.csv")

df.to_csv(out_tmp, index=False)
df.to_csv(out_desktop, index=False)
'''
s3.upload_file(out_tmp, bucket, key)
print("Saved to:", out_desktop)
print(f"Uploaded back to s3://{bucket}/{key}")'''
