# %%
import pygame
import random
import math
import time
import queue
import os
import boto3
import pandas as pd
from io import StringIO
from datetime import datetime, timedelta, date
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
'''# Create a session using your configured AWS credentials
s3 = boto3.client('s3')

# Upload a file to S3
bucket_name = "trackage.1"
file_name = "luggage_dataset5.csv" # Path to your local file
s3_object_name = "database.csv" # Name in S3

s3.upload_file(file_name, bucket_name, s3_object_name)

print(f"Uploaded {file_name} to S3 bucket {bucket_name} as {s3_object_name}")


# Download the file from S3
obj = s3.get_object(Bucket=bucket_name, Key=s3_object_name)
'''
# Read it as a Pandas DataFrame
df = pd.read_csv('A-350P-equal.csv')
df = df[df['Cluster_Size'] != 1]
#df = df[df['Claim_Option'] == 'SLHS Electronic Gates']

SPEED = 100

print(df.head()) # Show first 5 rows
'''
# Save the updated DataFrame to a temporary local file
temp_file = '/tmp/luggage_dataset5.csv' # Local path to save the modified file
df.to_csv(temp_file, index=False)

# Upload the updated file back to the same location on S3 (this will overwrite the file)
s3.upload_file(temp_file, bucket_name, s3_object_name)

print(f"File {s3_object_name} updated successfully in S3.")'''
# Out:
#               Bag_ID           Claim_Option  Handled_by_SLHS Reservation_ID  \
# 0  065-SV8120-000001  SLHS Electronic Gates             True      RES-00001
# 1  065-SV8120-000002  SLHS Electronic Gates             True      RES-00001
# 2  065-SV8120-000003  SLHS Electronic Gates             True      RES-00001
# 3  065-SV8120-000004  SLHS Electronic Gates             True      RES-00001
# 4  065-SV8120-000005  SLHS Electronic Gates             True      RES-00001
#
#    Phone_Number Last_Name  Password Flight_Number Flight_Arrival_Time  \
# 0   15409683906  Richmond  5"7e\:?^        SV8120               02:26
# 1   15409683906  Richmond  5"7e\:?^        SV8120               02:26
# 2   18544154800  Richmond  5"7e\:?^        SV8120               02:26
# 3   18544154800  Richmond  5"7e\:?^        SV8120               02:26
# 4   15409683906  Richmond  5"7e\:?^        SV8120               02:26
#
#    Cluster_Size Delivery_Address  Estimated_Arrival_Time  Actual_Arrival_Time  \
# 0             7              NaN                     NaN                  NaN
# 1             7              NaN                     NaN                  NaN
# 2             7              NaN                     NaN                  NaN
# 3             7              NaN                     NaN                  NaN
# 4             7              NaN                     NaN                  NaN
#
#    Pickup_Gate Luggage_Status Pickup_Time
# 0          NaN     In-transit       02:30
# 1          NaN     In-transit       02:30
# 2          NaN     In-transit       02:30
# 3          NaN     In-transit       02:30
# 4          NaN     In-transit       02:30
# '\n# Save the updated DataFrame to a temporary local file\ntemp_file = \'/tmp/luggage_dataset5.csv\' # Local path to save the modified file\ndf.to_csv(temp_file, index=False)\n\n# Upload the updated file back to the same location on S3 (this will overwrite the file)\ns3.upload_file(temp_file, bucket_name, s3_object_name)\n\nprint(f"File {s3_object_name} updated successfully in S3.")'

# %%
conveyor_belts = [
    [(1200, 600), (100, 600)],
    [(100, 550), (800, 550)],
    [(200, 500), (800, 500)],
    [(200, 450), (700, 450)],
    [(300, 400), (700, 400)],
    [(300, 350), (600, 350)],
    [(100, 250), (900, 250)],
    [(100, 600), (100, 200)],
    [(200, 500), (200, 200)],
    [(300, 400), (300, 200)],
    [(600, 350), (600, 200)],
    [(700, 450), (700, 200)],
    [(800, 550), (800, 200)],
    [(900, 600), (900, 250)],
    [(580, 200), (600, 250)],
    [(620, 200), (600, 250)],
    [(320, 200), (300, 250)],
    [(280, 200), (300, 250)],
    [(680, 200), (700, 250)],
    [(720, 200), (700, 250)],
    [(180, 200), (200, 250)],
    [(220, 200), (200, 250)],
    [(780, 200), (800, 250)],
    [(820, 200), (800, 250)],
    [(80, 200), (100, 250)],
    [(120, 200), (100, 250)],
]

points = [
    (100, 250), (100, 550), (100, 600),
    (200, 250), (200, 450), (200, 500),
    (300, 250), (300, 350), (300, 400),
    (600, 250), (600, 350), (700, 250),
    (700, 400), (700, 450), (800, 250),
    (800, 500), (800, 550), (900, 250),
    (900, 600)
]

gates_entry_positions = [
    (600, 250), # Gate 2
    (300, 250), # Gate 3
    (700, 250), # Gate 4
    (200, 250), # Gate 5
    (800, 250), # Gate 6
    (100, 250), # Gate 7
]

pickup_gates_positions = [
    (600, 200), # Gates 2
    (580, 200),
    (620, 200),
    (300, 200), # Gates 3
    (320, 200),
    (280, 200),
    (700, 200), # Gates 4
    (680, 200),
    (720, 200),
    (200, 200), # Gates 5
    (180, 200),
    (220, 200),
    (800, 200), # Gates 6
    (780, 200), 
    (820, 200),
    (100, 200), # Gates 7
    (80, 200),
    (120, 200),
]

# %%
class Path:
    
    def __init__(self, name, points):
        self.name = name  
        self.points = points
    
paths = {
    cluster: Path(f"{cluster}", points) for cluster, points in {
        7: [(900, 600), (100, 600), (100, 550), (100, 250)],
        6: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (800, 250)], 
        5: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (200, 250)], 
        4: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (700, 250)],
        3: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (300, 400), (300, 350), (300, 250)],
        2: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), 
            (700, 400), (300, 400), (300, 350), (600, 350), (600, 250)]
    }.items()
}

paths_2 = {
  cluster: Path(f"{cluster}", points) for cluster, points in {
        7: [(900, 250), (900, 600)],
        6: [(900, 250), (900, 600)], 
        5: [(900, 250), (900, 600)], 
        4: [(900, 250), (900, 600)],
        3: [(900, 250), (900, 600)],
        2: [(900, 250), (900, 600)]
    }.items()
}

def generate_random_color():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

cluster_sizes = [2, 3, 4, 5, 6, 7, 8, 9, 10] 

cluster_colors = {size: generate_random_color() for size in cluster_sizes}


flights = ['EK4276', 'AA9359', 'BA3438']

# Assign a unique color to each flight
flight_colors = {flight: generate_random_color() for flight in flights}

PPM = 1100/170 

pixel_speed = ((3*PPM)/60)*SPEED

estimated_times = {
    7: 74.70,
    6: 110.76,
    5: 141.67,
    4: 167.42,
    3: 188.03,
    2: 203.48
}

gate_mapping = {
    1: 'A',
    2: 'B',
    3: 'C'
}

# %%
class Bag:  
        
    def __init__(self, bag_id, reservation_id, cluster_size, flight_number, flight_time):
        self.ready = False
        self.path = []
        self.bag_id = bag_id
        self.reservation = reservation_id
        self.cluster_size = cluster_size
        self.position = (1200, 600)
        self.assigned_to_gate = False
        self.gate = None
        self.gate_name = None
        self.speed = pixel_speed
        self.target = None 
        self.color = cluster_colors[cluster_size]
        self.at_gate = False
        self.flight_number = flight_number
        self.flight_time = flight_time
        self.time = None
        self.estimated_time = None
        self.actual_time = None
        self.first_time = True
        self.real_time = None

    def set_at_gate(self):
        self.at_gate = True

    def set_ready(self):
        self.ready = True   

    def set_path(self):
        if(self.cluster_size < 8):
            self.path = paths[self.cluster_size].points[:]  
            if self.path:
                self.target = self.path.pop(0) 
        else:
            abs_path = self.cluster_size%7 + 1
            self.path = paths[abs_path].points[:]  
            if self.path:
                self.target = self.path.pop(0) 


    def set_gate(self, pickup_gate):
        self.gate = pickup_gate

    def set_gate_name(self, pickup_gate):
        self.gate_name = str(self.cluster_size) + gate_mapping[pickup_gate.name]

    def append_path(self, path):
        if isinstance(path, Path):  
            self.path.extend(path.points)  
        elif isinstance(path, list):  
            self.path.extend(path)  
        elif isinstance(path, tuple):
            self.path.append(path)
        
        if not self.target and self.path:
            self.target = self.path.pop(0) # Get it moving

    def move(self):
        if self.target:
            x, y = self.position
            tx, ty = self.target
    
            dx = tx - x
            dy = ty - y
            distance = (dx**2 + dy**2) ** 0.5
    
            if distance <= self.speed:
                self.position = self.target  
                if self.path:
                    self.target = self.path.pop(0)  
                else:
                    self.target = None  
            else:
                self.position = (x + (dx / distance) * self.speed, 
                                 y + (dy / distance) * self.speed)

# %%
class Gate:
    
    def __init__(self, name, gates, position):
        self.name = name 
        self.gates = gates
        self.position = position
        self.res_queue = queue.Queue() 

    def add_res(self, reservation):
        if not reservation in list(self.res_queue.queue):
            self.res_queue.put(reservation)

    def search(self, bag):
        for i in range(3):
            if(self.gates[i].reservation == bag.reservation):
                return i
        for i in range(3):
            if(self.gates[i].reservation == None):
                return i
        return -1

# %%
class PickupGate:
    
    def __init__(self, name, position):
        self.name = name 
        self.position = position
        self.reservation = None
        self.load = 0
        self.max_load = 10
        self.bags = []
        self.full = False 
        self.dispense_time = None
    
    def set_reservation(self, reservation):
        if self.reservation is None:  
            self.reservation = reservation
            return True
        else:
            return False

    def add_luggage(self, bag):
        if bag.reservation == self.reservation:
            self.bags.append(bag)
            self.load += 1
            
    def is_full(self):
        if(self.load>0):
            if self.load == self.bags[0].cluster_size:
                return True
        return False

    def clear_luggage(self):
        removed_bags = self.bags if self.bags else []  
        self.reservation = None
        self.load = 0
        self.bags = [] 
        return removed_bags

# %%
class Reservation:
    
    def __init__(self, id, cluster_size, flight_time, flight_number):
        self.id = id
        self.cluster_size = cluster_size
        self.flight_time = flight_time
        self.flight_number = flight_number
        self.time = None

    def __str__(self):
        return f"Reservation ID: {self.id}, Cluster Size: {self.cluster_size}, Time: {self.time}, Flight time: {self.flight_time}, Flight number: {self.flight_number}"

# %%
def convert_flight_time(flight_time_str):
    flight_time_obj = datetime.strptime(flight_time_str + ":00", '%H:%M:%S')
    return flight_time_obj

# %%
gate_entries = []
k = 0
for i in range(6):
    gates = []
    for j in range(3):
        gates.append(PickupGate(j+1, pickup_gates_positions[k]))
        k += 1
    gate_entries.append(Gate(i+2, gates, gates_entry_positions[i]))

reservations = []

conveyor_belt = []

# Group bags by Flight Number
grouped_conveyor_belt = []

for flight_number, group in df.groupby("Flight_Number"):
    flight_bags = []
    
    flight_time = group.iloc[0]["Flight_Arrival_Time"]
    flight_start_time = convert_flight_time(flight_time) # Convert to milliseconds
    
    for reservation_id, res_group in group.groupby("Reservation_ID"):
        cluster_size = int(res_group.iloc[0]['Cluster_Size'])  # Get cluster size

        for _, row in res_group.iterrows():
            real_bag_id = row["Bag_ID"]  # Adjust this column name if different
            flight_bags.append(Bag(real_bag_id, reservation_id, cluster_size, flight_number, flight_time))

    # Shuffle bags within this flight
    random.shuffle(flight_bags)

    bag_time = flight_start_time  # Initialize the timestamp for the first bag

    for bag in flight_bags:
        # Assign timestamp after shuffling
        bag.time = datetime.combine(date.today(), bag_time.time())
        bag.estimated_time = (bag_time + timedelta(seconds=estimated_times[bag.cluster_size])).time()
        bag_time += timedelta(seconds=3)/SPEED 

    # Optionally: store flight index to simulate 12-min delay later
    for bag in flight_bags:
        bag.flight_index = len(grouped_conveyor_belt)

    grouped_conveyor_belt.append(flight_bags)

for flight_group in grouped_conveyor_belt:
    conveyor_belt.extend(flight_group)

conveyor_belt = sorted(conveyor_belt, key=lambda bag: bag.time)

reservations_info = {}

for bag in conveyor_belt:
    if bag.reservation not in reservations_info:
        reservations_info[bag.reservation] = (bag.cluster_size, bag.flight_time, bag.flight_number)

reservations_f = {
    res_id: Reservation(res_id, cluster_size, flight_time, flight_number)
    for res_id, (cluster_size, flight_time, flight_number) in reservations_info.items()
}

reservations_c = []

# %%
pygame.init()

width, height = 1600, 800
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("SLHS Visualization")

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)

# %%
scanned_bags = []
i = 0

clock = pygame.time.Clock()
running = True
last_spawn_time = 0  
spawn_interval = 2000 
title_font = pygame.font.SysFont('Arial', 28, bold=True)
font = pygame.font.Font(None, 20)
bag_start_times = []  
start_time = pygame.time.get_ticks()  

while running:
    
    screen.fill(WHITE) 
    
    elapsed_ms = (pygame.time.get_ticks() - start_time)*SPEED
    elapsed_seconds = elapsed_ms // 1000
    minutes = elapsed_seconds // 60
    seconds = elapsed_seconds % 60
    
    time_text = font.render(f"Time: {minutes:02}:{seconds:02}", True, BLACK)
    screen.blit(time_text, (10, 10))

    title_text = title_font.render("SLHS Algorithm", True, BLACK)
    screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 20))
    '''
    flight_text = font.render(f"Flight: {read_bag.flight_number}", True, BLACK)
    screen.blit(flight_text, (1000, 10))   ''' 

    for belt in conveyor_belts:
        pygame.draw.line(screen, BLACK, belt[0], belt[1], 3)

    for point in points:
        pygame.draw.circle(screen, BLACK, point, 5)

    for gate in gates_entry_positions:
        pygame.draw.rect(screen, BLACK, (gate[0] - 5, gate[1] - 5, 10, 10))

    for pickup in pickup_gates_positions:
        pygame.draw.rect(screen, BLACK, (pickup[0] - 5, pickup[1] - 5, 10, 10))

    for gate_group in gate_entries: 
        for gate in gate_group.gates: 
            load_text = font.render(f"{gate.load}", True, BLACK)    
            screen.blit(load_text, (gate.position[0]-5, 177))
        
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False


    current_ticks = pygame.time.get_ticks()
    
    current_time = convert_flight_time(conveyor_belt[0].flight_time) + timedelta(milliseconds=current_ticks*SPEED)
    #print(current_time)
    current_time = current_time.time()
            
    more_items = len(conveyor_belt)-1

    if i < len(conveyor_belt): 
        read_bag = conveyor_belt[i] 
        if current_time >= read_bag.time.time():
        
            read_bag.real_time = datetime.now()
            scanned_bags.append(read_bag)
            '''
            mask = (df['Reservation_ID'].astype(str) == str(read_bag.reservation)) & (df['Last_Name'].astype(str) == str("Warren"))

            if not df[mask].empty:
            
                df.loc[mask, 'Luggage_Status'] = 'In the SLHS'
    
                # Save and upload to S3
                temp_file = '/tmp/luggage_dataset5.csv'
                df.to_csv(temp_file, index=False)
                s3.upload_file(temp_file, bucket_name, s3_object_name)
                print("Success")
            
            '''
            read_bag.set_ready()
            
            cluster_size = read_bag.cluster_size
            
            if cluster_size>7:
                cluster_size = cluster_size%7+1
            
            read_bag.set_path()
        
            gate = gate_entries[cluster_size-2].search(read_bag)
    
            bag_start_times.append(read_bag.time.time())
            
            if gate == -1:
                gate_entries[cluster_size-2].add_res(read_bag.reservation)
            else:
                gate_entries[cluster_size-2].gates[gate].set_reservation(read_bag.reservation)
                read_bag.append_path(gate_entries[cluster_size-2].gates[gate].position)
                read_bag.set_gate(gate_entries[cluster_size-2].gates[gate])
                read_bag.set_gate_name(gate_entries[cluster_size-2].gates[gate])
                read_bag.assigned_to_gate = True
            
            i+=1
    
    still_moving = False 
    
    j=0
    for bag in scanned_bags:
        
        if bag.cluster_size<8:            
            if bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].position and bag.at_gate:
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                if bag.first_time:
                    elapsed = datetime.now() - bag.real_time # both must be datetime objects
                    bag.actual_time = (elapsed*SPEED + bag.time).time()
                    bag.first_time = False
            elif bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].position:
                gate_entries[bag.cluster_size-2].gates[bag.gate.name-1].add_luggage(bag)
                bag.set_at_gate()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif not bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size-2].position:
                bag.append_path(paths_2[bag.cluster_size])
                bag.append_path(paths[bag.cluster_size])
                if bag.path: 
                    bag.move()
                    pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif current_time >= bag_start_times[j]:
                bag.move()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                still_moving = True 

        else:
            if bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].position and bag.at_gate:
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].position:
                gate_entries[bag.cluster_size%7-1].gates[bag.gate.name-1].add_luggage(bag)
                bag.set_at_gate()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif not bag.assigned_to_gate and bag.position == gate_entries[bag.cluster_size%7-1].position:
                bag.append_path(paths_2[bag.cluster_size%7-1])
                bag.append_path(paths[bag.cluster_size%7-1])
                if bag.path: 
                    bag.move()
                    pygame.draw.circle(screen, bag.color, bag.position, 8)
            elif current_time >= bag_start_times[j]:
                bag.move()
                pygame.draw.circle(screen, bag.color, bag.position, 8)
                still_moving = True 

        
        for gate_group in gate_entries:
            for gate in gate_group.gates:
                if gate.is_full():
                    res_id = gate.reservation
                    if res_id in reservations_f:  
                        reservations_f[res_id].time = current_time
                        reservations_c.append(reservations_f.pop(res_id))
                        '''
                        mask = (df['Reservation_ID'].astype(str) == str(res_id)) & (df['Last_Name'].astype(str) == str("Warren"))
                        if not df[mask].empty:
                            df.loc[mask, 'Luggage_Status'] = 'Ready for Pickup'
                            temp_file = '/tmp/luggage_dataset5.csv'
                            df.to_csv(temp_file, index=False)
                            s3.upload_file(temp_file, bucket_name, s3_object_name)
                            print(f"Updated status for {res_id} to ready and uploaded to S3.")'''
                            

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.is_full() and gate.dispense_time is None:
                    wait_seconds = random.randint(0, 70)/SPEED
                    gate.dispense_time = datetime.combine(datetime.today(), current_time) + timedelta(seconds=wait_seconds)
                            

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.dispense_time and current_time >= gate.dispense_time.time():
                    removed_bags = gate.clear_luggage()  
                    scanned_bags = [bag for bag in scanned_bags if bag not in removed_bags]  
                    print(f"Gate {gate_group.name} was emptied, and {len(removed_bags)} bags disappeared at {current_time}!")
                    gate.dispense_time = None  


        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.reservation == None: 
                    if not gate_group.res_queue.empty():
                        res = gate_group.res_queue.get() 
                        gate.set_reservation(res)

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if not bag.assigned_to_gate and bag.reservation == gate.reservation:
                    bag.append_path(gate.position)
                    bag.set_gate(gate)
                    bag.set_gate_name(gate)
                    bag.assigned_to_gate = True

        j+=1

    pygame.display.update()
    clock.tick(60) 

    
    if i >= len(conveyor_belt) and not still_moving:
        running = False  
        pygame.quit()
# Out:
# Gate 2 was emptied, and 2 bags disappeared at 02:28:00.320000!
# Gate 2 was emptied, and 2 bags disappeared at 02:28:09.560000!
# Gate 2 was emptied, and 2 bags disappeared at 02:28:40.720000!
# Gate 7 was emptied, and 7 bags disappeared at 02:28:47.740000!
# Gate 2 was emptied, and 2 bags disappeared at 02:28:54.380000!
# Gate 4 was emptied, and 4 bags disappeared at 02:28:54.380000!
# Gate 3 was emptied, and 3 bags disappeared at 02:28:54.720000!
# Gate 2 was emptied, and 2 bags disappeared at 02:29:01.060000!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:07.720000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:11.680000!
# Gate 7 was emptied, and 7 bags disappeared at 02:29:13.660000!
# Gate 2 was emptied, and 2 bags disappeared at 02:29:14!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:14.320000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:19.040000!
# Gate 5 was emptied, and 5 bags disappeared at 02:29:20.420000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:20.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:29:35.340000!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:37.020000!
# Gate 3 was emptied, and 3 bags disappeared at 02:29:37.340000!
# Gate 3 was emptied, and 3 bags disappeared at 02:29:40.640000!
# Gate 7 was emptied, and 7 bags disappeared at 02:29:41.960000!
# Gate 7 was emptied, and 7 bags disappeared at 02:29:43.300000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:44.340000!
# Gate 5 was emptied, and 5 bags disappeared at 02:29:45.680000!
# Gate 2 was emptied, and 2 bags disappeared at 02:29:47.340000!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:48.720000!
# Gate 2 was emptied, and 2 bags disappeared at 02:29:49.380000!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:50.420000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:51.440000!
# Gate 2 was emptied, and 2 bags disappeared at 02:29:54.100000!
# Gate 5 was emptied, and 5 bags disappeared at 02:29:54.760000!
# Gate 4 was emptied, and 4 bags disappeared at 02:29:56.420000!
# Gate 7 was emptied, and 7 bags disappeared at 02:29:57.460000!
# Gate 5 was emptied, and 5 bags disappeared at 02:29:58.440000!
# Gate 6 was emptied, and 6 bags disappeared at 02:29:59.760000!
# Gate 3 was emptied, and 3 bags disappeared at 02:30:04.040000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:06.980000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:06.980000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:11.300000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:13.600000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:14.260000!
# Gate 5 was emptied, and 5 bags disappeared at 02:30:14.580000!
# Gate 4 was emptied, and 4 bags disappeared at 02:30:15.600000!
# Gate 3 was emptied, and 3 bags disappeared at 02:30:16.960000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:20.560000!
# Gate 4 was emptied, and 4 bags disappeared at 02:30:21.220000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:21.900000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:25.600000!
# Gate 4 was emptied, and 4 bags disappeared at 02:30:26.220000!
# Gate 3 was emptied, and 3 bags disappeared at 02:30:26.900000!
# Gate 5 was emptied, and 5 bags disappeared at 02:30:28.220000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:28.220000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:29.560000!
# Gate 5 was emptied, and 5 bags disappeared at 02:30:31.960000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:32.660000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:35.340000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:37.400000!
# Gate 3 was emptied, and 3 bags disappeared at 02:30:39.400000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:39.400000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:43.420000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:48.720000!
# Gate 5 was emptied, and 5 bags disappeared at 02:30:49.040000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:51.340000!
# Gate 4 was emptied, and 4 bags disappeared at 02:30:51.980000!
# Gate 7 was emptied, and 7 bags disappeared at 02:30:53.020000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:53.340000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:54.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:30:55.660000!
# Gate 2 was emptied, and 2 bags disappeared at 02:30:58.360000!
# Gate 6 was emptied, and 6 bags disappeared at 02:30:59.680000!
# Gate 3 was emptied, and 3 bags disappeared at 02:31:01!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:01!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:04.340000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:04.340000!
# Gate 3 was emptied, and 3 bags disappeared at 02:31:04.660000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:05!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:10.040000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:10.700000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:11.680000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:12.700000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:14.340000!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:19.020000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:19.340000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:22.320000!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:22.660000!
# Gate 3 was emptied, and 3 bags disappeared at 02:31:22.660000!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:25.660000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:25.660000!
# Gate 3 was emptied, and 3 bags disappeared at 02:31:27.700000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:29.720000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:29.720000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:32.700000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:35.040000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:35.720000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:35.720000!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:39.420000!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:39.740000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:43.420000!
# Gate 3 was emptied, and 3 bags disappeared at 02:31:43.760000!
# Gate 5 was emptied, and 5 bags disappeared at 02:31:45.100000!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:45.460000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:47.780000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:48.440000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:48.780000!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:50.740000!
# Gate 4 was emptied, and 4 bags disappeared at 02:31:52.040000!
# Gate 2 was emptied, and 2 bags disappeared at 02:31:52.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:31:54.720000!
# Gate 6 was emptied, and 6 bags disappeared at 02:31:58.320000!
# Gate 7 was emptied, and 7 bags disappeared at 02:32:00.340000!
# Gate 6 was emptied, and 6 bags disappeared at 02:32:00.660000!
# Gate 3 was emptied, and 3 bags disappeared at 02:32:05.040000!
# Gate 6 was emptied, and 6 bags disappeared at 02:32:06.040000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:06.700000!
# Gate 3 was emptied, and 3 bags disappeared at 02:32:08.340000!
# Gate 7 was emptied, and 7 bags disappeared at 02:32:10.980000!
# Gate 3 was emptied, and 3 bags disappeared at 02:32:12!
# Gate 2 was emptied, and 2 bags disappeared at 02:32:14.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:16.740000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:17.400000!
# Gate 7 was emptied, and 7 bags disappeared at 02:32:19.720000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:20.380000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:21.740000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:22.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:32:24.060000!
# Gate 3 was emptied, and 3 bags disappeared at 02:32:24.720000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:44.080000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:45.420000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:47.360000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:50.360000!
# Gate 4 was emptied, and 4 bags disappeared at 02:32:53.020000!
# Gate 5 was emptied, and 5 bags disappeared at 02:32:59.400000!
# Gate 4 was emptied, and 4 bags disappeared at 02:33:18.080000!
# Gate 2 was emptied, and 2 bags disappeared at 02:40:23.260000!
# Gate 2 was emptied, and 2 bags disappeared at 02:41:08.020000!
# Gate 6 was emptied, and 6 bags disappeared at 02:41:13.640000!
# Gate 3 was emptied, and 3 bags disappeared at 02:41:14.620000!
# Gate 5 was emptied, and 5 bags disappeared at 02:41:25.200000!
# Gate 3 was emptied, and 3 bags disappeared at 02:41:26.500000!
# Gate 6 was emptied, and 6 bags disappeared at 02:41:30.540000!
# Gate 7 was emptied, and 7 bags disappeared at 02:41:32.200000!
# Gate 3 was emptied, and 3 bags disappeared at 02:41:34.520000!
# Gate 6 was emptied, and 6 bags disappeared at 02:41:40.500000!
# Gate 3 was emptied, and 3 bags disappeared at 02:41:41.460000!
# Gate 2 was emptied, and 2 bags disappeared at 02:41:42.440000!
# Gate 6 was emptied, and 6 bags disappeared at 02:41:52.380000!
# Gate 5 was emptied, and 5 bags disappeared at 02:41:59.300000!
# Gate 2 was emptied, and 2 bags disappeared at 02:42:01.640000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:06.320000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:12.940000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:15.960000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:18.320000!
# Gate 3 was emptied, and 3 bags disappeared at 02:42:19!
# Gate 5 was emptied, and 5 bags disappeared at 02:42:19!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:19!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:25.640000!
# Gate 2 was emptied, and 2 bags disappeared at 02:42:28.300000!
# Gate 3 was emptied, and 3 bags disappeared at 02:42:28.300000!
# Gate 2 was emptied, and 2 bags disappeared at 02:42:28.640000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:29.620000!
# Gate 4 was emptied, and 4 bags disappeared at 02:42:30.280000!
# Gate 5 was emptied, and 5 bags disappeared at 02:42:31.260000!
# Gate 3 was emptied, and 3 bags disappeared at 02:42:33.540000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:35.180000!
# Gate 5 was emptied, and 5 bags disappeared at 02:42:35.820000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:37.180000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:38.500000!
# Gate 4 was emptied, and 4 bags disappeared at 02:42:39.160000!
# Gate 4 was emptied, and 4 bags disappeared at 02:42:43.200000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:44.520000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:48.500000!
# Gate 3 was emptied, and 3 bags disappeared at 02:42:48.840000!
# Gate 5 was emptied, and 5 bags disappeared at 02:42:50.180000!
# Gate 2 was emptied, and 2 bags disappeared at 02:42:50.800000!
# Gate 6 was emptied, and 6 bags disappeared at 02:42:51.140000!
# Gate 2 was emptied, and 2 bags disappeared at 02:42:52.500000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:54.140000!
# Gate 7 was emptied, and 7 bags disappeared at 02:42:59.040000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:01.020000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:01.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:02.340000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:05.700000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:08.380000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:09.380000!
# Gate 2 was emptied, and 2 bags disappeared at 02:43:09.740000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:10.080000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:11.060000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:14.740000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:14.740000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:17.360000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:18.660000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:20.980000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:21.960000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:25.900000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:27.900000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:28.220000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:30.840000!
# Gate 2 was emptied, and 2 bags disappeared at 02:43:32.800000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:34.420000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:35.100000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:35.780000!
# Gate 2 was emptied, and 2 bags disappeared at 02:43:36.440000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:36.760000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:38.780000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:39.100000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:40.100000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:41.740000!
# Gate 2 was emptied, and 2 bags disappeared at 02:43:44.700000!
# Gate 5 was emptied, and 5 bags disappeared at 02:43:44.700000!
# Gate 7 was emptied, and 7 bags disappeared at 02:43:44.700000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:47.040000!
# Gate 4 was emptied, and 4 bags disappeared at 02:43:52.380000!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:55.680000!
# Gate 3 was emptied, and 3 bags disappeared at 02:43:56!
# Gate 6 was emptied, and 6 bags disappeared at 02:43:56.640000!
# Gate 6 was emptied, and 6 bags disappeared at 02:44:00.620000!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:01.320000!
# Gate 7 was emptied, and 7 bags disappeared at 02:44:03.660000!
# Gate 7 was emptied, and 7 bags disappeared at 02:44:05.040000!
# Gate 2 was emptied, and 2 bags disappeared at 02:44:07.020000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:10.340000!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:11.340000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:12.980000!
# Gate 2 was emptied, and 2 bags disappeared at 02:44:13.300000!
# Gate 6 was emptied, and 6 bags disappeared at 02:44:14!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:16.300000!
# Gate 6 was emptied, and 6 bags disappeared at 02:44:16.960000!
# Gate 2 was emptied, and 2 bags disappeared at 02:44:19.980000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:21.320000!
# Gate 6 was emptied, and 6 bags disappeared at 02:44:21.980000!
# Gate 3 was emptied, and 3 bags disappeared at 02:44:24.600000!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:31.260000!
# Gate 3 was emptied, and 3 bags disappeared at 02:44:31.920000!
# Gate 3 was emptied, and 3 bags disappeared at 02:44:33.900000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:41.840000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:43.180000!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:45.180000!
# Gate 4 was emptied, and 4 bags disappeared at 02:44:47.840000!
# Gate 3 was emptied, and 3 bags disappeared at 02:44:49.860000!
# Gate 2 was emptied, and 2 bags disappeared at 02:44:54.200000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:57.500000!
# Gate 2 was emptied, and 2 bags disappeared at 02:44:58.200000!
# Gate 5 was emptied, and 5 bags disappeared at 02:44:58.880000!
# Gate 2 was emptied, and 2 bags disappeared at 02:45:03.540000!
# Gate 4 was emptied, and 4 bags disappeared at 02:45:03.540000!
# Gate 2 was emptied, and 2 bags disappeared at 02:45:14.240000!
# Gate 3 was emptied, and 3 bags disappeared at 02:45:16.580000!
# Gate 5 was emptied, and 5 bags disappeared at 02:45:19.280000!
# Gate 3 was emptied, and 3 bags disappeared at 02:45:21.280000!
# Gate 4 was emptied, and 4 bags disappeared at 02:45:21.280000!
# Gate 4 was emptied, and 4 bags disappeared at 02:45:23.280000!
# Gate 2 was emptied, and 2 bags disappeared at 02:45:23.940000!
# Gate 3 was emptied, and 3 bags disappeared at 02:45:24.620000!
# Gate 2 was emptied, and 2 bags disappeared at 02:45:31.640000!
# Gate 5 was emptied, and 5 bags disappeared at 02:45:32.320000!
# Gate 5 was emptied, and 5 bags disappeared at 02:45:38.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:45:39.700000!
# Gate 3 was emptied, and 3 bags disappeared at 02:45:46.040000!
# Gate 3 was emptied, and 3 bags disappeared at 02:45:47.700000!
# Gate 2 was emptied, and 2 bags disappeared at 02:45:55!
# Gate 5 was emptied, and 5 bags disappeared at 02:45:56.680000!
# Gate 3 was emptied, and 3 bags disappeared at 02:46:11.260000!
# Gate 3 was emptied, and 3 bags disappeared at 02:46:23.260000!
# Gate 3 was emptied, and 3 bags disappeared at 02:46:26.940000!
# Gate 4 was emptied, and 4 bags disappeared at 02:53:08.120000!
# Gate 3 was emptied, and 3 bags disappeared at 02:54:24.860000!
# Gate 5 was emptied, and 5 bags disappeared at 02:54:33.840000!
# Gate 3 was emptied, and 3 bags disappeared at 02:54:37.200000!
# Gate 7 was emptied, and 7 bags disappeared at 02:54:42.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:54:56.680000!
# Gate 3 was emptied, and 3 bags disappeared at 02:55:04.320000!
# Gate 4 was emptied, and 4 bags disappeared at 02:55:04.320000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:07.340000!
# Gate 3 was emptied, and 3 bags disappeared at 02:55:12.740000!
# Gate 5 was emptied, and 5 bags disappeared at 02:55:15.400000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:19.120000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:26.500000!
# Gate 2 was emptied, and 2 bags disappeared at 02:55:28.160000!
# Gate 6 was emptied, and 6 bags disappeared at 02:55:29.180000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:31.520000!
# Gate 4 was emptied, and 4 bags disappeared at 02:55:37.540000!
# Gate 6 was emptied, and 6 bags disappeared at 02:55:37.540000!
# Gate 2 was emptied, and 2 bags disappeared at 02:55:44.140000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:45.140000!
# Gate 2 was emptied, and 2 bags disappeared at 02:55:50.440000!
# Gate 5 was emptied, and 5 bags disappeared at 02:55:51.800000!
# Gate 6 was emptied, and 6 bags disappeared at 02:55:52.120000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:52.120000!
# Gate 4 was emptied, and 4 bags disappeared at 02:55:52.420000!
# Gate 5 was emptied, and 5 bags disappeared at 02:55:53.760000!
# Gate 6 was emptied, and 6 bags disappeared at 02:55:55.100000!
# Gate 7 was emptied, and 7 bags disappeared at 02:55:57.440000!
# Gate 3 was emptied, and 3 bags disappeared at 02:55:58.440000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:00.760000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:01.440000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:01.780000!
# Gate 4 was emptied, and 4 bags disappeared at 02:56:04.120000!
# Gate 5 was emptied, and 5 bags disappeared at 02:56:04.460000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:05.480000!
# Gate 4 was emptied, and 4 bags disappeared at 02:56:10.480000!
# Gate 2 was emptied, and 2 bags disappeared at 02:56:12.780000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:13.440000!
# Gate 2 was emptied, and 2 bags disappeared at 02:56:14.120000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:18.160000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:19.800000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:20.500000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:22.760000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:24.120000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:24.780000!
# Gate 2 was emptied, and 2 bags disappeared at 02:56:28.420000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:29.740000!
# Gate 5 was emptied, and 5 bags disappeared at 02:56:30.080000!
# Gate 4 was emptied, and 4 bags disappeared at 02:56:31.100000!
# Gate 5 was emptied, and 5 bags disappeared at 02:56:32.780000!
# Gate 5 was emptied, and 5 bags disappeared at 02:56:34.120000!
# Gate 2 was emptied, and 2 bags disappeared at 02:56:36.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:37.100000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:39.780000!
# Gate 2 was emptied, and 2 bags disappeared at 02:56:43.140000!
# Gate 4 was emptied, and 4 bags disappeared at 02:56:43.140000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:44.120000!
# Gate 4 was emptied, and 4 bags disappeared at 02:56:44.780000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:45.400000!
# Gate 7 was emptied, and 7 bags disappeared at 02:56:47.040000!
# Gate 6 was emptied, and 6 bags disappeared at 02:56:48.040000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:49.720000!
# Gate 3 was emptied, and 3 bags disappeared at 02:56:59.120000!
# Gate 3 was emptied, and 3 bags disappeared at 02:57:00.120000!
# Gate 7 was emptied, and 7 bags disappeared at 02:57:03.100000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:04.380000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:05.360000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:05.360000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:06.680000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:07.680000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:08.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:08.340000!
# Gate 7 was emptied, and 7 bags disappeared at 02:57:08.340000!
# Gate 7 was emptied, and 7 bags disappeared at 02:57:09.360000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:14.020000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:15.040000!
# Gate 2 was emptied, and 2 bags disappeared at 02:57:15.360000!
# Gate 2 was emptied, and 2 bags disappeared at 02:57:17.020000!
# Gate 2 was emptied, and 2 bags disappeared at 02:57:18.720000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:22.740000!
# Gate 7 was emptied, and 7 bags disappeared at 02:57:23.400000!
# Gate 3 was emptied, and 3 bags disappeared at 02:57:27.400000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:28.700000!
# Gate 3 was emptied, and 3 bags disappeared at 02:57:33.740000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:37.780000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:39.780000!
# Gate 3 was emptied, and 3 bags disappeared at 02:57:40.100000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:40.100000!
# Gate 2 was emptied, and 2 bags disappeared at 02:57:40.420000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:40.420000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:41.760000!
# Gate 5 was emptied, and 5 bags disappeared at 02:57:41.760000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:46.800000!
# Gate 2 was emptied, and 2 bags disappeared at 02:57:49.140000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:50.520000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:53.500000!
# Gate 6 was emptied, and 6 bags disappeared at 02:57:57.200000!
# Gate 4 was emptied, and 4 bags disappeared at 02:57:57.540000!
# Gate 2 was emptied, and 2 bags disappeared at 02:58:02.140000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:03.800000!
# Gate 6 was emptied, and 6 bags disappeared at 02:58:03.800000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:06.480000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:10.220000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:10.580000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:10.920000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:13.220000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:13.900000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:14.220000!
# Gate 6 was emptied, and 6 bags disappeared at 02:58:16.900000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:19.880000!
# Gate 2 was emptied, and 2 bags disappeared at 02:58:20.880000!
# Gate 2 was emptied, and 2 bags disappeared at 02:58:27.180000!
# Gate 2 was emptied, and 2 bags disappeared at 02:58:33.140000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:38.700000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:44.280000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:46.580000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:46.580000!
# Gate 4 was emptied, and 4 bags disappeared at 02:58:49.580000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:49.920000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:50.240000!
# Gate 5 was emptied, and 5 bags disappeared at 02:58:53.500000!
# Gate 3 was emptied, and 3 bags disappeared at 02:58:57.820000!
# Gate 4 was emptied, and 4 bags disappeared at 02:59:09.220000!
# Gate 4 was emptied, and 4 bags disappeared at 02:59:13.600000!
# Gate 3 was emptied, and 3 bags disappeared at 02:59:15.620000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:16.260000!
# Gate 3 was emptied, and 3 bags disappeared at 02:59:17.260000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:19.260000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:20.960000!
# Gate 4 was emptied, and 4 bags disappeared at 02:59:22.280000!
# Gate 4 was emptied, and 4 bags disappeared at 02:59:35.280000!
# Gate 3 was emptied, and 3 bags disappeared at 02:59:36.300000!
# Gate 4 was emptied, and 4 bags disappeared at 02:59:45.280000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:52.960000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:54.600000!
# Gate 5 was emptied, and 5 bags disappeared at 02:59:59.620000!
# Gate 3 was emptied, and 3 bags disappeared at 02:59:59.940000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:04.620000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:08.600000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:17.240000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:22.280000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:36.280000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:47.520000!
# Gate 3 was emptied, and 3 bags disappeared at 03:00:52.800000!

# %%
for res in reservations_c:
    flight_time_obj = datetime.strptime(res.flight_time, "%H:%M" if len(res.flight_time) == 5 else "%H:%M:%S").time()

    served_dt = datetime.combine(datetime.today(), res.time)
    flight_dt = datetime.combine(datetime.today(), flight_time_obj)
    res.time = served_dt - flight_dt

    print(res)
# Out:
# Reservation ID: RES-00074, Cluster Size: 2, Time: 0:01:59.980000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00061, Cluster Size: 2, Time: 0:02:09.240000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00020, Cluster Size: 2, Time: 0:02:40.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00059, Cluster Size: 7, Time: 0:02:47.080000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00417, Cluster Size: 2, Time: 0:02:53.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00331, Cluster Size: 4, Time: 0:02:53.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00010, Cluster Size: 3, Time: 0:02:54.380000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00035, Cluster Size: 2, Time: 0:03:00.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00077, Cluster Size: 6, Time: 0:03:06.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00048, Cluster Size: 4, Time: 0:03:11.360000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00456, Cluster Size: 7, Time: 0:03:13.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00040, Cluster Size: 2, Time: 0:03:13.660000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00022, Cluster Size: 6, Time: 0:03:14, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00019, Cluster Size: 4, Time: 0:03:18.700000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00039, Cluster Size: 5, Time: 0:03:19.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00397, Cluster Size: 4, Time: 0:03:20.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00050, Cluster Size: 7, Time: 0:03:35, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00371, Cluster Size: 6, Time: 0:03:36.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00068, Cluster Size: 3, Time: 0:03:36.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00055, Cluster Size: 3, Time: 0:03:40.320000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00001, Cluster Size: 7, Time: 0:03:41.620000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00459, Cluster Size: 7, Time: 0:03:42.960000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00046, Cluster Size: 4, Time: 0:03:43.660000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00462, Cluster Size: 5, Time: 0:03:45, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00436, Cluster Size: 2, Time: 0:03:47.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00362, Cluster Size: 6, Time: 0:03:48.060000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00016, Cluster Size: 2, Time: 0:03:49.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00038, Cluster Size: 6, Time: 0:03:49.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00272, Cluster Size: 4, Time: 0:03:50.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00057, Cluster Size: 2, Time: 0:03:53.440000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00029, Cluster Size: 5, Time: 0:03:54.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00027, Cluster Size: 4, Time: 0:03:55.760000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00047, Cluster Size: 7, Time: 0:03:56.780000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00065, Cluster Size: 5, Time: 0:03:58.120000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00075, Cluster Size: 6, Time: 0:03:59.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00292, Cluster Size: 3, Time: 0:04:03.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00007, Cluster Size: 7, Time: 0:04:06, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00305, Cluster Size: 7, Time: 0:04:06.320000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00058, Cluster Size: 6, Time: 0:04:10.300000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00008, Cluster Size: 6, Time: 0:04:12.920000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00041, Cluster Size: 2, Time: 0:04:13.920000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00051, Cluster Size: 5, Time: 0:04:14.260000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00067, Cluster Size: 4, Time: 0:04:14.940000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00414, Cluster Size: 3, Time: 0:04:16.600000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00277, Cluster Size: 7, Time: 0:04:20.220000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00439, Cluster Size: 4, Time: 0:04:20.560000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00053, Cluster Size: 2, Time: 0:04:21.220000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00013, Cluster Size: 6, Time: 0:04:25.280000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00033, Cluster Size: 4, Time: 0:04:25.940000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00313, Cluster Size: 3, Time: 0:04:26.220000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00023, Cluster Size: 5, Time: 0:04:27.880000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00375, Cluster Size: 7, Time: 0:04:27.880000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00081, Cluster Size: 2, Time: 0:04:28.900000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00274, Cluster Size: 5, Time: 0:04:31.260000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00045, Cluster Size: 7, Time: 0:04:32.300000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00315, Cluster Size: 6, Time: 0:04:35.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00256, Cluster Size: 2, Time: 0:04:36.700000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00408, Cluster Size: 6, Time: 0:04:38.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00265, Cluster Size: 3, Time: 0:04:39.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00382, Cluster Size: 7, Time: 0:04:43.120000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00015, Cluster Size: 7, Time: 0:04:48.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00352, Cluster Size: 5, Time: 0:04:48.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00004, Cluster Size: 6, Time: 0:04:51, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00335, Cluster Size: 4, Time: 0:04:51.980000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00062, Cluster Size: 7, Time: 0:04:52.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00365, Cluster Size: 2, Time: 0:04:52.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00321, Cluster Size: 6, Time: 0:04:53.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00021, Cluster Size: 4, Time: 0:04:55.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00311, Cluster Size: 2, Time: 0:04:58.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00043, Cluster Size: 6, Time: 0:04:59.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00054, Cluster Size: 5, Time: 0:05:00.360000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00423, Cluster Size: 3, Time: 0:05:00.700000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00344, Cluster Size: 7, Time: 0:05:03.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00037, Cluster Size: 5, Time: 0:05:03.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00293, Cluster Size: 3, Time: 0:05:04.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00291, Cluster Size: 4, Time: 0:05:04.660000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00336, Cluster Size: 2, Time: 0:05:09.700000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00348, Cluster Size: 7, Time: 0:05:10.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00302, Cluster Size: 4, Time: 0:05:11.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00416, Cluster Size: 7, Time: 0:05:12.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00359, Cluster Size: 6, Time: 0:05:13.700000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00009, Cluster Size: 5, Time: 0:05:18.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00287, Cluster Size: 6, Time: 0:05:19.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00063, Cluster Size: 6, Time: 0:05:21.660000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00398, Cluster Size: 3, Time: 0:05:21.980000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00295, Cluster Size: 2, Time: 0:05:21.980000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00307, Cluster Size: 2, Time: 0:05:25.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00018, Cluster Size: 7, Time: 0:05:25.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00003, Cluster Size: 3, Time: 0:05:27.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00002, Cluster Size: 4, Time: 0:05:29.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00069, Cluster Size: 7, Time: 0:05:29.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00072, Cluster Size: 6, Time: 0:05:32.380000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00064, Cluster Size: 6, Time: 0:05:35.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00443, Cluster Size: 7, Time: 0:05:35.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00447, Cluster Size: 4, Time: 0:05:35.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00420, Cluster Size: 5, Time: 0:05:39.080000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00071, Cluster Size: 5, Time: 0:05:39.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00285, Cluster Size: 4, Time: 0:05:43.080000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00429, Cluster Size: 3, Time: 0:05:43.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00066, Cluster Size: 5, Time: 0:05:44.440000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00460, Cluster Size: 2, Time: 0:05:45.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00014, Cluster Size: 6, Time: 0:05:47.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00060, Cluster Size: 4, Time: 0:05:47.780000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00006, Cluster Size: 7, Time: 0:05:48.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00049, Cluster Size: 2, Time: 0:05:50.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00387, Cluster Size: 4, Time: 0:05:51.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00440, Cluster Size: 2, Time: 0:05:52.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00080, Cluster Size: 7, Time: 0:05:54.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00034, Cluster Size: 6, Time: 0:05:58, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00036, Cluster Size: 7, Time: 0:05:59.660000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00427, Cluster Size: 6, Time: 0:05:59.980000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00358, Cluster Size: 3, Time: 0:06:04.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00412, Cluster Size: 6, Time: 0:06:05.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00078, Cluster Size: 5, Time: 0:06:06.360000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00026, Cluster Size: 3, Time: 0:06:08, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00402, Cluster Size: 7, Time: 0:06:10.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00005, Cluster Size: 3, Time: 0:06:11.620000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00042, Cluster Size: 2, Time: 0:06:13.340000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00012, Cluster Size: 4, Time: 0:06:16.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00361, Cluster Size: 5, Time: 0:06:16.740000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00079, Cluster Size: 7, Time: 0:06:19.060000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00298, Cluster Size: 4, Time: 0:06:19.720000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00030, Cluster Size: 4, Time: 0:06:21.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00073, Cluster Size: 5, Time: 0:06:22.080000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00257, Cluster Size: 7, Time: 0:06:23.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00270, Cluster Size: 3, Time: 0:06:24.060000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00271, Cluster Size: 5, Time: 0:06:43.400000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00306, Cluster Size: 4, Time: 0:06:45.100000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00434, Cluster Size: 4, Time: 0:06:47.040000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00028, Cluster Size: 5, Time: 0:06:50.020000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00399, Cluster Size: 4, Time: 0:06:52.680000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00024, Cluster Size: 5, Time: 0:06:58.380000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00076, Cluster Size: 4, Time: 0:07:17.420000, Flight time: 02:26, Flight number: SV8120
# Reservation ID: RES-00278, Cluster Size: 2, Time: 0:01:22.600000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00391, Cluster Size: 2, Time: 0:02:07.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00148, Cluster Size: 6, Time: 0:02:12.980000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00379, Cluster Size: 3, Time: 0:02:13.960000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00154, Cluster Size: 5, Time: 0:02:24.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00128, Cluster Size: 3, Time: 0:02:26.140000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00085, Cluster Size: 6, Time: 0:02:30.200000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00143, Cluster Size: 7, Time: 0:02:31.540000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00157, Cluster Size: 3, Time: 0:02:33.560000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00153, Cluster Size: 6, Time: 0:02:40.140000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00115, Cluster Size: 3, Time: 0:02:40.820000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00160, Cluster Size: 2, Time: 0:02:41.780000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00159, Cluster Size: 6, Time: 0:02:51.700000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00155, Cluster Size: 5, Time: 0:02:58.960000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00349, Cluster Size: 2, Time: 0:03:01.300000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00353, Cluster Size: 6, Time: 0:03:05.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00356, Cluster Size: 7, Time: 0:03:12.620000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00164, Cluster Size: 7, Time: 0:03:15.300000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00136, Cluster Size: 6, Time: 0:03:17.620000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00451, Cluster Size: 3, Time: 0:03:18.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00419, Cluster Size: 5, Time: 0:03:18.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00091, Cluster Size: 7, Time: 0:03:18.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00308, Cluster Size: 6, Time: 0:03:25.320000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00086, Cluster Size: 2, Time: 0:03:27.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00444, Cluster Size: 3, Time: 0:03:27.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00415, Cluster Size: 2, Time: 0:03:27.980000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00118, Cluster Size: 6, Time: 0:03:29.260000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00150, Cluster Size: 4, Time: 0:03:29.620000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00138, Cluster Size: 5, Time: 0:03:30.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00396, Cluster Size: 3, Time: 0:03:32.560000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00165, Cluster Size: 7, Time: 0:03:34.520000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00392, Cluster Size: 5, Time: 0:03:35.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00121, Cluster Size: 7, Time: 0:03:36.820000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00151, Cluster Size: 7, Time: 0:03:37.840000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00253, Cluster Size: 4, Time: 0:03:38.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00087, Cluster Size: 4, Time: 0:03:42.860000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00328, Cluster Size: 6, Time: 0:03:43.880000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00320, Cluster Size: 6, Time: 0:03:48.180000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00094, Cluster Size: 3, Time: 0:03:48.180000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00141, Cluster Size: 5, Time: 0:03:49.520000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00442, Cluster Size: 6, Time: 0:03:50.180000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00111, Cluster Size: 2, Time: 0:03:50.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00093, Cluster Size: 2, Time: 0:03:52.120000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00339, Cluster Size: 7, Time: 0:03:54.140000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00156, Cluster Size: 7, Time: 0:03:58.740000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00082, Cluster Size: 7, Time: 0:04:00.060000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00432, Cluster Size: 5, Time: 0:04:00.700000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00095, Cluster Size: 4, Time: 0:04:02.020000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00309, Cluster Size: 5, Time: 0:04:05.020000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00428, Cluster Size: 4, Time: 0:04:08.060000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00301, Cluster Size: 6, Time: 0:04:08.700000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00135, Cluster Size: 2, Time: 0:04:09.380000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00448, Cluster Size: 3, Time: 0:04:09.740000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00112, Cluster Size: 6, Time: 0:04:10.080000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00119, Cluster Size: 3, Time: 0:04:14.400000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00090, Cluster Size: 5, Time: 0:04:14.400000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00104, Cluster Size: 6, Time: 0:04:16.680000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00152, Cluster Size: 7, Time: 0:04:18, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00088, Cluster Size: 7, Time: 0:04:20.320000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00334, Cluster Size: 4, Time: 0:04:21.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00288, Cluster Size: 7, Time: 0:04:25.260000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00126, Cluster Size: 4, Time: 0:04:27.240000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00364, Cluster Size: 3, Time: 0:04:27.900000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00140, Cluster Size: 6, Time: 0:04:30.520000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00269, Cluster Size: 2, Time: 0:04:32.140000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00411, Cluster Size: 6, Time: 0:04:34.100000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00109, Cluster Size: 4, Time: 0:04:34.420000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00134, Cluster Size: 5, Time: 0:04:35.100000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00326, Cluster Size: 5, Time: 0:04:36.100000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00089, Cluster Size: 2, Time: 0:04:36.100000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00323, Cluster Size: 7, Time: 0:04:38.120000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00282, Cluster Size: 6, Time: 0:04:38.440000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00102, Cluster Size: 7, Time: 0:04:39.420000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00127, Cluster Size: 3, Time: 0:04:41.100000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00317, Cluster Size: 2, Time: 0:04:44.020000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00084, Cluster Size: 5, Time: 0:04:44.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00123, Cluster Size: 7, Time: 0:04:44.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00133, Cluster Size: 3, Time: 0:04:46.720000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00142, Cluster Size: 4, Time: 0:04:52.020000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00146, Cluster Size: 6, Time: 0:04:55, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00345, Cluster Size: 3, Time: 0:04:55.680000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00351, Cluster Size: 6, Time: 0:04:56.300000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00108, Cluster Size: 6, Time: 0:04:59.980000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00096, Cluster Size: 4, Time: 0:05:00.980000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00161, Cluster Size: 7, Time: 0:05:03, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00116, Cluster Size: 7, Time: 0:05:04.340000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00299, Cluster Size: 2, Time: 0:05:06.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00393, Cluster Size: 5, Time: 0:05:09.680000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00145, Cluster Size: 4, Time: 0:05:10.680000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00446, Cluster Size: 5, Time: 0:05:12.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00461, Cluster Size: 2, Time: 0:05:12.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00092, Cluster Size: 6, Time: 0:05:13.660000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00279, Cluster Size: 4, Time: 0:05:15.960000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00333, Cluster Size: 6, Time: 0:05:16.620000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00410, Cluster Size: 2, Time: 0:05:19.300000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00162, Cluster Size: 5, Time: 0:05:20.660000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00137, Cluster Size: 6, Time: 0:05:21.640000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00390, Cluster Size: 3, Time: 0:05:23.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00149, Cluster Size: 4, Time: 0:05:30.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00261, Cluster Size: 3, Time: 0:05:31.580000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00449, Cluster Size: 3, Time: 0:05:33.220000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00139, Cluster Size: 5, Time: 0:05:41.160000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00280, Cluster Size: 5, Time: 0:05:42.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00297, Cluster Size: 4, Time: 0:05:44.860000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00340, Cluster Size: 4, Time: 0:05:47.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00322, Cluster Size: 3, Time: 0:05:49.520000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00100, Cluster Size: 2, Time: 0:05:53.880000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00147, Cluster Size: 5, Time: 0:05:57.180000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00105, Cluster Size: 2, Time: 0:05:57.500000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00113, Cluster Size: 5, Time: 0:05:58.540000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00394, Cluster Size: 4, Time: 0:06:02.560000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00103, Cluster Size: 2, Time: 0:06:02.900000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00125, Cluster Size: 2, Time: 0:06:13.920000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00324, Cluster Size: 3, Time: 0:06:16.240000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00129, Cluster Size: 5, Time: 0:06:18.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00373, Cluster Size: 3, Time: 0:06:20.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00107, Cluster Size: 4, Time: 0:06:20.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00099, Cluster Size: 4, Time: 0:06:22.960000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00114, Cluster Size: 2, Time: 0:06:23.620000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00117, Cluster Size: 3, Time: 0:06:23.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00158, Cluster Size: 2, Time: 0:06:31.320000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00437, Cluster Size: 5, Time: 0:06:31.980000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00343, Cluster Size: 5, Time: 0:06:37.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00083, Cluster Size: 4, Time: 0:06:39.020000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00325, Cluster Size: 3, Time: 0:06:45.720000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00341, Cluster Size: 3, Time: 0:06:47.060000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00384, Cluster Size: 2, Time: 0:06:54.360000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00130, Cluster Size: 5, Time: 0:06:56, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00263, Cluster Size: 3, Time: 0:07:11.260000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00106, Cluster Size: 3, Time: 0:07:22.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00276, Cluster Size: 3, Time: 0:07:25.940000, Flight time: 02:39, Flight number: AA2134
# Reservation ID: RES-00354, Cluster Size: 4, Time: 0:01:07.480000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00300, Cluster Size: 3, Time: 0:02:24.160000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00294, Cluster Size: 5, Time: 0:02:33.500000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00226, Cluster Size: 3, Time: 0:02:36.860000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00175, Cluster Size: 7, Time: 0:02:42.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00319, Cluster Size: 7, Time: 0:02:56.360000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00404, Cluster Size: 3, Time: 0:03:03.620000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00238, Cluster Size: 4, Time: 0:03:03.620000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00198, Cluster Size: 7, Time: 0:03:06.680000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00369, Cluster Size: 3, Time: 0:03:12.060000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00196, Cluster Size: 5, Time: 0:03:14.740000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00389, Cluster Size: 7, Time: 0:03:18.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00407, Cluster Size: 7, Time: 0:03:25.820000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00262, Cluster Size: 2, Time: 0:03:27.520000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00236, Cluster Size: 6, Time: 0:03:28.840000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00191, Cluster Size: 7, Time: 0:03:31.180000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00232, Cluster Size: 4, Time: 0:03:36.860000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00171, Cluster Size: 6, Time: 0:03:37.180000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00234, Cluster Size: 2, Time: 0:03:43.500000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00405, Cluster Size: 7, Time: 0:03:44.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00431, Cluster Size: 2, Time: 0:03:50.120000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00245, Cluster Size: 5, Time: 0:03:51.120000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00246, Cluster Size: 7, Time: 0:03:51.480000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00400, Cluster Size: 6, Time: 0:03:51.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00254, Cluster Size: 4, Time: 0:03:51.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00182, Cluster Size: 5, Time: 0:03:53.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00438, Cluster Size: 6, Time: 0:03:54.420000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00312, Cluster Size: 7, Time: 0:03:56.780000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00188, Cluster Size: 3, Time: 0:03:58.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00289, Cluster Size: 6, Time: 0:04:00.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00260, Cluster Size: 3, Time: 0:04:00.760000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00304, Cluster Size: 3, Time: 0:04:01.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00206, Cluster Size: 4, Time: 0:04:03.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00388, Cluster Size: 5, Time: 0:04:04.120000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00220, Cluster Size: 7, Time: 0:04:04.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00204, Cluster Size: 4, Time: 0:04:09.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00244, Cluster Size: 2, Time: 0:04:11.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00214, Cluster Size: 7, Time: 0:04:13.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00413, Cluster Size: 2, Time: 0:04:13.780000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00212, Cluster Size: 6, Time: 0:04:17.820000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00205, Cluster Size: 3, Time: 0:04:19.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00296, Cluster Size: 6, Time: 0:04:19.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00425, Cluster Size: 7, Time: 0:04:22.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00233, Cluster Size: 6, Time: 0:04:23.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00168, Cluster Size: 3, Time: 0:04:24.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00170, Cluster Size: 2, Time: 0:04:27.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00209, Cluster Size: 7, Time: 0:04:29.080000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00338, Cluster Size: 5, Time: 0:04:29.400000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00418, Cluster Size: 4, Time: 0:04:30.400000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00176, Cluster Size: 5, Time: 0:04:32.080000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00385, Cluster Size: 5, Time: 0:04:33.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00266, Cluster Size: 2, Time: 0:04:36.420000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00357, Cluster Size: 7, Time: 0:04:36.420000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00184, Cluster Size: 6, Time: 0:04:39.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00316, Cluster Size: 2, Time: 0:04:42.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00225, Cluster Size: 4, Time: 0:04:42.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00207, Cluster Size: 6, Time: 0:04:43.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00229, Cluster Size: 4, Time: 0:04:44.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00380, Cluster Size: 7, Time: 0:04:44.780000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00224, Cluster Size: 7, Time: 0:04:46.400000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00177, Cluster Size: 6, Time: 0:04:47.380000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00231, Cluster Size: 3, Time: 0:04:49.040000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00342, Cluster Size: 3, Time: 0:04:59.120000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00215, Cluster Size: 3, Time: 0:04:59.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00241, Cluster Size: 7, Time: 0:05:02.400000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00216, Cluster Size: 6, Time: 0:05:04.060000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00252, Cluster Size: 5, Time: 0:05:04.380000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00455, Cluster Size: 6, Time: 0:05:05.020000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00201, Cluster Size: 4, Time: 0:05:06.020000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00383, Cluster Size: 5, Time: 0:05:07.340000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00235, Cluster Size: 5, Time: 0:05:07.340000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00273, Cluster Size: 7, Time: 0:05:07.340000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00454, Cluster Size: 4, Time: 0:05:07.680000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00403, Cluster Size: 7, Time: 0:05:09, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00463, Cluster Size: 6, Time: 0:05:13.700000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00346, Cluster Size: 2, Time: 0:05:14.700000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00452, Cluster Size: 4, Time: 0:05:14.700000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00258, Cluster Size: 2, Time: 0:05:16.700000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00386, Cluster Size: 2, Time: 0:05:18.400000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00330, Cluster Size: 6, Time: 0:05:22.360000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00267, Cluster Size: 7, Time: 0:05:23.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00167, Cluster Size: 3, Time: 0:05:27.080000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00249, Cluster Size: 6, Time: 0:05:28.360000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00370, Cluster Size: 3, Time: 0:05:32.720000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00290, Cluster Size: 6, Time: 0:05:37.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00355, Cluster Size: 4, Time: 0:05:39.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00426, Cluster Size: 3, Time: 0:05:39.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00378, Cluster Size: 5, Time: 0:05:39.780000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00172, Cluster Size: 5, Time: 0:05:40.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00211, Cluster Size: 2, Time: 0:05:40.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00183, Cluster Size: 4, Time: 0:05:41.080000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00255, Cluster Size: 5, Time: 0:05:41.420000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00250, Cluster Size: 6, Time: 0:05:46.100000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00228, Cluster Size: 2, Time: 0:05:48.460000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00376, Cluster Size: 4, Time: 0:05:49.820000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00199, Cluster Size: 6, Time: 0:05:52.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00210, Cluster Size: 4, Time: 0:05:56.860000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00219, Cluster Size: 6, Time: 0:05:56.860000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00221, Cluster Size: 2, Time: 0:06:01.500000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00195, Cluster Size: 3, Time: 0:06:03.140000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00283, Cluster Size: 6, Time: 0:06:03.480000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00240, Cluster Size: 3, Time: 0:06:05.820000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00181, Cluster Size: 5, Time: 0:06:09.900000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00223, Cluster Size: 3, Time: 0:06:10.220000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00381, Cluster Size: 4, Time: 0:06:10.580000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00422, Cluster Size: 5, Time: 0:06:12.560000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00202, Cluster Size: 4, Time: 0:06:13.580000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00329, Cluster Size: 4, Time: 0:06:13.580000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00237, Cluster Size: 6, Time: 0:06:16.580000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00213, Cluster Size: 5, Time: 0:06:18.900000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00200, Cluster Size: 2, Time: 0:06:20.540000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00242, Cluster Size: 2, Time: 0:06:26.840000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00327, Cluster Size: 2, Time: 0:06:32.800000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00189, Cluster Size: 4, Time: 0:06:38.060000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00310, Cluster Size: 5, Time: 0:06:43.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00192, Cluster Size: 4, Time: 0:06:46.240000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00367, Cluster Size: 3, Time: 0:06:46.240000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00208, Cluster Size: 4, Time: 0:06:48.900000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00190, Cluster Size: 3, Time: 0:06:49.220000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00377, Cluster Size: 5, Time: 0:06:49.920000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00186, Cluster Size: 5, Time: 0:06:52.840000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00227, Cluster Size: 3, Time: 0:06:57.480000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00284, Cluster Size: 4, Time: 0:07:08.900000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00194, Cluster Size: 4, Time: 0:07:12.900000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00395, Cluster Size: 3, Time: 0:07:14.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00441, Cluster Size: 5, Time: 0:07:15.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00251, Cluster Size: 3, Time: 0:07:16.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00401, Cluster Size: 5, Time: 0:07:18.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00174, Cluster Size: 5, Time: 0:07:20.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00406, Cluster Size: 4, Time: 0:07:21.620000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00179, Cluster Size: 4, Time: 0:07:34.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00185, Cluster Size: 3, Time: 0:07:35.960000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00193, Cluster Size: 4, Time: 0:07:44.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00275, Cluster Size: 5, Time: 0:07:52.620000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00350, Cluster Size: 5, Time: 0:07:53.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00239, Cluster Size: 5, Time: 0:07:58.640000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00424, Cluster Size: 3, Time: 0:07:59.300000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00169, Cluster Size: 3, Time: 0:08:04.280000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00450, Cluster Size: 3, Time: 0:08:07.920000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00217, Cluster Size: 3, Time: 0:08:16.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00222, Cluster Size: 3, Time: 0:08:21.940000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00187, Cluster Size: 3, Time: 0:08:35.600000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00178, Cluster Size: 3, Time: 0:08:47.200000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00166, Cluster Size: 3, Time: 0:08:52.440000, Flight time: 02:52, Flight number: BA1796
# Reservation ID: RES-00421, Cluster Size: 3, Time: 0:08:53.440000, Flight time: 02:52, Flight number: BA1796

# %%
bag_time_map = {}
for bag in conveyor_belt:
    # Make sure these are Python strings "HH:MM:SS"
    est = bag.estimated_time
    act = getattr(bag, "actual_time", None)
    # If est/act are datetime.time or timedelta, convert them now:
    if hasattr(est, "strftime"):
        est = est.strftime("%H:%M:%S")
    if hasattr(act, "strftime"):
        act = act.strftime("%H:%M:%S")
    bag_time_map[bag.bag_id] = (est, act)

'''
s3 = boto3.client("s3")
bucket = "trackage.1"
key = "database.csv"

obj = s3.get_object(Bucket=bucket, Key=key)
df = pd.read_csv(obj["Body"], on_bad_lines="skip")
'''
gate_name_map = {str(bag.bag_id): bag.gate_name for bag in conveyor_belt}
df["Bag_ID"] = df["Bag_ID"].astype(str)
df["Pickup_Gate"] = df["Bag_ID"].map(gate_name_map)


df["Estimated_Arrival_Time"] = df["Bag_ID"].map(lambda bid: bag_time_map.get(bid, ("", ""))[0])
df["Actual_Arrival_Time"]    = df["Bag_ID"].map(lambda bid: bag_time_map.get(bid, ("", ""))[1])
df["Flight_Arrival_Time"] = (
    pd.to_datetime(df["Flight_Arrival_Time"], format="%H:%M", errors="coerce")
      .subtract(pd.Timedelta(minutes=15))
      .dt.strftime("%H:%M")
)


out_tmp     = "/tmp/luggage_dataset.csv"
out_desktop = os.path.join(os.path.expanduser("~"), "Desktop", "luggage_dataset5.csv")

df.to_csv(out_tmp, index=False)
df.to_csv(out_desktop, index=False)
'''
s3.upload_file(out_tmp, bucket, key)
print("Saved to:", out_desktop)
print(f"Uploaded back to s3://{bucket}/{key}")'''
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 38
#      35 out_tmp     = "/tmp/luggage_dataset.csv"
#      36 out_desktop = os.path.join(os.path.expanduser("~"), "Desktop", "luggage_dataset5.csv")
# ---> 38 df.to_csv(out_tmp, index=False)
#      39 df.to_csv(out_desktop, index=False)
#      40 '''
#      41 s3.upload_file(out_tmp, bucket, key)
#      42 print("Saved to:", out_desktop)
#      43 print(f"Uploaded back to s3://{bucket}/{key}")'''
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '\tmp'
