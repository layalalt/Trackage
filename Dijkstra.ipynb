# %%
import pygame
import random
import math
import queue
import pandas as pd
from datetime import datetime, timedelta, date
import time
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# ---------------- Global Configuration ----------------

PPM = 1100 / 170  # Pixels Per Meter (screen scaling)
pixel_speed = ((3 * PPM) / 60) * 20  # Converts 3 m/s to pixels per frame (adjusted for 60 FPS and visibility)

SIMULATION_SPEED = 20.0 # Adjust simulation speed here
update_log = []  # Global log for simulation messages

'''
# Set to store reservations that will have a longer wait time (4-5 minutes)
delayed_reservations = set()
# Counter to limit the number of delayed reservations
delayed_count = 0
# Maximum number of delayed reservations per flight#
MAX_DELAYED_RESERVATIONS = 0
'''

def add_update_message(message, color):
    update_log.append((message, color, pygame.time.get_ticks()))
    # Debug print
    print(f"[LOG] {message}")

"""Loads luggage data from CSV and filters for SLHS-handled bags."""
file_path = "~/Desktop/B-350P-equalwith rare.csv"
df = pd.read_csv(file_path)
df = df[df['Cluster_Size'] != 1]
#df['Handled_by_SLHS'] = df['Handled_by_SLHS'].astype(str).str.lower()
#df = df[df['Handled_by_SLHS'] == 'true']

'''
def get_flights_data(data):
    """Organizes luggage data into a dictionary grouped by flight number."""
    flights = data['Flight_Number'].unique()
    flights_data = {}
    for flight in flights:
        flights_data[flight] = data[data['Flight_Number'] == flight]
    return flights_data

def expected_bags_for_reservation(reservation, fallback):
    """
    Returns the expected bag count extracted from the reservation id.
    For instance, if the id ends with "04", returns 4.
    Otherwise, uses the fallback value.
    """
    if reservation[-2:].isdigit():
        return int(reservation[-2:])
    return fallback'''
# Out:
# '\ndef get_flights_data(data):\n    """Organizes luggage data into a dictionary grouped by flight number."""\n    flights = data[\'Flight_Number\'].unique()\n    flights_data = {}\n    for flight in flights:\n        flights_data[flight] = data[data[\'Flight_Number\'] == flight]\n    return flights_data\n\ndef expected_bags_for_reservation(reservation, fallback):\n    """\n    Returns the expected bag count extracted from the reservation id.\n    For instance, if the id ends with "04", returns 4.\n    Otherwise, uses the fallback value.\n    """\n    if reservation[-2:].isdigit():\n        return int(reservation[-2:])\n    return fallback'

# %%
# ---------------- Definitions for Conveyor Belt and Key Points ----------------

conveyor_belts = [
    [(1200, 600), (100, 600)],
    [(100, 550), (800, 550)],
    [(200, 500), (800, 500)],
    [(200, 450), (700, 450)],
    [(300, 400), (700, 400)],
    [(300, 350), (600, 350)],
    [(100, 250), (900, 250)],
    [(100, 600), (100, 200)],
    [(200, 500), (200, 200)],
    [(300, 400), (300, 200)],
    [(600, 350), (600, 200)],
    [(700, 450), (700, 200)],
    [(800, 550), (800, 200)],
    [(900, 600), (900, 250)],
    [(580, 200), (600, 250)],
    [(620, 200), (600, 250)],
    [(320, 200), (300, 250)],
    [(280, 200), (300, 250)],
    [(680, 200), (700, 250)],
    [(720, 200), (700, 250)],
    [(180, 200), (200, 250)],
    [(220, 200), (200, 250)],
    [(780, 200), (800, 250)],
    [(820, 200), (800, 250)],
    [(80, 200), (100, 250)],
    [(120, 200), (100, 250)],
]

points = [
    (100, 250), (100, 550), (100, 600),
    (200, 250), (200, 450), (200, 500),
    (300, 250), (300, 350), (300, 400),
    (600, 250), (600, 350), (700, 250),
    (700, 400), (700, 450), (800, 250),
    (800, 500), (800, 550), (900, 250),
    (900, 600)
]

gates_entry_positions = [
    (600, 250),  # Gate 7
    (300, 250),  # Gate 6
    (700, 250),  # Gate 5
    (200, 250),  # Gate 4
    (800, 250),  # Gate 3
    (100, 250),  # Gate 2
]

pickup_gates_positions = [
    (600, 200), # Gates 2
    (580, 200),
    (620, 200),
    (300, 200), # Gates 3
    (320, 200),
    (280, 200),
    (700, 200), # Gates 4
    (680, 200),
    (720, 200),
    (200, 200), # Gates 5
    (180, 200),
    (220, 200),
    (800, 200), # Gates 6
    (780, 200), 
    (820, 200),
    (100, 200), # Gates 7
    (80, 200),
    (120, 200),
]

# %%
# ---------------- Path and Reservation Color Generation ----------------

class Path:
    def __init__(self, name, points):
        self.name = name
        self.points = points

paths = {
    7: Path("F", [(900, 600), (100, 600), (100, 550), (100, 250)]),
    6: Path("E", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (800, 250)]),
    5: Path("D", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (200, 250)]),
    4: Path("C", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (700, 250)]),
    3: Path("B", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (300, 400), (300, 350), (300, 250)]),
    2: Path("A", [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450),
                   (700, 400), (300, 400), (300, 350), (600, 350), (600, 250)]),
    0: Path("Alaa", [(900, 600), (100, 600), (100, 550)]),
    17: Path("Woo", [(900, 600),(900, 600), (100, 600), (100, 550)])
}

paths_2 = {
    cluster: Path(str(cluster), points)
    for cluster, points in {
        7: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        6: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        5: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        4: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        3: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)],
        2: [(900, 600), (100, 600), (100, 550), (800, 550), (800, 500), (200, 500),
            (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350),
            (600, 250), (900, 250), (900, 600)]
    }.items()
}

def generate_random_color():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    
cluster_sizes = [2, 3, 4, 5, 6, 7, 8, 9, 10] 

cluster_colors = {size: generate_random_color() for size in cluster_sizes}

reservation_colors = {}
claim_stats = {}

# %%
# ---------------- Bag Class ----------------

class Bag:
    def __init__(self, bag_id, reservation_id, cluster_size, flight_number, flight_time):
        self.ready = False
        self.path = []
        self.bag_id = bag_id
        self.reservation = reservation_id
        self.flight_number = flight_number
        self.flight_time = flight_time
        self.cluster_size = cluster_size  # total number of bags in this reservation
        self.position = (1200, 600)
        self.assigned_to_gate = False
        self.gate = None
        self.speed = pixel_speed 
        self.target = None
        self.time = None
        self.at_gate = False
        self.route_points = [(100, 600), (100, 550), (800, 550), (800, 500), (200, 500), (200, 450), (700, 450), (700, 400), (300, 400), (300, 350), (600, 350), (600, 250), (900, 250), (900, 600)]
        self.current_point_index = 1
        self.color = cluster_colors[cluster_size]
        '''
        if self.reservation not in reservation_colors:
            reservation_colors[self.reservation] = generate_color_from_id(self.reservation)
        self.color = reservation_colors[self.reservation]
        self.last_reassign_attempt = 0'''

    def set_at_gate(self):
        self.at_gate = True

    def set_ready(self):
        self.ready = True   

    def set_path(self, path):
        self.path = path.points[:]
        if self.path:
            self.target = self.path.pop(0)

    def set_gate(self, pickup_gate):
        self.gate = pickup_gate

    def has_reached_gate(self):
        if self.gate is None:
            return False
        return self.position == self.gate.position

    def append_path(self, path):
        if isinstance(path, Path):  
            self.path.extend(path.points)  
        elif isinstance(path, list):  
            self.path.extend(path)  
        elif isinstance(path, tuple):
            self.path.append(path)
        
        if not self.target and self.path:
            self.target = self.path.pop(0) # Get it moving

    def append_remaining_path(self, path):
        for i, point in enumerate(path.points):
            if point == self.position:
                self.path = [self.position]
                self.append_path(path.points[i:])
                return True
            elif point == self.target:
                self.path = [self.target]
                self.append_path(path.points[i:])
                return True

        return False
                
                
    def move(self):
        if self.target:
            x, y = self.position
            tx, ty = self.target
    
            dx = tx - x
            dy = ty - y
            distance = (dx**2 + dy**2) ** 0.5
    
            if distance <= self.speed:
                self.position = self.target  
                if self.path:
                    self.target = self.path.pop(0)  
                else:
                    self.target = None  
            else:
                self.position = (x + (dx / distance) * self.speed, 
                                 y + (dy / distance) * self.speed)

# %%
# ---------------- Gate and PickupGate Classes ----------------
'''
gate_names = {7: "2", 6: "3", 5: "4", 4: "5", 3: "6", 2: "7"}
sub_gate_labels = ["A", "B", "C"]
terminal_priority = [7, 6, 5, 4, 3, 2]'''

class Gate:
    
    def __init__(self, name, gates, position):
        self.name = name
        self.gates = gates
        self.position = position

'''
    def search(self, bag):
        # First try to assign to a gate with the same reservation that is not full.
        for i, pickup in enumerate(self.gates):
            if pickup.reservation == bag.reservation and not pickup.full:
                return i
        # Otherwise, return the first unreserved gate.
        for i, pickup in enumerate(self.gates):
            if pickup.reservation is None:
                return i
        return -1'''

class PickupGate:
    
    def __init__(self, name, position, parent):
        self.name = name
        self.position = position
        self.parent = parent
        self.display_name = f"{name}"
        self.reservation = None
        self.load = 0
        self.bags = []
        self.full = False
        self.available = True
        self.dispense_time = None


    def set_reservation(self, reservation):
        if self.reservation is None:  
            self.reservation = reservation
            return True
        else:
            return False


    def add_luggage(self, bag):
        if bag.reservation == self.reservation:
            self.bags.append(bag)
            self.load += 1

    def is_full(self):
        if(self.load>0):
            if self.load == self.bags[0].cluster_size:
                return True
        return False

    def clear_luggage(self):
        removed_bags = self.bags if self.bags else []  
        self.reservation = None
        self.load = 0
        self.bags = [] 
        return removed_bags  
    

# ---------------- Initialize Gate Entries ----------------
gate_entries = []
k = 0
for i in range(6):
    gates = []
    for j in range(3):
        gates.append(PickupGate(j+1, pickup_gates_positions[k], i+2))
        k += 1
    gate_entries.append(Gate(i+2, gates, gates_entry_positions[i]))

# %%
point_to_gates = {

    (900, 250): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200),
                 (100, 200), (80, 200),  (120, 200)],
    
    (900, 600): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200),
                 (100, 200), (80, 200),  (120, 200)],

    (100, 600): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200),
                 (100, 200), (80, 200),  (120, 200)],

    (100, 550): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200),
                 (100, 200), (80, 200),  (120, 200)],

    (800, 550): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200)],
    
    (800, 500): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200),
                 (800, 200), (780, 200), (820, 200)],
    
    (200, 500): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200)],
    
    (200, 450): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200),
                 (200, 200), (180, 200), (220, 200)],
    
    (700, 450): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200)],
    
    (700, 400): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200),
                 (700, 200), (680, 200), (720, 200)],

    (300, 400): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200)],
    
    (300, 350): [(600, 200), (580, 200), (620, 200),
                 (300, 200), (320, 200), (280, 200)],

    (600, 350): [(600, 200), (580, 200), (620, 200)],

    (600, 250): [(600, 200), (580, 200), (620, 200)],

}

pickup_gates2 = []
for gate in gate_entries:
    pickup_gates2.extend(gate.gates) 


position_to_gate = {gate.position: gate for gate in pickup_gates2}

# Step 3: Convert your point_to_gates (positions) into point_to_gate_objects
points_to_gate = {
    point: [position_to_gate[pos] for pos in gate_positions if pos in position_to_gate]
    for point, gate_positions in point_to_gates.items()
}

# %%
def format_time(seconds):
    minutes = int(seconds // 60)
    sec = int(seconds % 60)
    return f"{minutes:02d}:{sec:02d}"

def convert_flight_time(flight_time_str):
    flight_time_obj = datetime.strptime(flight_time_str + ":00", '%H:%M:%S')
    return flight_time_obj

# %%
class Reservation:
    
    def __init__(self, id, cluster_size, flight_time, flight_number):
        self.id = id
        self.cluster_size = cluster_size
        self.flight_time = flight_time
        self.flight_number = flight_number
        self.time = None

    def __str__(self):
        return f"Reservation ID: {self.id}, Cluster Size: {self.cluster_size}, Time: {self.time}, Flight time: {self.flight_time}, Flight number: {self.flight_number}"

# %%
reservations = []

conveyor_belt = []

# Group bags by Flight Number
grouped_conveyor_belt = []

for flight_number, group in df.groupby("Flight_Number"):
    flight_bags = []
    
    flight_time = group.iloc[0]["Flight_Arrival_Time"]
    flight_start_time = convert_flight_time(flight_time) # Convert to milliseconds
    
    for reservation_id, res_group in group.groupby("Reservation_ID"):
        cluster_size = int(res_group.iloc[0]['Cluster_Size'])  # Get cluster size

        for _, row in res_group.iterrows():
            real_bag_id = row["Bag_ID"]  # Adjust this column name if different
            flight_bags.append(Bag(real_bag_id, reservation_id, cluster_size, flight_number, flight_time))

    # Shuffle bags within this flight
    random.shuffle(flight_bags)

    bag_time = flight_start_time  # Initialize the timestamp for the first bag

    for bag in flight_bags:
        # Assign timestamp after shuffling
        bag.time = datetime.combine(date.today(), bag_time.time())
        bag_time += timedelta(seconds=3)/20 

    # Optionally: store flight index to simulate 12-min delay later
    for bag in flight_bags:
        bag.flight_index = len(grouped_conveyor_belt)

    grouped_conveyor_belt.append(flight_bags)

for flight_group in grouped_conveyor_belt:
    conveyor_belt.extend(flight_group)

conveyor_belt = sorted(conveyor_belt, key=lambda bag: bag.time)

reservations_info = {}

for bag in conveyor_belt:
    if bag.reservation not in reservations_info:
        reservations_info[bag.reservation] = (bag.cluster_size, bag.flight_time, bag.flight_number)

reservations_f = {
    res_id: Reservation(res_id, cluster_size, flight_time, flight_number)
    for res_id, (cluster_size, flight_time, flight_number) in reservations_info.items()
}

reservations_c = []

# %%
# ---------------- Main Simulation ----------------
pygame.init()

start_time = pygame.time.get_ticks()  
'''
def is_gate_in_use(pickup, scanned_bags):
    for b in scanned_bags:
        if b.gate == pickup and pickup.status == "Reserved":
            return True
    return False'''
    

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (65, 105, 225)
GRAY = (200, 200, 200)

font = pygame.font.Font(None, 20)
width, height = 1400, 720
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Dijkstra's Algorithm Benchmark")
title_font = pygame.font.SysFont('Arial', 28, bold=True)
subtitle_font = pygame.font.SysFont('Arial', 20)
info_font = pygame.font.SysFont('Arial', 16)
medium_font = pygame.font.SysFont('Arial', 14)
small_font = pygame.font.SysFont('Arial', 12)
clock = pygame.time.Clock()

scanned_bags = []
bag_start_times = []  
i = 0
running = True
spawn_interval = 2000
last_spawn_time = 0
flight_start_time = pygame.time.get_ticks()

while running:
        
    screen.fill(WHITE)
    
    # Draw header and flight info.
    title_text = title_font.render("Dijkstra's Algorithm Benchmark", True, BLACK)
    screen.blit(title_text, (width // 2 - title_text.get_width() // 2, 20))
    #flight_text = subtitle_font.render(f"Flight: {flight_num}", True, BLUE)
    #screen.blit(flight_text, (width // 2 - flight_text.get_width() // 2, 60))
    elapsed_ms = (pygame.time.get_ticks() - start_time)*20
    elapsed_seconds = elapsed_ms // 1000
    minutes = elapsed_seconds // 60
    seconds = elapsed_seconds % 60
    time_text = font.render(f"Time: {minutes:02}:{seconds:02}", True, BLACK)
    screen.blit(time_text, (10, 10))
    
    # Draw conveyor belts and key points.
    for belt in conveyor_belts:
        pygame.draw.line(screen, BLACK, belt[0], belt[1], 3)
        
    for point in points:
        pygame.draw.circle(screen, BLACK, point, 5)
    
    # Draw gate entries and pickup gates.
    for gate in gate_entries:
        pygame.draw.rect(screen, BLACK, (gate.position[0] - 5, gate.position[1] - 5, 10, 10))
        for pickup in gate.gates:
            if pickup.reservation is None:
                pygame.draw.rect(screen, BLACK, (pickup.position[0] - 5, pickup.position[1] - 5, 10, 10))
            else:
                gate_color = reservation_colors.get(pickup.reservation, BLACK)
                pygame.draw.circle(screen, gate_color, pickup.position, 5)
            #point_label = small_font.render(pickup.display_name, True, BLACK)
            #screen.blit(point_label, (pickup.position[0] - 12, pickup.position[1] - 20))
    for gate_group in gate_entries: 
        for gate in gate_group.gates: 
            load_text = font.render(f"{gate.load}", True, BLACK)    
            screen.blit(load_text, (gate.position[0]-5, 177))
            
    help_text = small_font.render("Press ESC to exit | SPACE to skip wait time", True, GRAY)
    screen.blit(help_text, (width - 300, height - 20))
    
    #draw_log_box(screen, medium_font)
    #draw_gate_status_box(screen, medium_font, WHITE)
    
    # Event handling.
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    
    current_ticks = pygame.time.get_ticks()
    current_time = convert_flight_time(conveyor_belt[0].flight_time) + timedelta(milliseconds=current_ticks*20)
    current_time = current_time.time()

    more_items = len(conveyor_belt)-1

    if i < len(conveyor_belt):
        bag = conveyor_belt[i]
        if current_time >= bag.time.time():
            
            scanned_bags.append(bag)
            bag.set_ready()
            bag_start_times.append(bag.time.time())
             
    
            assigned = False        
            for gate in gate_entries:
                for pickup in gate.gates:
                    if pickup.available and not bag.assigned_to_gate:
                        bag.set_path(paths[gate.name])
                        bag.append_path(pickup.position)
                        bag.set_gate(pickup)
                        pickup.reservation = bag.reservation
                        pickup.available = False
                        bag.assigned_to_gate = True
                        assigned = True
                        for other_bag in conveyor_belt:
                            if other_bag.reservation == bag.reservation:
                                other_bag.set_path(paths[gate.name])
                                other_bag.append_path(pickup.position)
                                other_bag.set_gate(pickup)
                                other_bag.assigned_to_gate = True
                        break
                if assigned:
                    break  
                    
            if not bag.assigned_to_gate:
                bag.set_path(paths[0]) 
                
            i+=1

    still_moving = False 

    j=0
    for bag in scanned_bags:
 
        if bag.assigned_to_gate and bag.position == bag.gate.position and bag.at_gate:
            pygame.draw.circle(screen, bag.color, bag.position, 8)
        elif bag.assigned_to_gate and bag.position == bag.gate.position:
            bag.gate.add_luggage(bag)
            bag.set_at_gate()
            pygame.draw.circle(screen, bag.color, bag.position, 8)
        elif not bag.assigned_to_gate and bag.position == bag.route_points[bag.current_point_index]:            
            gates_to_check = points_to_gate.get(bag.position, [])
            for gate in gates_to_check:
                if gate.available:
                    if not bag.append_remaining_path(paths[gate.parent]):
                        bag.append_path(paths[gate.parent])
                        bag.append_path(gate.position)
                        bag.set_gate(gate)
                        gate.available = False
                        gate.reservation = bag.reservation
                        bag.assigned_to_gate = True
                    else:
                        bag.append_path(gate.position)
                        bag.set_gate(gate)
                        gate.available = False
                        gate.reservation = bag.reservation
                        bag.assigned_to_gate = True
                    if bag.path: 
                        bag.move()
                        pygame.draw.circle(screen, bag.color, bag.position, 8)
                    for other_bag in conveyor_belt: 
                        if not other_bag.assigned_to_gate and bag.reservation == other_bag.reservation and other_bag is not bag:
                            if other_bag.append_remaining_path(paths[gate.parent]):
                                other_bag.append_path(gate.position)
                                other_bag.set_gate(gate)
                                other_bag.assigned_to_gate = True
                            else:
                                other_bag.append_remaining_path(paths_2[2])
                                other_bag.append_path(paths[gate.parent])
                                other_bag.append_path(gate.position)
                                other_bag.set_gate(gate)
                                other_bag.assigned_to_gate = True
                    break

            if not bag.assigned_to_gate:
                bag.current_point_index = (bag.current_point_index + 1) % 14
                bag.append_path(bag.route_points[bag.current_point_index])
                if bag.path: 
                    bag.move()
                    pygame.draw.circle(screen, bag.color, bag.position, 8)
          
        elif current_time >= bag_start_times[j]:
            bag.move()
            pygame.draw.circle(screen, bag.color, bag.position, 8)
            still_moving = True 

        for gate_group in gate_entries:
            for gate in gate_group.gates:
                if gate.is_full():
                    res_id = gate.reservation
                    if res_id in reservations_f:  
                        reservations_f[res_id].time = current_time
                        reservations_c.append(reservations_f.pop(res_id))
                        
        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.is_full() and gate.dispense_time is None:
                    wait_seconds = random.randint(0, 70)/20
                    gate.dispense_time = datetime.combine(datetime.today(), current_time) + timedelta(seconds=wait_seconds)
                            

        for gate_group in gate_entries: 
            for gate in gate_group.gates: 
                if gate.dispense_time and current_time >= gate.dispense_time.time():
                    removed_bags = gate.clear_luggage()  
                    gate.available = True
                    gate.reservation = None
                    scanned_bags = [bag for bag in scanned_bags if bag not in removed_bags]  
                    print(f"Gate {gate_group.name} was emptied, and {len(removed_bags)} bags disappeared at {current_time}!")
                    gate.dispense_time = None  
        j+=1
        
    pygame.display.update()
    clock.tick(60) 

    if i >= len(conveyor_belt) and not still_moving:
        running = False  
        pygame.quit()
# Out:
# 2025-05-17 23:25:41.463 python[25670:1196228] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-05-17 23:25:41.463 python[25670:1196228] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Gate 7 was emptied, and 4 bags disappeared at 10:37:42.220000!
# Gate 5 was emptied, and 2 bags disappeared at 10:37:42.900000!
# Gate 7 was emptied, and 5 bags disappeared at 10:38:36.880000!
# Gate 6 was emptied, and 7 bags disappeared at 10:38:54.980000!
# Gate 7 was emptied, and 2 bags disappeared at 10:39:03.540000!
# Gate 2 was emptied, and 4 bags disappeared at 10:39:14.200000!
# Gate 6 was emptied, and 7 bags disappeared at 10:39:19.880000!
# Gate 5 was emptied, and 7 bags disappeared at 10:39:31.440000!
# Gate 6 was emptied, and 8 bags disappeared at 10:39:40.360000!
# Gate 4 was emptied, and 7 bags disappeared at 10:40:08.020000!
# Gate 5 was emptied, and 9 bags disappeared at 10:40:13.900000!
# Gate 4 was emptied, and 9 bags disappeared at 10:40:21.220000!
# Gate 2 was emptied, and 5 bags disappeared at 10:40:30.880000!
# Gate 4 was emptied, and 6 bags disappeared at 10:40:40.840000!
# Gate 5 was emptied, and 4 bags disappeared at 10:40:42.160000!
# Gate 3 was emptied, and 7 bags disappeared at 10:40:43.140000!
# Gate 3 was emptied, and 8 bags disappeared at 10:40:57.020000!
# Gate 3 was emptied, and 6 bags disappeared at 10:40:59.340000!
# Gate 2 was emptied, and 7 bags disappeared at 10:41:00.320000!
# Gate 7 was emptied, and 7 bags disappeared at 10:41:29!
# Gate 6 was emptied, and 7 bags disappeared at 10:41:45.800000!
# Gate 6 was emptied, and 4 bags disappeared at 10:41:58.920000!
# Gate 7 was emptied, and 5 bags disappeared at 10:42:12.060000!
# Gate 2 was emptied, and 2 bags disappeared at 10:42:12.720000!
# Gate 2 was emptied, and 6 bags disappeared at 10:42:14.060000!
# Gate 3 was emptied, and 4 bags disappeared at 10:42:15.660000!
# Gate 7 was emptied, and 6 bags disappeared at 10:42:20.300000!
# Gate 4 was emptied, and 4 bags disappeared at 10:42:26.920000!
# Gate 5 was emptied, and 5 bags disappeared at 10:42:57.160000!
# Gate 3 was emptied, and 3 bags disappeared at 10:43:08!
# Gate 4 was emptied, and 3 bags disappeared at 10:43:12.580000!
# Gate 6 was emptied, and 9 bags disappeared at 10:43:13.940000!
# Gate 2 was emptied, and 2 bags disappeared at 10:43:26.180000!
# Gate 5 was emptied, and 7 bags disappeared at 10:43:59.600000!
# Gate 3 was emptied, and 6 bags disappeared at 10:44:04.900000!
# Gate 4 was emptied, and 5 bags disappeared at 10:44:07.640000!
# Gate 2 was emptied, and 4 bags disappeared at 10:44:33.320000!
# Gate 5 was emptied, and 6 bags disappeared at 10:44:34.040000!
# Gate 6 was emptied, and 2 bags disappeared at 10:44:36.720000!
# Gate 6 was emptied, and 6 bags disappeared at 10:44:52.360000!
# Gate 7 was emptied, and 3 bags disappeared at 10:44:57.940000!
# Gate 5 was emptied, and 5 bags disappeared at 10:44:58.900000!
# Gate 7 was emptied, and 7 bags disappeared at 10:45:05.580000!
# Gate 4 was emptied, and 2 bags disappeared at 10:45:07.220000!
# Gate 3 was emptied, and 3 bags disappeared at 10:45:30.560000!
# Gate 7 was emptied, and 6 bags disappeared at 10:45:30.560000!
# Gate 2 was emptied, and 2 bags disappeared at 10:45:47.600000!
# Gate 4 was emptied, and 4 bags disappeared at 10:45:58.300000!
# Gate 6 was emptied, and 2 bags disappeared at 10:46:06.380000!
# Gate 2 was emptied, and 5 bags disappeared at 10:46:41.480000!
# Gate 3 was emptied, and 4 bags disappeared at 10:46:47.460000!
# Gate 6 was emptied, and 6 bags disappeared at 10:46:49.780000!
# Gate 5 was emptied, and 3 bags disappeared at 10:47:07.900000!
# Gate 6 was emptied, and 7 bags disappeared at 10:47:17.620000!
# Gate 4 was emptied, and 2 bags disappeared at 10:47:23.660000!
# Gate 5 was emptied, and 5 bags disappeared at 10:47:24.660000!
# Gate 5 was emptied, and 6 bags disappeared at 10:47:33.240000!
# Gate 7 was emptied, and 3 bags disappeared at 10:47:38.180000!
# Gate 4 was emptied, and 4 bags disappeared at 10:47:47.200000!
# Gate 3 was emptied, and 7 bags disappeared at 10:47:51.740000!
# Gate 4 was emptied, and 7 bags disappeared at 10:47:51.740000!
# Gate 2 was emptied, and 6 bags disappeared at 10:48:12.320000!
# Gate 2 was emptied, and 3 bags disappeared at 10:48:15.620000!
# Gate 3 was emptied, and 3 bags disappeared at 10:48:31.200000!
# Gate 2 was emptied, and 6 bags disappeared at 10:48:47.520000!
# Gate 7 was emptied, and 6 bags disappeared at 10:48:55.560000!
# Gate 4 was emptied, and 2 bags disappeared at 10:49:18.600000!
# Gate 5 was emptied, and 3 bags disappeared at 10:49:35.520000!
# Gate 7 was emptied, and 10 bags disappeared at 10:49:35.520000!
# Gate 6 was emptied, and 9 bags disappeared at 10:49:43!
# Gate 6 was emptied, and 4 bags disappeared at 10:49:45.620000!
# Gate 3 was emptied, and 3 bags disappeared at 10:49:52.520000!
# Gate 5 was emptied, and 6 bags disappeared at 10:50:07.800000!
# Gate 2 was emptied, and 3 bags disappeared at 10:50:11.400000!
# Gate 6 was emptied, and 6 bags disappeared at 10:50:14.340000!
# Gate 4 was emptied, and 3 bags disappeared at 10:50:29.100000!
# Gate 5 was emptied, and 5 bags disappeared at 10:50:48.200000!
# Gate 4 was emptied, and 4 bags disappeared at 10:50:54.520000!
# Gate 5 was emptied, and 3 bags disappeared at 10:51:20.160000!
# Gate 7 was emptied, and 4 bags disappeared at 10:51:33.560000!
# Gate 3 was emptied, and 5 bags disappeared at 10:51:37.180000!
# Gate 4 was emptied, and 3 bags disappeared at 10:51:44.040000!
# Gate 2 was emptied, and 6 bags disappeared at 10:51:53.580000!
# Gate 6 was emptied, and 3 bags disappeared at 10:52:05.340000!
# Gate 6 was emptied, and 2 bags disappeared at 10:52:11.220000!
# Gate 3 was emptied, and 5 bags disappeared at 10:52:22.040000!
# Gate 2 was emptied, and 4 bags disappeared at 10:52:28.700000!
# Gate 7 was emptied, and 2 bags disappeared at 10:52:41.180000!
# Gate 7 was emptied, and 5 bags disappeared at 10:52:41.820000!
# Gate 6 was emptied, and 5 bags disappeared at 10:53:17.280000!
# Gate 2 was emptied, and 2 bags disappeared at 10:53:26.220000!
# Gate 5 was emptied, and 5 bags disappeared at 10:53:41.540000!
# Gate 4 was emptied, and 2 bags disappeared at 10:53:45.200000!
# Gate 3 was emptied, and 7 bags disappeared at 10:53:46.900000!
# Gate 7 was emptied, and 5 bags disappeared at 10:53:59.560000!
# Gate 6 was emptied, and 2 bags disappeared at 10:54:13.520000!
# Gate 4 was emptied, and 8 bags disappeared at 10:54:15.180000!
# Gate 2 was emptied, and 3 bags disappeared at 10:54:19.780000!
# Gate 5 was emptied, and 6 bags disappeared at 10:54:25.220000!
# Gate 2 was emptied, and 4 bags disappeared at 10:54:42.500000!
# Gate 4 was emptied, and 6 bags disappeared at 10:54:46.480000!
# Gate 5 was emptied, and 2 bags disappeared at 10:54:49.600000!
# Gate 3 was emptied, and 3 bags disappeared at 10:54:56.280000!
# Gate 3 was emptied, and 6 bags disappeared at 10:55:11.680000!
# Gate 6 was emptied, and 4 bags disappeared at 10:55:11.680000!
# Gate 2 was emptied, and 8 bags disappeared at 10:55:35.300000!
# Gate 4 was emptied, and 6 bags disappeared at 10:55:44.220000!
# Gate 7 was emptied, and 7 bags disappeared at 10:56:33.160000!
# Gate 7 was emptied, and 3 bags disappeared at 10:56:33.520000!
# Gate 3 was emptied, and 2 bags disappeared at 10:56:46.480000!
# Gate 7 was emptied, and 7 bags disappeared at 10:56:57.620000!
# Gate 4 was emptied, and 2 bags disappeared at 10:57:07.640000!
# Gate 6 was emptied, and 4 bags disappeared at 10:57:10.980000!
# Gate 6 was emptied, and 6 bags disappeared at 10:57:14.880000!
# Gate 5 was emptied, and 4 bags disappeared at 10:57:30.080000!
# Gate 5 was emptied, and 5 bags disappeared at 10:57:34.040000!
# Gate 2 was emptied, and 3 bags disappeared at 10:57:35.660000!
# Gate 6 was emptied, and 2 bags disappeared at 10:57:41.600000!
# Gate 5 was emptied, and 3 bags disappeared at 10:57:47.240000!
# Gate 4 was emptied, and 3 bags disappeared at 10:57:50.540000!
# Gate 2 was emptied, and 6 bags disappeared at 10:58:12.980000!
# Gate 4 was emptied, and 9 bags disappeared at 10:58:26.840000!
# Gate 4 was emptied, and 2 bags disappeared at 10:58:31.140000!
# Gate 3 was emptied, and 5 bags disappeared at 10:58:31.480000!
# Gate 5 was emptied, and 2 bags disappeared at 10:58:46.120000!
# Gate 5 was emptied, and 3 bags disappeared at 10:58:57.220000!
# Gate 7 was emptied, and 5 bags disappeared at 10:58:58.260000!
# Gate 3 was emptied, and 10 bags disappeared at 10:59:00.260000!
# Gate 2 was emptied, and 5 bags disappeared at 10:59:04.620000!
# Gate 4 was emptied, and 6 bags disappeared at 10:59:20.500000!
# Gate 2 was emptied, and 2 bags disappeared at 10:59:40.540000!
# Gate 7 was emptied, and 7 bags disappeared at 10:59:51.560000!
# Gate 5 was emptied, and 4 bags disappeared at 11:00:11.920000!
# Gate 3 was emptied, and 7 bags disappeared at 11:00:33.680000!
# Gate 7 was emptied, and 7 bags disappeared at 11:00:48.240000!
# Gate 6 was emptied, and 7 bags disappeared at 11:00:58.840000!
# Gate 4 was emptied, and 7 bags disappeared at 11:01:13.700000!
# Gate 5 was emptied, and 10 bags disappeared at 11:01:24.240000!
# Gate 6 was emptied, and 5 bags disappeared at 11:01:24.240000!
# Gate 6 was emptied, and 3 bags disappeared at 11:01:32.180000!
# Gate 4 was emptied, and 3 bags disappeared at 11:01:41.080000!
# Gate 5 was emptied, and 3 bags disappeared at 11:01:55.580000!
# Gate 3 was emptied, and 4 bags disappeared at 11:01:57.600000!
# Gate 2 was emptied, and 5 bags disappeared at 11:01:59.600000!
# Gate 3 was emptied, and 6 bags disappeared at 11:02:23.220000!
# Gate 7 was emptied, and 6 bags disappeared at 11:02:24.860000!
# Gate 2 was emptied, and 5 bags disappeared at 11:02:40.520000!
# Gate 5 was emptied, and 4 bags disappeared at 11:02:45.880000!
# Gate 4 was emptied, and 7 bags disappeared at 11:02:49.520000!
# Gate 2 was emptied, and 6 bags disappeared at 11:03:04.200000!
# Gate 3 was emptied, and 3 bags disappeared at 11:03:30.440000!
# Gate 7 was emptied, and 5 bags disappeared at 11:03:43.420000!
# Gate 4 was emptied, and 3 bags disappeared at 11:03:46.340000!
# Gate 7 was emptied, and 3 bags disappeared at 11:04:03.880000!
# Gate 6 was emptied, and 3 bags disappeared at 11:04:30.080000!
# Gate 6 was emptied, and 4 bags disappeared at 11:04:39.600000!
# Gate 5 was emptied, and 4 bags disappeared at 11:04:42.580000!
# Gate 6 was emptied, and 6 bags disappeared at 11:05:00.080000!
# Gate 4 was emptied, and 2 bags disappeared at 11:05:02.060000!
# Gate 5 was emptied, and 3 bags disappeared at 11:05:12.220000!
# Gate 4 was emptied, and 10 bags disappeared at 11:05:20.140000!
# Gate 3 was emptied, and 7 bags disappeared at 11:05:20.800000!
# Gate 4 was emptied, and 2 bags disappeared at 11:05:33.120000!
# Gate 2 was emptied, and 7 bags disappeared at 11:05:43.500000!
# Gate 7 was emptied, and 5 bags disappeared at 11:05:44.480000!
# Gate 3 was emptied, and 7 bags disappeared at 11:06:01.540000!
# Gate 4 was emptied, and 2 bags disappeared at 11:06:05.180000!
# Gate 2 was emptied, and 9 bags disappeared at 11:06:11.760000!
# Gate 2 was emptied, and 7 bags disappeared at 11:06:20.460000!
# Gate 7 was emptied, and 4 bags disappeared at 11:06:22.080000!
# Gate 6 was emptied, and 3 bags disappeared at 11:06:31.120000!
# Gate 5 was emptied, and 7 bags disappeared at 11:06:35.560000!
# Gate 2 was emptied, and 3 bags disappeared at 11:06:50.700000!
# Gate 3 was emptied, and 4 bags disappeared at 11:06:51.020000!
# Gate 4 was emptied, and 3 bags disappeared at 11:07:00.600000!
# Gate 4 was emptied, and 2 bags disappeared at 11:07:01.600000!
# Gate 7 was emptied, and 2 bags disappeared at 11:07:08.260000!
# Gate 7 was emptied, and 7 bags disappeared at 11:07:31.680000!
# Gate 5 was emptied, and 4 bags disappeared at 11:07:40.960000!
# Gate 3 was emptied, and 6 bags disappeared at 11:07:58.820000!
# Gate 6 was emptied, and 3 bags disappeared at 11:08:14.420000!
# Gate 3 was emptied, and 6 bags disappeared at 11:08:19.880000!
# Gate 6 was emptied, and 2 bags disappeared at 11:08:29.500000!
# Gate 6 was emptied, and 4 bags disappeared at 11:08:32.400000!
# Gate 5 was emptied, and 9 bags disappeared at 11:08:53.480000!
# Gate 4 was emptied, and 4 bags disappeared at 11:08:54.520000!
# Gate 4 was emptied, and 5 bags disappeared at 11:09:01.840000!
# Gate 5 was emptied, and 3 bags disappeared at 11:09:05.760000!
# Gate 3 was emptied, and 2 bags disappeared at 11:09:32.260000!
# Gate 2 was emptied, and 4 bags disappeared at 11:09:34.240000!
# Gate 2 was emptied, and 3 bags disappeared at 11:09:41.460000!
# Gate 2 was emptied, and 5 bags disappeared at 11:09:49.360000!
# Gate 7 was emptied, and 5 bags disappeared at 11:10:07.560000!
# Gate 4 was emptied, and 4 bags disappeared at 11:10:38.820000!
# Gate 6 was emptied, and 6 bags disappeared at 11:10:42.420000!
# Gate 5 was emptied, and 3 bags disappeared at 11:10:59.460000!
# Gate 7 was emptied, and 10 bags disappeared at 11:11:10.320000!
# Gate 2 was emptied, and 3 bags disappeared at 11:11:17.220000!
# Gate 7 was emptied, and 5 bags disappeared at 11:11:30.780000!
# Gate 3 was emptied, and 6 bags disappeared at 11:11:36.320000!
# Gate 4 was emptied, and 6 bags disappeared at 11:11:37.640000!
# Gate 3 was emptied, and 2 bags disappeared at 11:11:41.880000!
# Gate 4 was emptied, and 5 bags disappeared at 11:11:54.860000!
# Gate 6 was emptied, and 7 bags disappeared at 11:11:56.480000!
# Gate 3 was emptied, and 3 bags disappeared at 11:12:09.140000!
# Gate 5 was emptied, and 4 bags disappeared at 11:12:10.440000!
# Gate 2 was emptied, and 5 bags disappeared at 11:12:20.780000!
# Gate 6 was emptied, and 5 bags disappeared at 11:12:22.420000!
# Gate 2 was emptied, and 4 bags disappeared at 11:12:24.400000!
# Gate 5 was emptied, and 5 bags disappeared at 11:13:00.920000!
# Gate 7 was emptied, and 6 bags disappeared at 11:13:17.520000!
# Gate 4 was emptied, and 2 bags disappeared at 11:13:33.500000!
# Gate 6 was emptied, and 3 bags disappeared at 11:13:47.480000!
# Gate 7 was emptied, and 7 bags disappeared at 11:13:54.360000!
# Gate 7 was emptied, and 3 bags disappeared at 11:14:07.640000!
# Gate 5 was emptied, and 3 bags disappeared at 11:14:21.040000!
# Gate 6 was emptied, and 9 bags disappeared at 11:14:24.680000!
# Gate 6 was emptied, and 4 bags disappeared at 11:14:33.500000!
# Gate 2 was emptied, and 3 bags disappeared at 11:14:58.900000!
# Gate 3 was emptied, and 7 bags disappeared at 11:14:58.900000!
# Gate 3 was emptied, and 6 bags disappeared at 11:15:09.480000!
# Gate 4 was emptied, and 7 bags disappeared at 11:15:12.080000!
# Gate 3 was emptied, and 5 bags disappeared at 11:15:15.560000!
# Gate 2 was emptied, and 5 bags disappeared at 11:15:17.180000!
# Gate 2 was emptied, and 7 bags disappeared at 11:15:49.240000!
# Gate 4 was emptied, and 8 bags disappeared at 11:15:54.540000!
# Gate 5 was emptied, and 7 bags disappeared at 11:16:00.420000!
# Gate 4 was emptied, and 3 bags disappeared at 11:16:34.700000!
# Gate 7 was emptied, and 2 bags disappeared at 11:16:35.880000!
# Gate 5 was emptied, and 4 bags disappeared at 11:16:46.160000!
# Gate 7 was emptied, and 7 bags disappeared at 11:17:06.780000!
# Gate 5 was emptied, and 2 bags disappeared at 11:17:09.100000!
# Gate 3 was emptied, and 2 bags disappeared at 11:17:15.320000!
# Gate 7 was emptied, and 2 bags disappeared at 11:17:22.600000!
# Gate 3 was emptied, and 5 bags disappeared at 11:17:31.220000!
# Gate 6 was emptied, and 5 bags disappeared at 11:17:34.860000!
# Gate 4 was emptied, and 3 bags disappeared at 11:18:03.420000!
# Gate 7 was emptied, and 2 bags disappeared at 11:18:06.740000!
# Gate 5 was emptied, and 6 bags disappeared at 11:18:09.860000!
# Gate 6 was emptied, and 2 bags disappeared at 11:18:13.440000!
# Gate 6 was emptied, and 10 bags disappeared at 11:18:18.780000!
# Gate 6 was emptied, and 4 bags disappeared at 11:18:25.980000!
# Gate 2 was emptied, and 6 bags disappeared at 11:18:30.220000!
# Gate 4 was emptied, and 3 bags disappeared at 11:18:37.560000!
# Gate 2 was emptied, and 5 bags disappeared at 11:18:45.560000!
# Gate 3 was emptied, and 4 bags disappeared at 11:18:55.900000!
# Gate 2 was emptied, and 3 bags disappeared at 11:19:32.480000!
# Gate 7 was emptied, and 2 bags disappeared at 11:19:45.480000!
# Gate 3 was emptied, and 5 bags disappeared at 11:19:47.420000!
# Gate 5 was emptied, and 7 bags disappeared at 11:19:54.780000!
# Gate 4 was emptied, and 5 bags disappeared at 11:20:23.760000!
# Gate 7 was emptied, and 7 bags disappeared at 11:20:36.700000!
# Gate 7 was emptied, and 3 bags disappeared at 11:20:43.280000!
# Gate 5 was emptied, and 7 bags disappeared at 11:20:51.540000!
# Gate 3 was emptied, and 6 bags disappeared at 11:21:05.440000!
# Gate 4 was emptied, and 4 bags disappeared at 11:21:20.880000!
# Gate 6 was emptied, and 4 bags disappeared at 11:21:24.200000!
# Gate 2 was emptied, and 3 bags disappeared at 11:21:36.220000!
# Gate 5 was emptied, and 3 bags disappeared at 11:21:53.380000!
# Gate 6 was emptied, and 5 bags disappeared at 11:21:59.300000!
# Gate 6 was emptied, and 2 bags disappeared at 11:22:03.560000!
# Gate 4 was emptied, and 4 bags disappeared at 11:22:05.200000!
# Gate 3 was emptied, and 4 bags disappeared at 11:22:12.100000!
# Gate 5 was emptied, and 5 bags disappeared at 11:22:22.200000!
# Gate 2 was emptied, and 7 bags disappeared at 11:22:25.540000!
# Gate 7 was emptied, and 6 bags disappeared at 11:22:25.840000!
# Gate 2 was emptied, and 3 bags disappeared at 11:22:30.900000!
# Gate 3 was emptied, and 2 bags disappeared at 11:22:42.520000!
# Gate 7 was emptied, and 4 bags disappeared at 11:23:07.240000!
# Gate 3 was emptied, and 7 bags disappeared at 11:23:40.640000!
# Gate 5 was emptied, and 6 bags disappeared at 11:23:53.220000!
# Gate 7 was emptied, and 4 bags disappeared at 11:23:56.540000!
# Gate 4 was emptied, and 7 bags disappeared at 11:24:09!
# Gate 4 was emptied, and 5 bags disappeared at 11:24:09.940000!
# Gate 4 was emptied, and 4 bags disappeared at 11:24:12.560000!
# Gate 6 was emptied, and 4 bags disappeared at 11:24:39.900000!
# Gate 2 was emptied, and 2 bags disappeared at 11:24:48.880000!
# Gate 4 was emptied, and 2 bags disappeared at 11:25:12.440000!
# Gate 2 was emptied, and 3 bags disappeared at 11:25:14.100000!
# Gate 6 was emptied, and 5 bags disappeared at 11:25:30.860000!
# Gate 5 was emptied, and 10 bags disappeared at 11:25:32.500000!
# Gate 3 was emptied, and 8 bags disappeared at 11:25:58.620000!
# Gate 5 was emptied, and 6 bags disappeared at 11:26:03.260000!
# Gate 6 was emptied, and 4 bags disappeared at 11:26:04.920000!
# Gate 2 was emptied, and 5 bags disappeared at 11:26:13.580000!
# Gate 7 was emptied, and 7 bags disappeared at 11:26:16.840000!
# Gate 5 was emptied, and 3 bags disappeared at 11:26:22.100000!
# Gate 7 was emptied, and 6 bags disappeared at 11:26:24.740000!
# Gate 7 was emptied, and 7 bags disappeared at 11:26:25.400000!
# Gate 3 was emptied, and 3 bags disappeared at 11:26:29.980000!
# Gate 4 was emptied, and 5 bags disappeared at 11:26:54.280000!
# Gate 3 was emptied, and 10 bags disappeared at 11:27:20.500000!
# Gate 2 was emptied, and 2 bags disappeared at 11:27:38.860000!
# Gate 2 was emptied, and 7 bags disappeared at 11:27:44.560000!
# Gate 4 was emptied, and 7 bags disappeared at 11:28:00.200000!
# Gate 6 was emptied, and 5 bags disappeared at 11:28:01.200000!
# Gate 7 was emptied, and 4 bags disappeared at 11:28:01.880000!
# Gate 2 was emptied, and 7 bags disappeared at 11:28:09.840000!
# Gate 6 was emptied, and 4 bags disappeared at 11:28:29.820000!
# Gate 5 was emptied, and 7 bags disappeared at 11:28:32.500000!
# Gate 4 was emptied, and 6 bags disappeared at 11:28:37.520000!
# Gate 3 was emptied, and 5 bags disappeared at 11:28:49.120000!
# Gate 3 was emptied, and 7 bags disappeared at 11:28:51.760000!
# Gate 7 was emptied, and 7 bags disappeared at 11:29:09.360000!
# Gate 7 was emptied, and 2 bags disappeared at 11:29:11!
# Gate 5 was emptied, and 5 bags disappeared at 11:29:13.600000!
# Gate 6 was emptied, and 5 bags disappeared at 11:29:16.520000!
# Gate 4 was emptied, and 2 bags disappeared at 11:29:50.940000!
# Gate 7 was emptied, and 7 bags disappeared at 11:30:00.360000!
# Gate 5 was emptied, and 5 bags disappeared at 11:30:02!
# Gate 3 was emptied, and 5 bags disappeared at 11:30:04.300000!
# Gate 4 was emptied, and 4 bags disappeared at 11:30:29.260000!
# Gate 6 was emptied, and 2 bags disappeared at 11:30:33.540000!
# Gate 3 was emptied, and 5 bags disappeared at 11:30:36.900000!
# Gate 4 was emptied, and 4 bags disappeared at 11:30:37.220000!
# Gate 2 was emptied, and 7 bags disappeared at 11:30:52.260000!
# Gate 5 was emptied, and 3 bags disappeared at 11:31:02.880000!
# Gate 5 was emptied, and 5 bags disappeared at 11:31:10.560000!
# Gate 2 was emptied, and 7 bags disappeared at 11:31:14.540000!
# Gate 6 was emptied, and 7 bags disappeared at 11:31:49.720000!
# Gate 7 was emptied, and 5 bags disappeared at 11:31:50.400000!
# Gate 2 was emptied, and 3 bags disappeared at 11:31:52.380000!
# Gate 4 was emptied, and 2 bags disappeared at 11:32:01.860000!
# Gate 5 was emptied, and 4 bags disappeared at 11:32:22.340000!
# Gate 3 was emptied, and 6 bags disappeared at 11:32:23.980000!
# Gate 7 was emptied, and 6 bags disappeared at 11:32:51.140000!
# Gate 6 was emptied, and 6 bags disappeared at 11:32:59.140000!
# Gate 4 was emptied, and 4 bags disappeared at 11:33:15.860000!
# Gate 2 was emptied, and 4 bags disappeared at 11:33:18.180000!
# Gate 7 was emptied, and 5 bags disappeared at 11:33:42.200000!
# Gate 7 was emptied, and 3 bags disappeared at 11:33:44.580000!
# Gate 3 was emptied, and 5 bags disappeared at 11:33:45.880000!
# Gate 2 was emptied, and 5 bags disappeared at 11:33:48.560000!
# Gate 5 was emptied, and 6 bags disappeared at 11:33:54.880000!
# Gate 3 was emptied, and 9 bags disappeared at 11:33:55.900000!
# Gate 6 was emptied, and 2 bags disappeared at 11:34:09.560000!
# Gate 4 was emptied, and 10 bags disappeared at 11:34:21.740000!
# Gate 3 was emptied, and 6 bags disappeared at 11:34:25.380000!
# Gate 6 was emptied, and 5 bags disappeared at 11:34:28.740000!
# Gate 2 was emptied, and 6 bags disappeared at 11:34:37.440000!
# Gate 5 was emptied, and 7 bags disappeared at 11:34:45.140000!
# Gate 7 was emptied, and 3 bags disappeared at 11:34:46.520000!
# Gate 5 was emptied, and 3 bags disappeared at 11:34:58.200000!
# Gate 3 was emptied, and 2 bags disappeared at 11:35:35.880000!
# Gate 4 was emptied, and 9 bags disappeared at 11:35:37.200000!
# Gate 2 was emptied, and 5 bags disappeared at 11:36:51.860000!
# Gate 4 was emptied, and 3 bags disappeared at 11:36:53.180000!
# Gate 6 was emptied, and 8 bags disappeared at 11:36:56.460000!
# Gate 2 was emptied, and 7 bags disappeared at 11:37:01.160000!
# Gate 2 was emptied, and 4 bags disappeared at 11:37:07.060000!
# Gate 3 was emptied, and 4 bags disappeared at 11:37:24.880000!
# Gate 3 was emptied, and 4 bags disappeared at 11:37:29.220000!
# Gate 4 was emptied, and 2 bags disappeared at 11:37:37.880000!
# Gate 6 was emptied, and 5 bags disappeared at 11:37:39.180000!
# Gate 7 was emptied, and 7 bags disappeared at 11:37:44.840000!
# Gate 5 was emptied, and 6 bags disappeared at 11:37:48.860000!
# Gate 7 was emptied, and 3 bags disappeared at 11:37:48.860000!
# Gate 6 was emptied, and 6 bags disappeared at 11:37:56.160000!
# Gate 7 was emptied, and 3 bags disappeared at 11:38:02.120000!
# Gate 5 was emptied, and 7 bags disappeared at 11:38:14.380000!
# Gate 5 was emptied, and 8 bags disappeared at 11:38:57.360000!
# Gate 6 was emptied, and 4 bags disappeared at 11:39:25.980000!
# Gate 4 was emptied, and 4 bags disappeared at 11:39:32.700000!
# Gate 3 was emptied, and 3 bags disappeared at 11:39:38.380000!
# Gate 5 was emptied, and 2 bags disappeared at 11:39:43.020000!
# Gate 6 was emptied, and 2 bags disappeared at 11:39:53.920000!
# Gate 4 was emptied, and 5 bags disappeared at 11:39:58.780000!
# Gate 2 was emptied, and 5 bags disappeared at 11:40:06.740000!
# Gate 4 was emptied, and 6 bags disappeared at 11:40:13.720000!
# Gate 3 was emptied, and 3 bags disappeared at 11:40:18.800000!
# Gate 2 was emptied, and 5 bags disappeared at 11:40:33.720000!
# Gate 3 was emptied, and 4 bags disappeared at 11:40:42.940000!
# Gate 2 was emptied, and 6 bags disappeared at 11:40:52.320000!
# Gate 6 was emptied, and 2 bags disappeared at 11:41:13.020000!
# Gate 5 was emptied, and 5 bags disappeared at 11:41:16.040000!
# Gate 7 was emptied, and 4 bags disappeared at 11:41:23.300000!
# Gate 7 was emptied, and 6 bags disappeared at 11:41:38.940000!
# Gate 7 was emptied, and 4 bags disappeared at 11:41:43.620000!
# Gate 5 was emptied, and 3 bags disappeared at 11:41:58.720000!
# Gate 4 was emptied, and 2 bags disappeared at 11:42:21.420000!
# Gate 6 was emptied, and 3 bags disappeared at 11:42:36.660000!

# %%
for res in reservations_c:
    flight_time_obj = datetime.strptime(res.flight_time, "%H:%M" if len(res.flight_time) == 5 else "%H:%M:%S").time()

    served_dt = datetime.combine(datetime.today(), res.time)
    flight_dt = datetime.combine(datetime.today(), flight_time_obj)
    res.time = served_dt - flight_dt

    print(res)
# Out:
# Reservation ID: RES-00030, Cluster Size: 4, Time: 0:03:39.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00055, Cluster Size: 2, Time: 0:03:41.580000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00352, Cluster Size: 5, Time: 0:04:33.820000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00052, Cluster Size: 7, Time: 0:04:53.700000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00353, Cluster Size: 2, Time: 0:05:01.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00403, Cluster Size: 4, Time: 0:05:11.620000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00053, Cluster Size: 7, Time: 0:05:18.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00261, Cluster Size: 7, Time: 0:05:28.480000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00304, Cluster Size: 8, Time: 0:05:37.080000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00386, Cluster Size: 7, Time: 0:06:06.080000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00006, Cluster Size: 9, Time: 0:06:12.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00330, Cluster Size: 9, Time: 0:06:19.920000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00036, Cluster Size: 5, Time: 0:06:28.620000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00048, Cluster Size: 6, Time: 0:06:37.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00415, Cluster Size: 4, Time: 0:06:41.200000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00325, Cluster Size: 7, Time: 0:06:41.520000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00253, Cluster Size: 8, Time: 0:06:56.340000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00037, Cluster Size: 6, Time: 0:06:57.640000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00051, Cluster Size: 7, Time: 0:06:59.680000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00237, Cluster Size: 7, Time: 0:07:28.680000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00029, Cluster Size: 7, Time: 0:07:43.200000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00077, Cluster Size: 4, Time: 0:07:57.960000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00256, Cluster Size: 5, Time: 0:08:09.780000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00061, Cluster Size: 2, Time: 0:08:11.120000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00049, Cluster Size: 6, Time: 0:08:13.700000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00067, Cluster Size: 4, Time: 0:08:14.060000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00002, Cluster Size: 6, Time: 0:08:18.960000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00069, Cluster Size: 4, Time: 0:08:24.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00399, Cluster Size: 5, Time: 0:08:54.520000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00242, Cluster Size: 3, Time: 0:09:07.680000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00047, Cluster Size: 3, Time: 0:09:10.600000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00003, Cluster Size: 9, Time: 0:09:10.600000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00362, Cluster Size: 2, Time: 0:09:24.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00038, Cluster Size: 7, Time: 0:09:59.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00248, Cluster Size: 6, Time: 0:10:04.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00350, Cluster Size: 5, Time: 0:10:05.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00010, Cluster Size: 6, Time: 0:10:31.280000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00243, Cluster Size: 4, Time: 0:10:31.280000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00364, Cluster Size: 2, Time: 0:10:33.680000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00041, Cluster Size: 6, Time: 0:10:50.060000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00075, Cluster Size: 5, Time: 0:10:55.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00272, Cluster Size: 3, Time: 0:10:57.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00014, Cluster Size: 7, Time: 0:11:02.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00021, Cluster Size: 2, Time: 0:11:04.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00028, Cluster Size: 6, Time: 0:11:28.280000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00025, Cluster Size: 3, Time: 0:11:29.920000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00409, Cluster Size: 2, Time: 0:11:43.940000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00066, Cluster Size: 4, Time: 0:11:57.960000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00273, Cluster Size: 2, Time: 0:12:06.040000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00020, Cluster Size: 5, Time: 0:12:38.500000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00332, Cluster Size: 4, Time: 0:12:45.760000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00060, Cluster Size: 6, Time: 0:12:49.100000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00413, Cluster Size: 3, Time: 0:13:06.280000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00302, Cluster Size: 7, Time: 0:13:15.960000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00368, Cluster Size: 2, Time: 0:13:20.980000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00357, Cluster Size: 5, Time: 0:13:24, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00366, Cluster Size: 6, Time: 0:13:30.600000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00269, Cluster Size: 3, Time: 0:13:37.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00286, Cluster Size: 4, Time: 0:13:46.860000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00278, Cluster Size: 7, Time: 0:13:48.500000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00262, Cluster Size: 7, Time: 0:13:51.420000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00011, Cluster Size: 6, Time: 0:14:10.960000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00239, Cluster Size: 3, Time: 0:14:12.980000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00428, Cluster Size: 3, Time: 0:14:29.220000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00295, Cluster Size: 6, Time: 0:14:44.600000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00290, Cluster Size: 6, Time: 0:14:55.220000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00044, Cluster Size: 2, Time: 0:15:15.660000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00026, Cluster Size: 10, Time: 0:15:32.540000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00008, Cluster Size: 3, Time: 0:15:34.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00073, Cluster Size: 9, Time: 0:15:42, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00275, Cluster Size: 4, Time: 0:15:44.620000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00435, Cluster Size: 3, Time: 0:15:50.580000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00012, Cluster Size: 6, Time: 0:16:05.500000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00358, Cluster Size: 3, Time: 0:16:11.080000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00057, Cluster Size: 6, Time: 0:16:13.360000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00282, Cluster Size: 3, Time: 0:16:27.480000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00401, Cluster Size: 5, Time: 0:16:47.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00257, Cluster Size: 4, Time: 0:16:52.120000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00062, Cluster Size: 3, Time: 0:17:18.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00032, Cluster Size: 4, Time: 0:17:33.240000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00372, Cluster Size: 5, Time: 0:17:33.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00349, Cluster Size: 3, Time: 0:17:41.100000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00289, Cluster Size: 6, Time: 0:17:53.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00046, Cluster Size: 3, Time: 0:18:04.380000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00064, Cluster Size: 2, Time: 0:18:10.220000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00065, Cluster Size: 5, Time: 0:18:20.120000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00017, Cluster Size: 4, Time: 0:18:28.340000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00151, Cluster Size: 2, Time: 0:05:38.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00045, Cluster Size: 5, Time: 0:18:38.600000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00259, Cluster Size: 5, Time: 0:19:16.640000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00324, Cluster Size: 2, Time: 0:19:22.580000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00323, Cluster Size: 5, Time: 0:19:41.540000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00351, Cluster Size: 7, Time: 0:19:43.200000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00336, Cluster Size: 2, Time: 0:19:44.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00018, Cluster Size: 5, Time: 0:19:56.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00392, Cluster Size: 2, Time: 0:20:12.520000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00007, Cluster Size: 8, Time: 0:20:14.860000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00035, Cluster Size: 3, Time: 0:20:16.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00054, Cluster Size: 6, Time: 0:20:22.780000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00406, Cluster Size: 4, Time: 0:20:40.840000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00015, Cluster Size: 6, Time: 0:20:43.520000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00027, Cluster Size: 2, Time: 0:20:48.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00277, Cluster Size: 3, Time: 0:20:53.840000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00076, Cluster Size: 4, Time: 0:21:10.060000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00040, Cluster Size: 6, Time: 0:21:10.400000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00056, Cluster Size: 8, Time: 0:21:34.640000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00059, Cluster Size: 6, Time: 0:21:43.580000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00043, Cluster Size: 7, Time: 0:22:31.200000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00019, Cluster Size: 3, Time: 0:22:31.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00303, Cluster Size: 2, Time: 0:22:43.800000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00106, Cluster Size: 7, Time: 0:09:54.660000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00016, Cluster Size: 2, Time: 0:23:06.300000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00144, Cluster Size: 4, Time: 0:10:08.300000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00096, Cluster Size: 6, Time: 0:10:12.560000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00024, Cluster Size: 4, Time: 0:23:27.460000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00001, Cluster Size: 5, Time: 0:23:31.360000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00013, Cluster Size: 3, Time: 0:23:32.020000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00009, Cluster Size: 2, Time: 0:23:38.940000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00058, Cluster Size: 3, Time: 0:23:44.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00071, Cluster Size: 3, Time: 0:23:48.880000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00023, Cluster Size: 6, Time: 0:24:09.360000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00084, Cluster Size: 9, Time: 0:11:25.840000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00412, Cluster Size: 5, Time: 0:24:28.520000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00121, Cluster Size: 2, Time: 0:11:29.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00085, Cluster Size: 2, Time: 0:11:44.820000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00074, Cluster Size: 3, Time: 0:24:55.940000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00337, Cluster Size: 5, Time: 0:11:56.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00345, Cluster Size: 10, Time: 0:11:57.220000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00068, Cluster Size: 5, Time: 0:25:04.280000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00039, Cluster Size: 6, Time: 0:25:19.180000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00280, Cluster Size: 2, Time: 0:25:37.240000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00360, Cluster Size: 7, Time: 0:12:48.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00293, Cluster Size: 4, Time: 0:26:11.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00131, Cluster Size: 7, Time: 0:13:31.680000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00080, Cluster Size: 7, Time: 0:13:47.940000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00152, Cluster Size: 7, Time: 0:13:58.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00004, Cluster Size: 7, Time: 0:27:13.060000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00326, Cluster Size: 5, Time: 0:27:21.560000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00398, Cluster Size: 10, Time: 0:14:22.580000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00390, Cluster Size: 3, Time: 0:27:31.540000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00367, Cluster Size: 3, Time: 0:27:37.500000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00284, Cluster Size: 3, Time: 0:27:54.940000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00245, Cluster Size: 4, Time: 0:14:55.940000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00072, Cluster Size: 5, Time: 0:27:57.260000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00306, Cluster Size: 6, Time: 0:15:19.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00437, Cluster Size: 6, Time: 0:15:21.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00114, Cluster Size: 5, Time: 0:15:39.860000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00301, Cluster Size: 4, Time: 0:28:44.780000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00101, Cluster Size: 7, Time: 0:15:48.200000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00104, Cluster Size: 6, Time: 0:16:01.540000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00034, Cluster Size: 3, Time: 0:29:30.120000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00384, Cluster Size: 5, Time: 0:16:40.520000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00099, Cluster Size: 3, Time: 0:16:46, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00148, Cluster Size: 3, Time: 0:17:00.280000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00236, Cluster Size: 3, Time: 0:17:29.740000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00118, Cluster Size: 4, Time: 0:17:36.340000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00247, Cluster Size: 4, Time: 0:17:38.960000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00296, Cluster Size: 6, Time: 0:17:56.540000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00091, Cluster Size: 2, Time: 0:18:02.060000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00241, Cluster Size: 3, Time: 0:31:08.900000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00355, Cluster Size: 7, Time: 0:18:18.500000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00102, Cluster Size: 10, Time: 0:18:18.860000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00434, Cluster Size: 2, Time: 0:18:30.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00120, Cluster Size: 7, Time: 0:18:41.840000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00157, Cluster Size: 5, Time: 0:18:44.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00147, Cluster Size: 7, Time: 0:19:01.220000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00111, Cluster Size: 2, Time: 0:19:04.200000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00146, Cluster Size: 9, Time: 0:19:10.460000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00139, Cluster Size: 7, Time: 0:19:16.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00087, Cluster Size: 4, Time: 0:19:19.500000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00141, Cluster Size: 3, Time: 0:19:28.840000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00098, Cluster Size: 7, Time: 0:19:32.800000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00160, Cluster Size: 3, Time: 0:19:47.080000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00122, Cluster Size: 4, Time: 0:19:48.080000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00319, Cluster Size: 2, Time: 0:19:58.920000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00156, Cluster Size: 3, Time: 0:19:59.580000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00270, Cluster Size: 2, Time: 0:33:05.300000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00318, Cluster Size: 7, Time: 0:20:30.660000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00145, Cluster Size: 4, Time: 0:20:37.640000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00113, Cluster Size: 6, Time: 0:20:55.900000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00317, Cluster Size: 3, Time: 0:21:11.740000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00137, Cluster Size: 6, Time: 0:21:18.500000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00100, Cluster Size: 2, Time: 0:21:27.860000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00128, Cluster Size: 4, Time: 0:21:31.420000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00161, Cluster Size: 9, Time: 0:21:51.820000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00093, Cluster Size: 4, Time: 0:21:52.820000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00374, Cluster Size: 5, Time: 0:21:59.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00115, Cluster Size: 3, Time: 0:22:02.820000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00331, Cluster Size: 2, Time: 0:22:28.680000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00155, Cluster Size: 4, Time: 0:22:32.940000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00124, Cluster Size: 3, Time: 0:22:39.800000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00321, Cluster Size: 5, Time: 0:22:48.040000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00426, Cluster Size: 5, Time: 0:10:05.900000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00305, Cluster Size: 4, Time: 0:23:37.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00385, Cluster Size: 6, Time: 0:23:40.460000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00431, Cluster Size: 3, Time: 0:23:58.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00252, Cluster Size: 10, Time: 0:11:08, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00387, Cluster Size: 3, Time: 0:24:14.580000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00410, Cluster Size: 5, Time: 0:24:29.460000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00281, Cluster Size: 6, Time: 0:24:33.060000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00081, Cluster Size: 6, Time: 0:24:36.320000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00279, Cluster Size: 2, Time: 0:24:40.200000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00095, Cluster Size: 5, Time: 0:24:52.520000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00079, Cluster Size: 7, Time: 0:24:53.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00112, Cluster Size: 3, Time: 0:25:08.820000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00150, Cluster Size: 4, Time: 0:25:10.120000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00369, Cluster Size: 5, Time: 0:25:18.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00250, Cluster Size: 5, Time: 0:12:21.120000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00375, Cluster Size: 4, Time: 0:25:21.440000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00348, Cluster Size: 5, Time: 0:26:00.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00310, Cluster Size: 6, Time: 0:13:16.840000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00316, Cluster Size: 2, Time: 0:26:31.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00391, Cluster Size: 3, Time: 0:26:44.520000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00208, Cluster Size: 7, Time: 0:13:52.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00149, Cluster Size: 3, Time: 0:27:06.980000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00408, Cluster Size: 3, Time: 0:14:19.100000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00218, Cluster Size: 9, Time: 0:14:24.360000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00182, Cluster Size: 4, Time: 0:14:32.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00246, Cluster Size: 7, Time: 0:27:55.280000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00123, Cluster Size: 3, Time: 0:27:58.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00109, Cluster Size: 6, Time: 0:28:08.840000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00130, Cluster Size: 7, Time: 0:28:10.800000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00103, Cluster Size: 5, Time: 0:28:13.400000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00433, Cluster Size: 5, Time: 0:28:15.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00090, Cluster Size: 7, Time: 0:28:46.200000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00376, Cluster Size: 8, Time: 0:28:51.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00427, Cluster Size: 7, Time: 0:28:59.780000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00240, Cluster Size: 2, Time: 0:29:33.040000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00417, Cluster Size: 3, Time: 0:29:33.400000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00425, Cluster Size: 4, Time: 0:29:44.840000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00207, Cluster Size: 7, Time: 0:17:03.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00414, Cluster Size: 2, Time: 0:30:05.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00363, Cluster Size: 2, Time: 0:30:14.020000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00097, Cluster Size: 2, Time: 0:30:21.580000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00086, Cluster Size: 5, Time: 0:30:27.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00117, Cluster Size: 5, Time: 0:30:34.500000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00142, Cluster Size: 3, Time: 0:31:01.140000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00164, Cluster Size: 2, Time: 0:18:04.740000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00300, Cluster Size: 6, Time: 0:18:09.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00344, Cluster Size: 2, Time: 0:31:13.120000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00153, Cluster Size: 10, Time: 0:31:17.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00254, Cluster Size: 4, Time: 0:18:23.340000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00154, Cluster Size: 6, Time: 0:31:30.220000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00371, Cluster Size: 3, Time: 0:31:35.880000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00129, Cluster Size: 5, Time: 0:31:43.160000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00354, Cluster Size: 4, Time: 0:31:54.540000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00126, Cluster Size: 3, Time: 0:32:32.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00217, Cluster Size: 2, Time: 0:19:41.860000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00140, Cluster Size: 5, Time: 0:32:44.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00333, Cluster Size: 7, Time: 0:32:53.420000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00378, Cluster Size: 5, Time: 0:33:21.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00359, Cluster Size: 7, Time: 0:33:35.720000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00328, Cluster Size: 3, Time: 0:33:40.980000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00167, Cluster Size: 7, Time: 0:20:49.240000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00134, Cluster Size: 6, Time: 0:34:04.120000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00078, Cluster Size: 4, Time: 0:34:19.560000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00365, Cluster Size: 4, Time: 0:21:21.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00432, Cluster Size: 3, Time: 0:34:32.920000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00388, Cluster Size: 3, Time: 0:34:51.080000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00291, Cluster Size: 5, Time: 0:34:58.980000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00287, Cluster Size: 2, Time: 0:35:02.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00268, Cluster Size: 4, Time: 0:22:03.560000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00188, Cluster Size: 4, Time: 0:22:09.820000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00383, Cluster Size: 5, Time: 0:22:21.900000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00334, Cluster Size: 6, Time: 0:22:22.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00283, Cluster Size: 7, Time: 0:22:25.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00199, Cluster Size: 3, Time: 0:22:29.220000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00421, Cluster Size: 2, Time: 0:35:42.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00251, Cluster Size: 4, Time: 0:23:04.020000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00271, Cluster Size: 7, Time: 0:23:37.040000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00418, Cluster Size: 6, Time: 0:23:50.900000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00266, Cluster Size: 4, Time: 0:36:53.860000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00338, Cluster Size: 7, Time: 0:24:07.340000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00216, Cluster Size: 5, Time: 0:24:07.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00158, Cluster Size: 4, Time: 0:37:10.280000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00159, Cluster Size: 4, Time: 0:37:39.260000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00092, Cluster Size: 2, Time: 0:37:47.860000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00116, Cluster Size: 2, Time: 0:38:11.800000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00222, Cluster Size: 3, Time: 0:25:13.420000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00370, Cluster Size: 5, Time: 0:25:27.480000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00179, Cluster Size: 10, Time: 0:25:31.860000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00339, Cluster Size: 8, Time: 0:25:56.680000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00181, Cluster Size: 6, Time: 0:25:59.600000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00309, Cluster Size: 4, Time: 0:26:01.940000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00135, Cluster Size: 5, Time: 0:39:11.240000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00393, Cluster Size: 7, Time: 0:26:14.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00082, Cluster Size: 3, Time: 0:39:20.480000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00235, Cluster Size: 6, Time: 0:26:21.140000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00244, Cluster Size: 7, Time: 0:26:22.780000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00089, Cluster Size: 3, Time: 0:39:26.720000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00373, Cluster Size: 5, Time: 0:26:52.980000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00172, Cluster Size: 10, Time: 0:27:19.180000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00424, Cluster Size: 2, Time: 0:40:38.180000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00232, Cluster Size: 7, Time: 0:27:42.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00176, Cluster Size: 4, Time: 0:27:58.880000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00379, Cluster Size: 5, Time: 0:27:58.880000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00308, Cluster Size: 7, Time: 0:27:59.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00166, Cluster Size: 7, Time: 0:28:07.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00225, Cluster Size: 4, Time: 0:28:26.860000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00173, Cluster Size: 7, Time: 0:28:32.160000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00221, Cluster Size: 6, Time: 0:28:34.860000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00228, Cluster Size: 5, Time: 0:28:47.840000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00165, Cluster Size: 7, Time: 0:28:51.120000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00110, Cluster Size: 2, Time: 0:42:07.360000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00230, Cluster Size: 7, Time: 0:29:08.680000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00213, Cluster Size: 5, Time: 0:29:12.960000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00356, Cluster Size: 5, Time: 0:29:15.880000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00340, Cluster Size: 2, Time: 0:55:47.220000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00380, Cluster Size: 7, Time: 0:29:57.660000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00201, Cluster Size: 5, Time: 0:29:59.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00394, Cluster Size: 5, Time: 0:30:03.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00193, Cluster Size: 4, Time: 0:30:27.280000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00107, Cluster Size: 2, Time: 0:43:30.960000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00094, Cluster Size: 4, Time: 0:43:35.200000, Flight time: 10:47, Flight number: BA6532
# Reservation ID: RES-00227, Cluster Size: 5, Time: 0:30:36.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00189, Cluster Size: 7, Time: 0:30:51.580000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00220, Cluster Size: 3, Time: 0:31:01.240000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00200, Cluster Size: 5, Time: 0:31:07.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00422, Cluster Size: 7, Time: 0:31:13.180000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00177, Cluster Size: 7, Time: 0:31:46.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00184, Cluster Size: 5, Time: 0:31:48.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00400, Cluster Size: 3, Time: 0:31:49.720000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00312, Cluster Size: 2, Time: 0:31:58.580000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00238, Cluster Size: 4, Time: 0:32:20.680000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00436, Cluster Size: 6, Time: 0:32:23.660000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00183, Cluster Size: 6, Time: 0:32:48.160000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00341, Cluster Size: 6, Time: 0:32:58.500000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00343, Cluster Size: 4, Time: 0:33:15.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00402, Cluster Size: 4, Time: 0:33:17.480000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00214, Cluster Size: 5, Time: 0:33:39.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00274, Cluster Size: 3, Time: 0:33:41.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00299, Cluster Size: 5, Time: 0:33:42.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00231, Cluster Size: 5, Time: 0:33:45.220000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00203, Cluster Size: 6, Time: 0:33:54.260000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00264, Cluster Size: 9, Time: 0:33:55.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00174, Cluster Size: 2, Time: 0:34:05.860000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00169, Cluster Size: 10, Time: 0:34:21.380000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00260, Cluster Size: 6, Time: 0:34:24.720000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00196, Cluster Size: 5, Time: 0:34:25.740000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00285, Cluster Size: 6, Time: 0:34:34.100000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00342, Cluster Size: 7, Time: 0:34:44.140000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00212, Cluster Size: 3, Time: 0:34:44.800000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00429, Cluster Size: 3, Time: 0:34:57.560000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00206, Cluster Size: 2, Time: 0:35:33.180000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00195, Cluster Size: 9, Time: 0:35:33.820000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00180, Cluster Size: 5, Time: 0:36:51.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00314, Cluster Size: 3, Time: 0:36:52.180000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00224, Cluster Size: 8, Time: 0:36:52.840000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00265, Cluster Size: 7, Time: 0:36:59.180000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00294, Cluster Size: 4, Time: 0:37:06.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00205, Cluster Size: 4, Time: 0:37:23.900000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00311, Cluster Size: 4, Time: 0:37:27.560000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00210, Cluster Size: 2, Time: 0:37:36.200000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00223, Cluster Size: 5, Time: 0:37:37.540000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00192, Cluster Size: 7, Time: 0:37:41.500000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00288, Cluster Size: 3, Time: 0:37:45.480000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00419, Cluster Size: 6, Time: 0:37:47.840000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00178, Cluster Size: 6, Time: 0:37:52.840000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00185, Cluster Size: 3, Time: 0:38:00.520000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00298, Cluster Size: 7, Time: 0:38:14.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00204, Cluster Size: 8, Time: 0:38:54.360000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00234, Cluster Size: 4, Time: 0:39:25.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00211, Cluster Size: 4, Time: 0:39:29.320000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00405, Cluster Size: 3, Time: 0:39:38.080000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00171, Cluster Size: 2, Time: 0:39:41.040000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00197, Cluster Size: 2, Time: 0:39:50.580000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00229, Cluster Size: 5, Time: 0:39:57.800000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00377, Cluster Size: 5, Time: 0:40:04.420000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00263, Cluster Size: 6, Time: 0:40:13.060000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00233, Cluster Size: 3, Time: 0:40:17.460000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00346, Cluster Size: 5, Time: 0:40:31.100000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00255, Cluster Size: 4, Time: 0:40:39.620000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00430, Cluster Size: 6, Time: 0:40:51.960000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00022, Cluster Size: 2, Time: 1:07:10.020000, Flight time: 10:34, Flight number: EK4179
# Reservation ID: RES-00175, Cluster Size: 5, Time: 0:41:13.360000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00198, Cluster Size: 4, Time: 0:41:22.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00215, Cluster Size: 6, Time: 0:41:36.640000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00226, Cluster Size: 4, Time: 0:41:40.300000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00168, Cluster Size: 3, Time: 0:41:55.720000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00202, Cluster Size: 2, Time: 0:42:20.040000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00209, Cluster Size: 3, Time: 0:42:35.340000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00190, Cluster Size: 4, Time: 0:43:18.760000, Flight time: 11:00, Flight number: SV5592
# Reservation ID: RES-00329, Cluster Size: 2, Time: 0:43:20.400000, Flight time: 11:00, Flight number: SV5592
